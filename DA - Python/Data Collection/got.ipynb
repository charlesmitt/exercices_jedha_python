# %%
import requests
import pandas as pd
import json

url = "https://anapioficeandfire.com/api/characters/100"

r = requests.get(url)

# %%
r.content
# Out:
# b'{"url":"https://www.anapioficeandfire.com/api/characters/100","name":"Alysanne Bulwer","gender":"Female","culture":"","born":"In 291 AC","died":"","titles":["Lady of Blackcrown"],"aliases":[],"father":"","mother":"","spouse":"","allegiances":["https://www.anapioficeandfire.com/api/houses/52"],"books":["https://www.anapioficeandfire.com/api/books/3","https://www.anapioficeandfire.com/api/books/5","https://www.anapioficeandfire.com/api/books/8"],"povBooks":[],"tvSeries":[],"playedBy":[]}'

# %%
r.json()
# Out:
# {'url': 'https://www.anapioficeandfire.com/api/characters/100',
#  'name': 'Alysanne Bulwer',
#  'gender': 'Female',
#  'culture': '',
#  'born': 'In 291 AC',
#  'died': '',
#  'titles': ['Lady of Blackcrown'],
#  'aliases': [],
#  'father': '',
#  'mother': '',
#  'spouse': '',
#  'allegiances': ['https://www.anapioficeandfire.com/api/houses/52'],
#  'books': ['https://www.anapioficeandfire.com/api/books/3',
#   'https://www.anapioficeandfire.com/api/books/5',
#   'https://www.anapioficeandfire.com/api/books/8'],
#  'povBooks': [],
#  'tvSeries': [],
#  'playedBy': []}

# %%
r.json().keys()
# Out:
# dict_keys(['url', 'name', 'gender', 'culture', 'born', 'died', 'titles', 'aliases', 'father', 'mother', 'spouse', 'allegiances', 'books', 'povBooks', 'tvSeries', 'playedBy'])

# %%
df = pd.DataFrame(columns=r.json().keys())
df.head()
# Out:
# Empty DataFrame
# Columns: [url, name, gender, culture, born, died, titles, aliases, father, mother, spouse, allegiances, books, povBooks, tvSeries, playedBy]
# Index: []

# %%
for i in range(1,150):
    url = f"https://anapioficeandfire.com/api/characters/{i}"
    r = requests.get(url)
    df.loc[i]=(r.json())
    print("Ajout ",i)
# Out:
# Ajout  1
# Ajout  2
# Ajout  3
# Ajout  4
# Ajout  5
# Ajout  6
# Ajout  7
# Ajout  8
# Ajout  9
# Ajout  10
# Ajout  11
# Ajout  12
# Ajout  13
# Ajout  14
# Ajout  15
# Ajout  16
# Ajout  17
# Ajout  18
# Ajout  19
# Ajout  20
# Ajout  21
# Ajout  22
# Ajout  23
# Ajout  24
# Ajout  25
# Ajout  26
# Ajout  27
# Ajout  28
# Ajout  29
# Ajout  30
# Ajout  31
# Ajout  32
# Ajout  33
# Ajout  34
# Ajout  35
# Ajout  36
# Ajout  37
# Ajout  38
# Ajout  39
# Ajout  40
# Ajout  41
# Ajout  42
# Ajout  43
# Ajout  44
# Ajout  45
# Ajout  46
# Ajout  47
# Ajout  48
# Ajout  49
# Ajout  50
# Ajout  51
# Ajout  52
# Ajout  53
# Ajout  54
# Ajout  55
# Ajout  56
# Ajout  57
# Ajout  58
# Ajout  59
# Ajout  60
# Ajout  61
# Ajout  62
# Ajout  63
# Ajout  64
# Ajout  65
# Ajout  66
# Ajout  67
# Ajout  68
# Ajout  69
# Ajout  70
# Ajout  71
# Ajout  72
# Ajout  73
# Ajout  74
# Ajout  75
# Ajout  76
# Ajout  77
# Ajout  78
# Ajout  79
# Ajout  80
# Ajout  81
# Ajout  82
# Ajout  83
# Ajout  84
# ...

# %%
df.head()
# Out:
#                                                  url    name  gender  \
# 1     https://anapioficeandfire.com/api/characters/1          Female
# 2     https://anapioficeandfire.com/api/characters/2  Walder    Male
# 3     https://anapioficeandfire.com/api/characters/3            Male
# 4  https://www.anapioficeandfire.com/api/characte...          Female
# 5     https://anapioficeandfire.com/api/characters/5            Male
#
#     culture born died titles                     aliases father mother spouse  \
# 1  Braavosi               []  [The Daughter of the Dusk]
# 2                         []                     [Hodor]
# 3                         []                   [Lamprey]
# 4  Braavosi               []         [The Merling Queen]
# 5                         []            [Old Crackbones]
#
#                                       allegiances  \
# 1                                              []
# 2  [https://anapioficeandfire.com/api/houses/362]
# ...
