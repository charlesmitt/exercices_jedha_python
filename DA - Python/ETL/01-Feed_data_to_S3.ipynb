# %% [markdown]
# # Feed data to S3
#
# The goal of this short exercise is to practise using `boto3` to communicate with the Amazon Data Lake service: S3.
#
# The exercise is organized in two parts:
# * Part one will have you upload a file from your local system directly to s3
# * Part two will show you how to send files to your s3 that only exist as local python variables

# %% [markdown]
# ## Part 1

# %% [markdown]
# 1. Start by installing `boto3` if it has not been alrady

# %%
# Install boto3 using pip 
## Add '!' only if you install directly from a Jupyter Notebook
# !pip install Boto3
# Out:
# Requirement already satisfied: Boto3 in c:\users\admin\anaconda3\lib\site-packages (1.35.30)
# Requirement already satisfied: botocore<1.36.0,>=1.35.30 in c:\users\admin\anaconda3\lib\site-packages (from Boto3) (1.35.30)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\admin\anaconda3\lib\site-packages (from Boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\admin\anaconda3\lib\site-packages (from Boto3) (0.10.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\admin\appdata\roaming\python\python312\site-packages (from botocore<1.36.0,>=1.35.30->Boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\admin\anaconda3\lib\site-packages (from botocore<1.36.0,>=1.35.30->Boto3) (2.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\roaming\python\python312\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.36.0,>=1.35.30->Boto3) (1.16.0)

# %% [markdown]
# 2. Import the necessary libraries

# %%
import json
import os
import pandas as pd
import boto3
from dotenv import load_dotenv   #for python-dotenv method
load_dotenv()
# Out:
# True

# %% [markdown]
# 3. Create an instance of `boto3.Session` that connects with your aws account.

# %%
access_key = os.environ.get('aws_access')
secret_key = os.environ.get('aws_secret')

session = boto3.Session(aws_access_key_id=access_key, 
                        aws_secret_access_key=secret_key)

# %% [markdown]
# 4. Create a variable called `s3` that connects your session to the s3 ressource.

# %%
s3 = session.resource("s3")

# %% [markdown]
# 5. Create a variable called `bucket` that will connect to an existing bucket in your s3 or to a bucket you are creating now.

# %%
""""bucket = s3.create_bucket(Bucket="bucketcrypto",CreateBucketConfiguration={
        'LocationConstraint': 'eu-west-3'
    }
)
"""
bucket = s3.Bucket("bucketcrypto")

# %% [markdown]
# 6. In the [documentation](https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/s3.html#S3.Bucket.upload_file), find a method that lets you upload files to your s3, and upload the file `crypto.json` to your bucket in the folder of your choice.

# %%
put_object = bucket.upload_file('crypto_data.json', 'crypto_datffa1.json')

# %% [markdown]
# ## Part 2

# %% [markdown]
# 1. Using the `json` library, load the `crypto_data.json` file in a variable called `crypto`

# %%
with open("crypto_data.json", 'r') as file:
    crypto = json.load(file)

# %% [markdown]
# 2. What is the type of variable `crypto`

# %%
type(crypto)
# Out:
# dict

# %% [markdown]
# 3. Display the different possible keys in `crypto` in the form of a list

# %%
print(crypto.keys())
# Out:
# dict_keys(['btc-bitcoin', 'eth-ethereum', 'usdt-tether', 'bnb-binance-coin', 'hex-hex', 'usdc-usd-coin', 'ada-cardano', 'sol-solana', 'xrp-xrp', 'luna-terra'])

# %% [markdown]
# 4. Have a look at the value associated with the first key, do you think it could easily be converted to a pandas DataFrame?

# %%
crypto.get('btc-bitcoin')
# Out:
# [{'time_open': '2012-01-01T00:00:00Z',
#   'time_close': '2012-01-01T23:59:59Z',
#   'open': 4.72,
#   'high': 4.72,
#   'low': 4.72,
#   'close': 4.72},
#  {'time_open': '2012-01-02T00:00:00Z',
#   'time_close': '2012-01-02T23:59:59Z',
#   'open': 5.27,
#   'high': 5.27,
#   'low': 5.27,
#   'close': 5.27},
#  {'time_open': '2012-01-03T00:00:00Z',
#   'time_close': '2012-01-03T23:59:59Z',
#   'open': 5.22,
#   'high': 5.22,
#   'low': 5.22,
#   'close': 5.22},
#  {'time_open': '2012-01-04T00:00:00Z',
#   'time_close': '2012-01-04T23:59:59Z',
#   'open': 4.88,
#   'high': 4.88,
#   'low': 4.88,
#   'close': 4.88},
#  {'time_open': '2012-01-05T00:00:00Z',
#   'time_close': '2012-01-05T23:59:59Z',
#   'open': 5.57,
#   'high': 5.57,
#   'low': 5.57,
#   'close': 5.57},
#  {'time_open': '2012-01-06T00:00:00Z',
#   'time_close': '2012-01-06T23:59:59Z',
#   'open': 6.95,
#   'high': 6.95,
#   'low': 6.95,
#   'close': 6.95},
#  {'time_open': '2012-01-07T00:00:00Z',
#   'time_close': '2012-01-07T23:59:59Z',
#   'open': 6.7,
#   'high': 6.7,
#   'low': 6.7,
#   'close': 6.7},
#  {'time_open': '2012-01-08T00:00:00Z',
#   'time_close': '2012-01-08T23:59:59Z',
#   'open': 6.81,
#   'high': 6.81,
#   'low': 6.81,
#   'close': 6.81},
#  {'time_open': '2012-01-09T00:00:00Z',
#   'time_close': '2012-01-09T23:59:59Z',
#   'open': 7.11,
#   'high': 7.11,
#   'low': 7.11,
#   'close': 7.11},
#  {'time_open': '2012-01-10T00:00:00Z',
#   'time_close': '2012-01-10T23:59:59Z',
#   'open': 6.33,
#   'high': 6.33,
#   'low': 6.33,
#   'close': 6.33},
#  {'time_open': '2012-01-11T00:00:00Z',
#   'time_close': '2012-01-11T23:59:59Z',
#   'open': 6.36,
#   'high': 6.36,
#   'low': 6.36,
#   'close': 6.36},
#  {'time_open': '2012-01-12T00:00:00Z',
#   'time_close': '2012-01-12T23:59:59Z',
#   'open': 6.9,
#   'high': 6.9,
#   'low': 6.9,
#   'close': 6.9},
#  {'time_open': '2012-01-13T00:00:00Z',
#   'time_close': '2012-01-13T23:59:59Z',
#   'open': 6.8,
#   'high': 6.8,
#   'low': 6.8,
#   'close': 6.8},
#  {'time_open': '2012-01-14T00:00:00Z',
#   'time_close': '2012-01-14T23:59:59Z',
#   'open': 6.41,
#   'high': 6.41,
#   'low': 6.41,
#   'close': 6.41},
#  {'time_open': '2012-01-15T00:00:00Z',
#   'time_close': '2012-01-15T23:59:59Z',
#   'open': 6.75,
#   'high': 6.75,
#   'low': 6.75,
#   'close': 6.75},
#  {'time_open': '2012-01-16T00:00:00Z',
#   'time_close': '2012-01-16T23:59:59Z',
#   'open': 7,
#   'high': 7,
#   'low': 7,
#   'close': 7},
#  {'time_open': '2012-01-17T00:00:00Z',
#   'time_close': '2012-01-17T23:59:59Z',
#   'open': 6.68,
#   'high': 6.68,
#   'low': 6.68,
#   'close': 6.68},
#  {'time_open': '2012-01-18T00:00:00Z',
#   'time_close': '2012-01-18T23:59:59Z',
#   'open': 5.6,
#   'high': 5.6,
#   'low': 5.6,
#   'close': 5.6},
#  {'time_open': '2012-01-19T00:00:00Z',
#   'time_close': '2012-01-19T23:59:59Z',
#   'open': 5.92,
#   'high': 5.92,
#   'low': 5.92,
#   'close': 5.92},
#  {'time_open': '2012-01-20T00:00:00Z',
#   'time_close': '2012-01-20T23:59:59Z',
#   'open': 6.36,
#   'high': 6.36,
#   'low': 6.36,
#   'close': 6.36},
#  {'time_open': '2012-01-21T00:00:00Z',
#   'time_close': '2012-01-21T23:59:59Z',
#   'open': 6.49,
#   'high': 6.49,
#   'low': 6.49,
#   'close': 6.49},
#  {'time_open': '2012-01-22T00:00:00Z',
#   'time_close': '2012-01-22T23:59:59Z',
#   'open': 6.18,
#   'high': 6.18,
#   'low': 6.18,
#   'close': 6.18},
#  {'time_open': '2012-01-23T00:00:00Z',
#   'time_close': '2012-01-23T23:59:59Z',
#   'open': 6.31,
#   'high': 6.31,
#   'low': 6.31,
#   'close': 6.31},
#  {'time_open': '2012-01-24T00:00:00Z',
#   'time_close': '2012-01-24T23:59:59Z',
#   'open': 6.36,
#   'high': 6.36,
#   'low': 6.36,
#   'close': 6.36},
#  {'time_open': '2012-01-25T00:00:00Z',
#   'time_close': '2012-01-25T23:59:59Z',
#   'open': 6.29,
#   'high': 6.29,
#   'low': 6.29,
#   'close': 6.29},
#  {'time_open': '2012-01-26T00:00:00Z',
#   'time_close': '2012-01-26T23:59:59Z',
#   'open': 5.75,
#   'high': 5.75,
#   'low': 5.75,
#   'close': 5.75},
#  {'time_open': '2012-01-27T00:00:00Z',
#   'time_close': '2012-01-27T23:59:59Z',
#   'open': 5.34,
#   'high': 5.34,
#   'low': 5.34,
#   'close': 5.34},
#  {'time_open': '2012-01-28T00:00:00Z',
#   'time_close': '2012-01-28T23:59:59Z',
#   'open': 5.29,
#   'high': 5.29,
#   'low': 5.29,
#   'close': 5.29},
#  {'time_open': '2012-01-29T00:00:00Z',
#   'time_close': '2012-01-29T23:59:59Z',
#   'open': 5.63,
#   'high': 5.63,
#   'low': 5.63,
#   'close': 5.63},
#  {'time_open': '2012-01-30T00:00:00Z',
#   'time_close': '2012-01-30T23:59:59Z',
#   'open': 5.38,
#   'high': 5.38,
#   'low': 5.38,
#   'close': 5.38},
#  {'time_open': '2012-01-31T00:00:00Z',
#   'time_close': '2012-01-31T23:59:59Z',
#   'open': 5.49,
#   'high': 5.49,
#   'low': 5.49,
#   'close': 5.49},
#  {'time_open': '2012-02-01T00:00:00Z',
#   'time_close': '2012-02-01T23:59:59Z',
#   'open': 5.48,
#   'high': 5.48,
#   'low': 5.48,
#   'close': 5.48},
#  {'time_open': '2012-02-02T00:00:00Z',
#   'time_close': '2012-02-02T23:59:59Z',
#   'open': 6.08,
#   'high': 6.08,
#   'low': 6.08,
#   'close': 6.08},
#  {'time_open': '2012-02-03T00:00:00Z',
#   'time_close': '2012-02-03T23:59:59Z',
#   'open': 6.1,
#   'high': 6.1,
#   'low': 6.1,
#   'close': 6.1},
#  {'time_open': '2012-02-04T00:00:00Z',
#   'time_close': '2012-02-04T23:59:59Z',
#   'open': 5.96,
#   'high': 5.96,
#   'low': 5.96,
#   'close': 5.96},
#  {'time_open': '2012-02-05T00:00:00Z',
#   'time_close': '2012-02-05T23:59:59Z',
#   'open': 5.87,
#   'high': 5.87,
#   'low': 5.87,
#   'close': 5.87},
#  {'time_open': '2012-02-06T00:00:00Z',
#   'time_close': '2012-02-06T23:59:59Z',
#   'open': 5.69,
#   'high': 5.69,
#   'low': 5.69,
#   'close': 5.69},
#  {'time_open': '2012-02-07T00:00:00Z',
#   'time_close': '2012-02-07T23:59:59Z',
#   'open': 5.45,
#   'high': 5.45,
#   'low': 5.45,
#   'close': 5.45},
#  {'time_open': '2012-02-08T00:00:00Z',
#   'time_close': '2012-02-08T23:59:59Z',
#   'open': 5.69,
#   'high': 5.69,
#   'low': 5.69,
#   'close': 5.69},
#  {'time_open': '2012-02-09T00:00:00Z',
#   'time_close': '2012-02-09T23:59:59Z',
#   'open': 5.6,
#   'high': 5.6,
#   'low': 5.6,
#   'close': 5.6},
#  {'time_open': '2012-02-10T00:00:00Z',
#   'time_close': '2012-02-10T23:59:59Z',
#   'open': 5.83,
#   'high': 5.83,
#   'low': 5.83,
#   'close': 5.83},
#  {'time_open': '2012-02-11T00:00:00Z',
#   'time_close': '2012-02-11T23:59:59Z',
#   'open': 5.91,
#   'high': 5.91,
#   'low': 5.91,
#   'close': 5.91},
#  {'time_open': '2012-02-12T00:00:00Z',
#   'time_close': '2012-02-12T23:59:59Z',
#   'open': 5.6,
#   'high': 5.6,
#   'low': 5.6,
#   'close': 5.6},
#  {'time_open': '2012-02-13T00:00:00Z',
#   'time_close': '2012-02-13T23:59:59Z',
#   'open': 5.51,
#   'high': 5.51,
#   'low': 5.51,
#   'close': 5.51},
#  {'time_open': '2012-02-14T00:00:00Z',
#   'time_close': '2012-02-14T23:59:59Z',
#   'open': 5.26,
#   'high': 5.26,
#   'low': 5.26,
#   'close': 5.26},
#  {'time_open': '2012-02-15T00:00:00Z',
#   'time_close': '2012-02-15T23:59:59Z',
#   'open': 4.46,
#   'high': 4.46,
#   'low': 4.46,
#   'close': 4.46},
#  {'time_open': '2012-02-16T00:00:00Z',
#   'time_close': '2012-02-16T23:59:59Z',
#   'open': 4.33,
#   'high': 4.33,
#   'low': 4.33,
#   'close': 4.33},
#  {'time_open': '2012-02-17T00:00:00Z',
#   'time_close': '2012-02-17T23:59:59Z',
#   'open': 4.27,
#   'high': 4.27,
#   'low': 4.27,
#   'close': 4.27},
#  {'time_open': '2012-02-18T00:00:00Z',
#   'time_close': '2012-02-18T23:59:59Z',
#   'open': 4.41,
#   'high': 4.41,
#   'low': 4.41,
#   'close': 4.41},
#  {'time_open': '2012-02-19T00:00:00Z',
#   'time_close': '2012-02-19T23:59:59Z',
#   'open': 4.22,
#   'high': 4.22,
#   'low': 4.22,
#   'close': 4.22},
#  {'time_open': '2012-02-20T00:00:00Z',
#   'time_close': '2012-02-20T23:59:59Z',
#   'open': 4.39,
#   'high': 4.39,
#   'low': 4.39,
#   'close': 4.39},
#  {'time_open': '2012-02-21T00:00:00Z',
#   'time_close': '2012-02-21T23:59:59Z',
#   'open': 4.36,
#   'high': 4.36,
#   'low': 4.36,
#   'close': 4.36},
#  {'time_open': '2012-02-22T00:00:00Z',
#   'time_close': '2012-02-22T23:59:59Z',
#   'open': 4.27,
#   'high': 4.27,
#   'low': 4.27,
#   'close': 4.27},
#  {'time_open': '2012-02-23T00:00:00Z',
#   'time_close': '2012-02-23T23:59:59Z',
#   'open': 4.42,
#   'high': 4.42,
#   'low': 4.42,
#   'close': 4.42},
#  {'time_open': '2012-02-24T00:00:00Z',
#   'time_close': '2012-02-24T23:59:59Z',
#   'open': 5.01,
#   'high': 5.01,
#   'low': 5.01,
#   'close': 5.01},
#  {'time_open': '2012-02-25T00:00:00Z',
#   'time_close': '2012-02-25T23:59:59Z',
#   'open': 5.03,
#   'high': 5.03,
#   'low': 5.03,
#   'close': 5.03},
#  {'time_open': '2012-02-26T00:00:00Z',
#   'time_close': '2012-02-26T23:59:59Z',
#   'open': 4.77,
#   'high': 4.77,
#   'low': 4.77,
#   'close': 4.77},
#  {'time_open': '2012-02-27T00:00:00Z',
#   'time_close': '2012-02-27T23:59:59Z',
#   'open': 4.92,
#   'high': 4.92,
#   'low': 4.92,
#   'close': 4.92},
#  {'time_open': '2012-02-28T00:00:00Z',
#   'time_close': '2012-02-28T23:59:59Z',
#   'open': 4.96,
#   'high': 4.96,
#   'low': 4.96,
#   'close': 4.96},
#  {'time_open': '2012-02-29T00:00:00Z',
#   'time_close': '2012-02-29T23:59:59Z',
#   'open': 4.87,
#   'high': 4.87,
#   'low': 4.87,
#   'close': 4.87},
#  {'time_open': '2012-03-01T00:00:00Z',
#   'time_close': '2012-03-01T23:59:59Z',
#   'open': 4.86,
#   'high': 4.86,
#   'low': 4.86,
#   'close': 4.86},
#  {'time_open': '2012-03-02T00:00:00Z',
#   'time_close': '2012-03-02T23:59:59Z',
#   'open': 4.92,
#   'high': 4.92,
#   'low': 4.92,
#   'close': 4.92},
#  {'time_open': '2012-03-03T00:00:00Z',
#   'time_close': '2012-03-03T23:59:59Z',
#   'open': 4.7,
#   'high': 4.7,
#   'low': 4.7,
#   'close': 4.7},
#  {'time_open': '2012-03-04T00:00:00Z',
#   'time_close': '2012-03-04T23:59:59Z',
#   'open': 4.61,
#   'high': 4.61,
#   'low': 4.61,
#   'close': 4.61},
#  {'time_open': '2012-03-05T00:00:00Z',
#   'time_close': '2012-03-05T23:59:59Z',
#   'open': 4.82,
#   'high': 4.82,
#   'low': 4.82,
#   'close': 4.82},
#  {'time_open': '2012-03-06T00:00:00Z',
#   'time_close': '2012-03-06T23:59:59Z',
#   'open': 4.98,
#   'high': 4.98,
#   'low': 4.98,
#   'close': 4.98},
#  {'time_open': '2012-03-07T00:00:00Z',
#   'time_close': '2012-03-07T23:59:59Z',
#   'open': 4.99,
#   'high': 4.99,
#   'low': 4.99,
#   'close': 4.99},
#  {'time_open': '2012-03-08T00:00:00Z',
#   'time_close': '2012-03-08T23:59:59Z',
#   'open': 4.94,
#   'high': 4.94,
#   'low': 4.94,
#   'close': 4.94},
#  {'time_open': '2012-03-09T00:00:00Z',
#   'time_close': '2012-03-09T23:59:59Z',
#   'open': 4.93,
#   'high': 4.93,
#   'low': 4.93,
#   'close': 4.93},
#  {'time_open': '2012-03-10T00:00:00Z',
#   'time_close': '2012-03-10T23:59:59Z',
#   'open': 4.86,
#   'high': 4.86,
#   'low': 4.86,
#   'close': 4.86},
#  {'time_open': '2012-03-11T00:00:00Z',
#   'time_close': '2012-03-11T23:59:59Z',
#   'open': 4.83,
#   'high': 4.83,
#   'low': 4.83,
#   'close': 4.83},
#  {'time_open': '2012-03-12T00:00:00Z',
#   'time_close': '2012-03-12T23:59:59Z',
#   'open': 4.91,
#   'high': 4.91,
#   'low': 4.91,
#   'close': 4.91},
#  {'time_open': '2012-03-13T00:00:00Z',
#   'time_close': '2012-03-13T23:59:59Z',
#   'open': 4.89,
#   'high': 4.89,
#   'low': 4.89,
#   'close': 4.89},
#  {'time_open': '2012-03-14T00:00:00Z',
#   'time_close': '2012-03-14T23:59:59Z',
#   'open': 5.27,
#   'high': 5.27,
#   'low': 5.27,
#   'close': 5.27},
#  {'time_open': '2012-03-15T00:00:00Z',
#   'time_close': '2012-03-15T23:59:59Z',
#   'open': 5.38,
#   'high': 5.38,
#   'low': 5.38,
#   'close': 5.38},
#  {'time_open': '2012-03-16T00:00:00Z',
#   'time_close': '2012-03-16T23:59:59Z',
#   'open': 5.33,
#   'high': 5.33,
#   'low': 5.33,
#   'close': 5.33},
#  {'time_open': '2012-03-17T00:00:00Z',
#   'time_close': '2012-03-17T23:59:59Z',
#   'open': 5.34,
#   'high': 5.34,
#   'low': 5.34,
#   'close': 5.34},
#  {'time_open': '2012-03-18T00:00:00Z',
#   'time_close': '2012-03-18T23:59:59Z',
#   'open': 5.22,
#   'high': 5.22,
#   'low': 5.22,
#   'close': 5.22},
#  {'time_open': '2012-03-19T00:00:00Z',
#   'time_close': '2012-03-19T23:59:59Z',
#   'open': 5.28,
#   'high': 5.28,
#   'low': 5.28,
#   'close': 5.28},
#  {'time_open': '2012-03-20T00:00:00Z',
#   'time_close': '2012-03-20T23:59:59Z',
#   'open': 4.69,
#   'high': 4.69,
#   'low': 4.69,
#   'close': 4.69},
#  {'time_open': '2012-03-21T00:00:00Z',
#   'time_close': '2012-03-21T23:59:59Z',
#   'open': 4.84,
#   'high': 4.84,
#   'low': 4.84,
#   'close': 4.84},
#  {'time_open': '2012-03-22T00:00:00Z',
#   'time_close': '2012-03-22T23:59:59Z',
#   'open': 4.81,
#   'high': 4.81,
#   'low': 4.81,
#   'close': 4.81},
#  {'time_open': '2012-03-23T00:00:00Z',
#   'time_close': '2012-03-23T23:59:59Z',
#   'open': 4.7,
#   'high': 4.7,
#   'low': 4.7,
#   'close': 4.7},
#  {'time_open': '2012-03-24T00:00:00Z',
#   'time_close': '2012-03-24T23:59:59Z',
#   'open': 4.69,
#   'high': 4.69,
#   'low': 4.69,
#   'close': 4.69},
#  {'time_open': '2012-03-25T00:00:00Z',
#   'time_close': '2012-03-25T23:59:59Z',
#   'open': 4.68,
#   'high': 4.68,
#   'low': 4.68,
#   'close': 4.68},
#  {'time_open': '2012-03-26T00:00:00Z',
#   'time_close': '2012-03-26T23:59:59Z',
#   'open': 4.55,
#   'high': 4.55,
#   'low': 4.55,
#   'close': 4.55},
#  {'time_open': '2012-03-27T00:00:00Z',
#   'time_close': '2012-03-27T23:59:59Z',
#   'open': 4.62,
#   'high': 4.62,
#   'low': 4.62,
#   'close': 4.62},
#  {'time_open': '2012-03-28T00:00:00Z',
#   'time_close': '2012-03-28T23:59:59Z',
#   'open': 4.81,
#   'high': 4.81,
#   'low': 4.81,
#   'close': 4.81},
#  {'time_open': '2012-03-29T00:00:00Z',
#   'time_close': '2012-03-29T23:59:59Z',
#   'open': 4.79,
#   'high': 4.79,
#   'low': 4.79,
#   'close': 4.79},
#  {'time_open': '2012-03-30T00:00:00Z',
#   'time_close': '2012-03-30T23:59:59Z',
#   'open': 4.81,
#   'high': 4.81,
#   'low': 4.81,
#   'close': 4.81},
#  {'time_open': '2012-03-31T00:00:00Z',
#   'time_close': '2012-03-31T23:59:59Z',
#   'open': 4.86,
#   'high': 4.86,
#   'low': 4.86,
#   'close': 4.86},
#  {'time_open': '2012-04-01T00:00:00Z',
#   'time_close': '2012-04-01T23:59:59Z',
#   'open': 4.91,
#   'high': 4.91,
#   'low': 4.91,
#   'close': 4.91},
#  {'time_open': '2012-04-02T00:00:00Z',
#   'time_close': '2012-04-02T23:59:59Z',
#   'open': 4.83,
#   'high': 4.83,
#   'low': 4.83,
#   'close': 4.83},
#  {'time_open': '2012-04-03T00:00:00Z',
#   'time_close': '2012-04-03T23:59:59Z',
#   'open': 4.97,
#   'high': 4.97,
#   'low': 4.97,
#   'close': 4.97},
#  {'time_open': '2012-04-04T00:00:00Z',
#   'time_close': '2012-04-04T23:59:59Z',
#   'open': 4.95,
#   'high': 4.95,
#   'low': 4.95,
#   'close': 4.95},
#  {'time_open': '2012-04-05T00:00:00Z',
#   'time_close': '2012-04-05T23:59:59Z',
#   'open': 4.91,
#   'high': 4.91,
#   'low': 4.91,
#   'close': 4.91},
#  {'time_open': '2012-04-06T00:00:00Z',
#   'time_close': '2012-04-06T23:59:59Z',
#   'open': 4.92,
#   'high': 4.92,
#   'low': 4.92,
#   'close': 4.92},
#  {'time_open': '2012-04-07T00:00:00Z',
#   'time_close': '2012-04-07T23:59:59Z',
#   'open': 4.95,
#   'high': 4.95,
#   'low': 4.95,
#   'close': 4.95},
#  {'time_open': '2012-04-08T00:00:00Z',
#   'time_close': '2012-04-08T23:59:59Z',
#   'open': 4.69,
#   'high': 4.69,
#   'low': 4.69,
#   'close': 4.69},
#  {'time_open': '2012-04-09T00:00:00Z',
#   'time_close': '2012-04-09T23:59:59Z',
#   'open': 4.79,
#   'high': 4.79,
#   'low': 4.79,
#   'close': 4.79},
#  {'time_open': '2012-04-10T00:00:00Z',
#   'time_close': '2012-04-10T23:59:59Z',
#   'open': 4.87,
#   'high': 4.87,
#   'low': 4.87,
#   'close': 4.87},
#  {'time_open': '2012-04-11T00:00:00Z',
#   'time_close': '2012-04-11T23:59:59Z',
#   'open': 4.84,
#   'high': 4.84,
#   'low': 4.84,
#   'close': 4.84},
#  {'time_open': '2012-04-12T00:00:00Z',
#   'time_close': '2012-04-12T23:59:59Z',
#   'open': 4.93,
#   'high': 4.93,
#   'low': 4.93,
#   'close': 4.93},
#  {'time_open': '2012-04-13T00:00:00Z',
#   'time_close': '2012-04-13T23:59:59Z',
#   'open': 4.92,
#   'high': 4.92,
#   'low': 4.92,
#   'close': 4.92},
#  {'time_open': '2012-04-14T00:00:00Z',
#   'time_close': '2012-04-14T23:59:59Z',
#   'open': 4.94,
#   'high': 4.94,
#   'low': 4.94,
#   'close': 4.94},
#  {'time_open': '2012-04-15T00:00:00Z',
#   'time_close': '2012-04-15T23:59:59Z',
#   'open': 4.96,
#   'high': 4.96,
#   'low': 4.96,
#   'close': 4.96},
#  {'time_open': '2012-04-16T00:00:00Z',
#   'time_close': '2012-04-16T23:59:59Z',
#   'open': 4.97,
#   'high': 4.97,
#   'low': 4.97,
#   'close': 4.97},
#  {'time_open': '2012-04-17T00:00:00Z',
#   'time_close': '2012-04-17T23:59:59Z',
#   'open': 4.93,
#   'high': 4.93,
#   'low': 4.93,
#   'close': 4.93},
#  {'time_open': '2012-04-18T00:00:00Z',
#   'time_close': '2012-04-18T23:59:59Z',
#   'open': 4.98,
#   'high': 4.98,
#   'low': 4.98,
#   'close': 4.98},
#  {'time_open': '2012-04-19T00:00:00Z',
#   'time_close': '2012-04-19T23:59:59Z',
#   'open': 5.12,
#   'high': 5.12,
#   'low': 5.12,
#   'close': 5.12},
#  {'time_open': '2012-04-20T00:00:00Z',
#   'time_close': '2012-04-20T23:59:59Z',
#   'open': 5.14,
#   'high': 5.14,
#   'low': 5.14,
#   'close': 5.14},
#  {'time_open': '2012-04-21T00:00:00Z',
#   'time_close': '2012-04-21T23:59:59Z',
#   'open': 5.35,
#   'high': 5.35,
#   'low': 5.35,
#   'close': 5.35},
#  {'time_open': '2012-04-22T00:00:00Z',
#   'time_close': '2012-04-22T23:59:59Z',
#   'open': 5.26,
#   'high': 5.26,
#   'low': 5.26,
#   'close': 5.26},
#  {'time_open': '2012-04-23T00:00:00Z',
#   'time_close': '2012-04-23T23:59:59Z',
#   'open': 5.2,
#   'high': 5.2,
#   'low': 5.2,
#   'close': 5.2},
#  {'time_open': '2012-04-24T00:00:00Z',
#   'time_close': '2012-04-24T23:59:59Z',
#   'open': 4.96,
#   'high': 4.96,
#   'low': 4.96,
#   'close': 4.96},
#  {'time_open': '2012-04-25T00:00:00Z',
#   'time_close': '2012-04-25T23:59:59Z',
#   'open': 5.1,
#   'high': 5.1,
#   'low': 5.1,
#   'close': 5.1},
#  {'time_open': '2012-04-26T00:00:00Z',
#   'time_close': '2012-04-26T23:59:59Z',
#   'open': 5.13,
#   'high': 5.13,
#   'low': 5.13,
#   'close': 5.13},
#  {'time_open': '2012-04-27T00:00:00Z',
#   'time_close': '2012-04-27T23:59:59Z',
#   'open': 5.1,
#   'high': 5.1,
#   'low': 5.1,
#   'close': 5.1},
#  {'time_open': '2012-04-28T00:00:00Z',
#   'time_close': '2012-04-28T23:59:59Z',
#   'open': 5.11,
#   'high': 5.11,
#   'low': 5.11,
#   'close': 5.11},
#  {'time_open': '2012-04-29T00:00:00Z',
#   'time_close': '2012-04-29T23:59:59Z',
#   'open': 4.98,
#   'high': 4.98,
#   'low': 4.98,
#   'close': 4.98},
#  {'time_open': '2012-04-30T00:00:00Z',
#   'time_close': '2012-04-30T23:59:59Z',
#   'open': 4.9,
#   'high': 4.9,
#   'low': 4.9,
#   'close': 4.9},
#  {'time_open': '2012-05-01T00:00:00Z',
#   'time_close': '2012-05-01T23:59:59Z',
#   'open': 4.95,
#   'high': 4.95,
#   'low': 4.95,
#   'close': 4.95},
#  {'time_open': '2012-05-02T00:00:00Z',
#   'time_close': '2012-05-02T23:59:59Z',
#   'open': 5,
#   'high': 5,
#   'low': 5,
#   'close': 5},
#  {'time_open': '2012-05-03T00:00:00Z',
#   'time_close': '2012-05-03T23:59:59Z',
#   'open': 5.07,
#   'high': 5.07,
#   'low': 5.07,
#   'close': 5.07},
#  {'time_open': '2012-05-04T00:00:00Z',
#   'time_close': '2012-05-04T23:59:59Z',
#   'open': 5.13,
#   'high': 5.13,
#   'low': 5.13,
#   'close': 5.13},
#  {'time_open': '2012-05-05T00:00:00Z',
#   'time_close': '2012-05-05T23:59:59Z',
#   'open': 5.07,
#   'high': 5.07,
#   'low': 5.07,
#   'close': 5.07},
#  {'time_open': '2012-05-06T00:00:00Z',
#   'time_close': '2012-05-06T23:59:59Z',
#   'open': 5.08,
#   'high': 5.08,
#   'low': 5.08,
#   'close': 5.08},
#  {'time_open': '2012-05-07T00:00:00Z',
#   'time_close': '2012-05-07T23:59:59Z',
#   'open': 5.05,
#   'high': 5.05,
#   'low': 5.05,
#   'close': 5.05},
#  {'time_open': '2012-05-08T00:00:00Z',
#   'time_close': '2012-05-08T23:59:59Z',
#   'open': 5.06,
#   'high': 5.06,
#   'low': 5.06,
#   'close': 5.06},
#  {'time_open': '2012-05-09T00:00:00Z',
#   'time_close': '2012-05-09T23:59:59Z',
#   'open': 5.05,
#   'high': 5.05,
#   'low': 5.05,
#   'close': 5.05},
#  {'time_open': '2012-05-10T00:00:00Z',
#   'time_close': '2012-05-10T23:59:59Z',
#   'open': 5.04,
#   'high': 5.04,
#   'low': 5.04,
#   'close': 5.04},
#  {'time_open': '2012-05-11T00:00:00Z',
#   'time_close': '2012-05-11T23:59:59Z',
#   'open': 4.85,
#   'high': 4.85,
#   'low': 4.85,
#   'close': 4.85},
#  {'time_open': '2012-05-12T00:00:00Z',
#   'time_close': '2012-05-12T23:59:59Z',
#   'open': 4.96,
#   'high': 4.96,
#   'low': 4.96,
#   'close': 4.96},
#  {'time_open': '2012-05-13T00:00:00Z',
#   'time_close': '2012-05-13T23:59:59Z',
#   'open': 4.95,
#   'high': 4.95,
#   'low': 4.95,
#   'close': 4.95},
#  {'time_open': '2012-05-14T00:00:00Z',
#   'time_close': '2012-05-14T23:59:59Z',
#   'open': 4.93,
#   'high': 4.93,
#   'low': 4.93,
#   'close': 4.93},
#  {'time_open': '2012-05-15T00:00:00Z',
#   'time_close': '2012-05-15T23:59:59Z',
#   'open': 5.01,
#   'high': 5.01,
#   'low': 5.01,
#   'close': 5.01},
#  {'time_open': '2012-05-16T00:00:00Z',
#   'time_close': '2012-05-16T23:59:59Z',
#   'open': 5.04,
#   'high': 5.04,
#   'low': 5.04,
#   'close': 5.04},
#  {'time_open': '2012-05-17T00:00:00Z',
#   'time_close': '2012-05-17T23:59:59Z',
#   'open': 5.09,
#   'high': 5.09,
#   'low': 5.09,
#   'close': 5.09},
#  {'time_open': '2012-05-18T00:00:00Z',
#   'time_close': '2012-05-18T23:59:59Z',
#   'open': 5.1,
#   'high': 5.1,
#   'low': 5.1,
#   'close': 5.1},
#  {'time_open': '2012-05-19T00:00:00Z',
#   'time_close': '2012-05-19T23:59:59Z',
#   'open': 5.12,
#   'high': 5.12,
#   'low': 5.12,
#   'close': 5.12},
#  {'time_open': '2012-05-20T00:00:00Z',
#   'time_close': '2012-05-20T23:59:59Z',
#   'open': 5.1,
#   'high': 5.1,
#   'low': 5.1,
#   'close': 5.1},
#  {'time_open': '2012-05-21T00:00:00Z',
#   'time_close': '2012-05-21T23:59:59Z',
#   'open': 5.09,
#   'high': 5.09,
#   'low': 5.09,
#   'close': 5.09},
#  {'time_open': '2012-05-22T00:00:00Z',
#   'time_close': '2012-05-22T23:59:59Z',
#   'open': 5.1,
#   'high': 5.1,
#   'low': 5.1,
#   'close': 5.1},
#  {'time_open': '2012-05-23T00:00:00Z',
#   'time_close': '2012-05-23T23:59:59Z',
#   'open': 5.1,
#   'high': 5.1,
#   'low': 5.1,
#   'close': 5.1},
#  {'time_open': '2012-05-24T00:00:00Z',
#   'time_close': '2012-05-24T23:59:59Z',
#   'open': 5.14,
#   'high': 5.14,
#   'low': 5.14,
#   'close': 5.14},
#  {'time_open': '2012-05-25T00:00:00Z',
#   'time_close': '2012-05-25T23:59:59Z',
#   'open': 5.12,
#   'high': 5.12,
#   'low': 5.12,
#   'close': 5.12},
#  {'time_open': '2012-05-26T00:00:00Z',
#   'time_close': '2012-05-26T23:59:59Z',
#   'open': 5.15,
#   'high': 5.15,
#   'low': 5.15,
#   'close': 5.15},
#  {'time_open': '2012-05-27T00:00:00Z',
#   'time_close': '2012-05-27T23:59:59Z',
#   'open': 5.1,
#   'high': 5.1,
#   'low': 5.1,
#   'close': 5.1},
#  {'time_open': '2012-05-28T00:00:00Z',
#   'time_close': '2012-05-28T23:59:59Z',
#   'open': 5.14,
#   'high': 5.14,
#   'low': 5.14,
#   'close': 5.14},
#  {'time_open': '2012-05-29T00:00:00Z',
#   'time_close': '2012-05-29T23:59:59Z',
#   'open': 5.14,
#   'high': 5.14,
#   'low': 5.14,
#   'close': 5.14},
#  {'time_open': '2012-05-30T00:00:00Z',
#   'time_close': '2012-05-30T23:59:59Z',
#   'open': 5.15,
#   'high': 5.15,
#   'low': 5.15,
#   'close': 5.15},
#  {'time_open': '2012-05-31T00:00:00Z',
#   'time_close': '2012-05-31T23:59:59Z',
#   'open': 5.14,
#   'high': 5.14,
#   'low': 5.14,
#   'close': 5.14},
#  {'time_open': '2012-06-01T00:00:00Z',
#   'time_close': '2012-06-01T23:59:59Z',
#   'open': 5.18,
#   'high': 5.18,
#   'low': 5.18,
#   'close': 5.18},
#  {'time_open': '2012-06-02T00:00:00Z',
#   'time_close': '2012-06-02T23:59:59Z',
#   'open': 5.27,
#   'high': 5.27,
#   'low': 5.27,
#   'close': 5.27},
#  {'time_open': '2012-06-03T00:00:00Z',
#   'time_close': '2012-06-03T23:59:59Z',
#   'open': 5.25,
#   'high': 5.25,
#   'low': 5.25,
#   'close': 5.25},
#  {'time_open': '2012-06-04T00:00:00Z',
#   'time_close': '2012-06-04T23:59:59Z',
#   'open': 5.21,
#   'high': 5.21,
#   'low': 5.21,
#   'close': 5.21},
#  {'time_open': '2012-06-05T00:00:00Z',
#   'time_close': '2012-06-05T23:59:59Z',
#   'open': 5.27,
#   'high': 5.27,
#   'low': 5.27,
#   'close': 5.27},
#  {'time_open': '2012-06-06T00:00:00Z',
#   'time_close': '2012-06-06T23:59:59Z',
#   'open': 5.44,
#   'high': 5.44,
#   'low': 5.44,
#   'close': 5.44},
#  {'time_open': '2012-06-07T00:00:00Z',
#   'time_close': '2012-06-07T23:59:59Z',
#   'open': 5.46,
#   'high': 5.46,
#   'low': 5.46,
#   'close': 5.46},
#  {'time_open': '2012-06-08T00:00:00Z',
#   'time_close': '2012-06-08T23:59:59Z',
#   'open': 5.59,
#   'high': 5.59,
#   'low': 5.59,
#   'close': 5.59},
#  {'time_open': '2012-06-09T00:00:00Z',
#   'time_close': '2012-06-09T23:59:59Z',
#   'open': 5.63,
#   'high': 5.63,
#   'low': 5.63,
#   'close': 5.63},
#  {'time_open': '2012-06-10T00:00:00Z',
#   'time_close': '2012-06-10T23:59:59Z',
#   'open': 5.56,
#   'high': 5.56,
#   'low': 5.56,
#   'close': 5.56},
#  {'time_open': '2012-06-11T00:00:00Z',
#   'time_close': '2012-06-11T23:59:59Z',
#   'open': 5.47,
#   'high': 5.47,
#   'low': 5.47,
#   'close': 5.47},
#  {'time_open': '2012-06-12T00:00:00Z',
#   'time_close': '2012-06-12T23:59:59Z',
#   'open': 5.57,
#   'high': 5.57,
#   'low': 5.57,
#   'close': 5.57},
#  {'time_open': '2012-06-13T00:00:00Z',
#   'time_close': '2012-06-13T23:59:59Z',
#   'open': 5.7,
#   'high': 5.7,
#   'low': 5.7,
#   'close': 5.7},
#  {'time_open': '2012-06-14T00:00:00Z',
#   'time_close': '2012-06-14T23:59:59Z',
#   'open': 5.93,
#   'high': 5.93,
#   'low': 5.93,
#   'close': 5.93},
#  {'time_open': '2012-06-15T00:00:00Z',
#   'time_close': '2012-06-15T23:59:59Z',
#   'open': 5.95,
#   'high': 5.95,
#   'low': 5.95,
#   'close': 5.95},
#  {'time_open': '2012-06-16T00:00:00Z',
#   'time_close': '2012-06-16T23:59:59Z',
#   'open': 6.5,
#   'high': 6.5,
#   'low': 6.5,
#   'close': 6.5},
#  {'time_open': '2012-06-17T00:00:00Z',
#   'time_close': '2012-06-17T23:59:59Z',
#   'open': 6.4,
#   'high': 6.4,
#   'low': 6.4,
#   'close': 6.4},
#  {'time_open': '2012-06-18T00:00:00Z',
#   'time_close': '2012-06-18T23:59:59Z',
#   'open': 6.16,
#   'high': 6.16,
#   'low': 6.16,
#   'close': 6.16},
#  {'time_open': '2012-06-19T00:00:00Z',
#   'time_close': '2012-06-19T23:59:59Z',
#   'open': 6.31,
#   'high': 6.31,
#   'low': 6.31,
#   'close': 6.31},
#  {'time_open': '2012-06-20T00:00:00Z',
#   'time_close': '2012-06-20T23:59:59Z',
#   'open': 6.5,
#   'high': 6.5,
#   'low': 6.5,
#   'close': 6.5},
#  {'time_open': '2012-06-21T00:00:00Z',
#   'time_close': '2012-06-21T23:59:59Z',
#   'open': 6.67,
#   'high': 6.67,
#   'low': 6.67,
#   'close': 6.67},
#  {'time_open': '2012-06-22T00:00:00Z',
#   'time_close': '2012-06-22T23:59:59Z',
#   'open': 6.68,
#   'high': 6.68,
#   'low': 6.68,
#   'close': 6.68},
#  {'time_open': '2012-06-23T00:00:00Z',
#   'time_close': '2012-06-23T23:59:59Z',
#   'open': 6.55,
#   'high': 6.55,
#   'low': 6.55,
#   'close': 6.55},
#  {'time_open': '2012-06-24T00:00:00Z',
#   'time_close': '2012-06-24T23:59:59Z',
#   'open': 6.43,
#   'high': 6.43,
#   'low': 6.43,
#   'close': 6.43},
#  {'time_open': '2012-06-25T00:00:00Z',
#   'time_close': '2012-06-25T23:59:59Z',
#   'open': 6.35,
#   'high': 6.35,
#   'low': 6.35,
#   'close': 6.35},
#  {'time_open': '2012-06-26T00:00:00Z',
#   'time_close': '2012-06-26T23:59:59Z',
#   'open': 6.3,
#   'high': 6.3,
#   'low': 6.3,
#   'close': 6.3},
#  {'time_open': '2012-06-27T00:00:00Z',
#   'time_close': '2012-06-27T23:59:59Z',
#   'open': 6.42,
#   'high': 6.42,
#   'low': 6.42,
#   'close': 6.42},
#  {'time_open': '2012-06-28T00:00:00Z',
#   'time_close': '2012-06-28T23:59:59Z',
#   'open': 6.65,
#   'high': 6.65,
#   'low': 6.65,
#   'close': 6.65},
#  {'time_open': '2012-06-29T00:00:00Z',
#   'time_close': '2012-06-29T23:59:59Z',
#   'open': 6.61,
#   'high': 6.61,
#   'low': 6.61,
#   'close': 6.61},
#  {'time_open': '2012-06-30T00:00:00Z',
#   'time_close': '2012-06-30T23:59:59Z',
#   'open': 6.65,
#   'high': 6.65,
#   'low': 6.65,
#   'close': 6.65},
#  {'time_open': '2012-07-01T00:00:00Z',
#   'time_close': '2012-07-01T23:59:59Z',
#   'open': 6.69,
#   'high': 6.69,
#   'low': 6.69,
#   'close': 6.69},
#  {'time_open': '2012-07-02T00:00:00Z',
#   'time_close': '2012-07-02T23:59:59Z',
#   'open': 6.63,
#   'high': 6.63,
#   'low': 6.63,
#   'close': 6.63},
#  {'time_open': '2012-07-03T00:00:00Z',
#   'time_close': '2012-07-03T23:59:59Z',
#   'open': 6.76,
#   'high': 6.76,
#   'low': 6.76,
#   'close': 6.76},
#  {'time_open': '2012-07-04T00:00:00Z',
#   'time_close': '2012-07-04T23:59:59Z',
#   'open': 6.45,
#   'high': 6.45,
#   'low': 6.45,
#   'close': 6.45},
#  {'time_open': '2012-07-05T00:00:00Z',
#   'time_close': '2012-07-05T23:59:59Z',
#   'open': 6.51,
#   'high': 6.51,
#   'low': 6.51,
#   'close': 6.51},
#  {'time_open': '2012-07-06T00:00:00Z',
#   'time_close': '2012-07-06T23:59:59Z',
#   'open': 6.67,
#   'high': 6.67,
#   'low': 6.67,
#   'close': 6.67},
#  {'time_open': '2012-07-07T00:00:00Z',
#   'time_close': '2012-07-07T23:59:59Z',
#   'open': 6.65,
#   'high': 6.65,
#   'low': 6.65,
#   'close': 6.65},
#  {'time_open': '2012-07-08T00:00:00Z',
#   'time_close': '2012-07-08T23:59:59Z',
#   'open': 6.76,
#   'high': 6.76,
#   'low': 6.76,
#   'close': 6.76},
#  {'time_open': '2012-07-09T00:00:00Z',
#   'time_close': '2012-07-09T23:59:59Z',
#   'open': 6.8,
#   'high': 6.8,
#   'low': 6.8,
#   'close': 6.8},
#  {'time_open': '2012-07-10T00:00:00Z',
#   'time_close': '2012-07-10T23:59:59Z',
#   'open': 7.02,
#   'high': 7.02,
#   'low': 7.02,
#   'close': 7.02},
#  {'time_open': '2012-07-11T00:00:00Z',
#   'time_close': '2012-07-11T23:59:59Z',
#   'open': 7.2,
#   'high': 7.2,
#   'low': 7.2,
#   'close': 7.2},
#  {'time_open': '2012-07-12T00:00:00Z',
#   'time_close': '2012-07-12T23:59:59Z',
#   'open': 7.15,
#   'high': 7.15,
#   'low': 7.15,
#   'close': 7.15},
#  {'time_open': '2012-07-13T00:00:00Z',
#   'time_close': '2012-07-13T23:59:59Z',
#   'open': 7.76,
#   'high': 7.76,
#   'low': 7.76,
#   'close': 7.76},
#  {'time_open': '2012-07-14T00:00:00Z',
#   'time_close': '2012-07-14T23:59:59Z',
#   'open': 7.67,
#   'high': 7.67,
#   'low': 7.67,
#   'close': 7.67},
#  {'time_open': '2012-07-15T00:00:00Z',
#   'time_close': '2012-07-15T23:59:59Z',
#   'open': 7.54,
#   'high': 7.54,
#   'low': 7.54,
#   'close': 7.54},
#  {'time_open': '2012-07-16T00:00:00Z',
#   'time_close': '2012-07-16T23:59:59Z',
#   'open': 7.62,
#   'high': 7.62,
#   'low': 7.62,
#   'close': 7.62},
#  {'time_open': '2012-07-17T00:00:00Z',
#   'time_close': '2012-07-17T23:59:59Z',
#   'open': 8.5,
#   'high': 8.5,
#   'low': 8.5,
#   'close': 8.5},
#  {'time_open': '2012-07-18T00:00:00Z',
#   'time_close': '2012-07-18T23:59:59Z',
#   'open': 8.8,
#   'high': 8.8,
#   'low': 8.8,
#   'close': 8.8},
#  {'time_open': '2012-07-19T00:00:00Z',
#   'time_close': '2012-07-19T23:59:59Z',
#   'open': 9.11,
#   'high': 9.11,
#   'low': 9.11,
#   'close': 9.11},
#  {'time_open': '2012-07-20T00:00:00Z',
#   'time_close': '2012-07-20T23:59:59Z',
#   'open': 8.87,
#   'high': 8.87,
#   'low': 8.87,
#   'close': 8.87},
#  {'time_open': '2012-07-21T00:00:00Z',
#   'time_close': '2012-07-21T23:59:59Z',
#   'open': 8.52,
#   'high': 8.52,
#   'low': 8.52,
#   'close': 8.52},
#  {'time_open': '2012-07-22T00:00:00Z',
#   'time_close': '2012-07-22T23:59:59Z',
#   'open': 8.85,
#   'high': 8.85,
#   'low': 8.85,
#   'close': 8.85},
#  {'time_open': '2012-07-23T00:00:00Z',
#   'time_close': '2012-07-23T23:59:59Z',
#   'open': 8.41,
#   'high': 8.41,
#   'low': 8.41,
#   'close': 8.41},
#  {'time_open': '2012-07-24T00:00:00Z',
#   'time_close': '2012-07-24T23:59:59Z',
#   'open': 8.45,
#   'high': 8.45,
#   'low': 8.45,
#   'close': 8.45},
#  {'time_open': '2012-07-25T00:00:00Z',
#   'time_close': '2012-07-25T23:59:59Z',
#   'open': 8.6,
#   'high': 8.6,
#   'low': 8.6,
#   'close': 8.6},
#  {'time_open': '2012-07-26T00:00:00Z',
#   'time_close': '2012-07-26T23:59:59Z',
#   'open': 8.8,
#   'high': 8.8,
#   'low': 8.8,
#   'close': 8.8},
#  {'time_open': '2012-07-27T00:00:00Z',
#   'time_close': '2012-07-27T23:59:59Z',
#   'open': 8.9,
#   'high': 8.9,
#   'low': 8.9,
#   'close': 8.9},
#  {'time_open': '2012-07-28T00:00:00Z',
#   'time_close': '2012-07-28T23:59:59Z',
#   'open': 8.9,
#   'high': 8.9,
#   'low': 8.9,
#   'close': 8.9},
#  {'time_open': '2012-07-29T00:00:00Z',
#   'time_close': '2012-07-29T23:59:59Z',
#   'open': 8.89,
#   'high': 8.89,
#   'low': 8.89,
#   'close': 8.89},
#  {'time_open': '2012-07-30T00:00:00Z',
#   'time_close': '2012-07-30T23:59:59Z',
#   'open': 8.71,
#   'high': 8.71,
#   'low': 8.71,
#   'close': 8.71},
#  {'time_open': '2012-07-31T00:00:00Z',
#   'time_close': '2012-07-31T23:59:59Z',
#   'open': 9.1,
#   'high': 9.1,
#   'low': 9.1,
#   'close': 9.1},
#  {'time_open': '2012-08-01T00:00:00Z',
#   'time_close': '2012-08-01T23:59:59Z',
#   'open': 9.35,
#   'high': 9.35,
#   'low': 9.35,
#   'close': 9.35},
#  {'time_open': '2012-08-02T00:00:00Z',
#   'time_close': '2012-08-02T23:59:59Z',
#   'open': 9.55,
#   'high': 9.55,
#   'low': 9.55,
#   'close': 9.55},
#  {'time_open': '2012-08-03T00:00:00Z',
#   'time_close': '2012-08-03T23:59:59Z',
#   'open': 10.53,
#   'high': 10.53,
#   'low': 10.53,
#   'close': 10.53},
#  {'time_open': '2012-08-04T00:00:00Z',
#   'time_close': '2012-08-04T23:59:59Z',
#   'open': 10.97,
#   'high': 10.97,
#   'low': 10.97,
#   'close': 10.97},
#  {'time_open': '2012-08-05T00:00:00Z',
#   'time_close': '2012-08-05T23:59:59Z',
#   'open': 10.98,
#   'high': 10.98,
#   'low': 10.98,
#   'close': 10.98},
#  {'time_open': '2012-08-06T00:00:00Z',
#   'time_close': '2012-08-06T23:59:59Z',
#   'open': 10.87,
#   'high': 10.87,
#   'low': 10.87,
#   'close': 10.87},
#  {'time_open': '2012-08-07T00:00:00Z',
#   'time_close': '2012-08-07T23:59:59Z',
#   'open': 10.86,
#   'high': 10.86,
#   'low': 10.86,
#   'close': 10.86},
#  {'time_open': '2012-08-08T00:00:00Z',
#   'time_close': '2012-08-08T23:59:59Z',
#   'open': 11.1,
#   'high': 11.1,
#   'low': 11.1,
#   'close': 11.1},
#  {'time_open': '2012-08-09T00:00:00Z',
#   'time_close': '2012-08-09T23:59:59Z',
#   'open': 11.06,
#   'high': 11.06,
#   'low': 11.06,
#   'close': 11.06},
#  {'time_open': '2012-08-10T00:00:00Z',
#   'time_close': '2012-08-10T23:59:59Z',
#   'open': 11.06,
#   'high': 11.06,
#   'low': 11.06,
#   'close': 11.06},
#  {'time_open': '2012-08-11T00:00:00Z',
#   'time_close': '2012-08-11T23:59:59Z',
#   'open': 11.39,
#   'high': 11.39,
#   'low': 11.39,
#   'close': 11.39},
#  {'time_open': '2012-08-12T00:00:00Z',
#   'time_close': '2012-08-12T23:59:59Z',
#   'open': 11.51,
#   'high': 11.51,
#   'low': 11.51,
#   'close': 11.51},
#  {'time_open': '2012-08-13T00:00:00Z',
#   'time_close': '2012-08-13T23:59:59Z',
#   'open': 11.62,
#   'high': 11.62,
#   'low': 11.62,
#   'close': 11.62},
#  {'time_open': '2012-08-14T00:00:00Z',
#   'time_close': '2012-08-14T23:59:59Z',
#   'open': 12.04,
#   'high': 12.04,
#   'low': 12.04,
#   'close': 12.04},
#  {'time_open': '2012-08-15T00:00:00Z',
#   'time_close': '2012-08-15T23:59:59Z',
#   'open': 12.19,
#   'high': 12.19,
#   'low': 12.19,
#   'close': 12.19},
#  {'time_open': '2012-08-16T00:00:00Z',
#   'time_close': '2012-08-16T23:59:59Z',
#   'open': 13.25,
#   'high': 13.25,
#   'low': 13.25,
#   'close': 13.25},
#  {'time_open': '2012-08-17T00:00:00Z',
#   'time_close': '2012-08-17T23:59:59Z',
#   'open': 13.5,
#   'high': 13.5,
#   'low': 13.5,
#   'close': 13.5},
#  {'time_open': '2012-08-18T00:00:00Z',
#   'time_close': '2012-08-18T23:59:59Z',
#   'open': 11.58,
#   'high': 11.58,
#   'low': 11.58,
#   'close': 11.58},
#  {'time_open': '2012-08-19T00:00:00Z',
#   'time_close': '2012-08-19T23:59:59Z',
#   'open': 11.61,
#   'high': 11.61,
#   'low': 11.61,
#   'close': 11.61},
#  {'time_open': '2012-08-20T00:00:00Z',
#   'time_close': '2012-08-20T23:59:59Z',
#   'open': 8,
#   'high': 8,
#   'low': 8,
#   'close': 8},
#  {'time_open': '2012-08-21T00:00:00Z',
#   'time_close': '2012-08-21T23:59:59Z',
#   'open': 10.1,
#   'high': 10.1,
#   'low': 10.1,
#   'close': 10.1},
#  {'time_open': '2012-08-22T00:00:00Z',
#   'time_close': '2012-08-22T23:59:59Z',
#   'open': 9.92,
#   'high': 9.92,
#   'low': 9.92,
#   'close': 9.92},
#  {'time_open': '2012-08-23T00:00:00Z',
#   'time_close': '2012-08-23T23:59:59Z',
#   'open': 9.81,
#   'high': 9.81,
#   'low': 9.81,
#   'close': 9.81},
#  {'time_open': '2012-08-24T00:00:00Z',
#   'time_close': '2012-08-24T23:59:59Z',
#   'open': 10.1,
#   'high': 10.1,
#   'low': 10.1,
#   'close': 10.1},
#  {'time_open': '2012-08-25T00:00:00Z',
#   'time_close': '2012-08-25T23:59:59Z',
#   'open': 10.6,
#   'high': 10.6,
#   'low': 10.6,
#   'close': 10.6},
#  {'time_open': '2012-08-26T00:00:00Z',
#   'time_close': '2012-08-26T23:59:59Z',
#   'open': 10.52,
#   'high': 10.52,
#   'low': 10.52,
#   'close': 10.52},
#  {'time_open': '2012-08-27T00:00:00Z',
#   'time_close': '2012-08-27T23:59:59Z',
#   'open': 10.61,
#   'high': 10.61,
#   'low': 10.61,
#   'close': 10.61},
#  {'time_open': '2012-08-28T00:00:00Z',
#   'time_close': '2012-08-28T23:59:59Z',
#   'open': 10.95,
#   'high': 10.95,
#   'low': 10.95,
#   'close': 10.95},
#  {'time_open': '2012-08-29T00:00:00Z',
#   'time_close': '2012-08-29T23:59:59Z',
#   'open': 10.94,
#   'high': 10.94,
#   'low': 10.94,
#   'close': 10.94},
#  {'time_open': '2012-08-30T00:00:00Z',
#   'time_close': '2012-08-30T23:59:59Z',
#   'open': 10.92,
#   'high': 10.92,
#   'low': 10.92,
#   'close': 10.92},
#  {'time_open': '2012-08-31T00:00:00Z',
#   'time_close': '2012-08-31T23:59:59Z',
#   'open': 10.78,
#   'high': 10.78,
#   'low': 10.78,
#   'close': 10.78},
#  {'time_open': '2012-09-01T00:00:00Z',
#   'time_close': '2012-09-01T23:59:59Z',
#   'open': 10.16,
#   'high': 10.16,
#   'low': 10.16,
#   'close': 10.16},
#  {'time_open': '2012-09-02T00:00:00Z',
#   'time_close': '2012-09-02T23:59:59Z',
#   'open': 9.97,
#   'high': 9.97,
#   'low': 9.97,
#   'close': 9.97},
#  {'time_open': '2012-09-03T00:00:00Z',
#   'time_close': '2012-09-03T23:59:59Z',
#   'open': 10.2,
#   'high': 10.2,
#   'low': 10.2,
#   'close': 10.2},
#  {'time_open': '2012-09-04T00:00:00Z',
#   'time_close': '2012-09-04T23:59:59Z',
#   'open': 10.53,
#   'high': 10.53,
#   'low': 10.53,
#   'close': 10.53},
#  {'time_open': '2012-09-05T00:00:00Z',
#   'time_close': '2012-09-05T23:59:59Z',
#   'open': 10.38,
#   'high': 10.38,
#   'low': 10.38,
#   'close': 10.38},
#  {'time_open': '2012-09-06T00:00:00Z',
#   'time_close': '2012-09-06T23:59:59Z',
#   'open': 11,
#   'high': 11,
#   'low': 11,
#   'close': 11},
#  {'time_open': '2012-09-07T00:00:00Z',
#   'time_close': '2012-09-07T23:59:59Z',
#   'open': 11.18,
#   'high': 11.18,
#   'low': 11.18,
#   'close': 11.18},
#  {'time_open': '2012-09-08T00:00:00Z',
#   'time_close': '2012-09-08T23:59:59Z',
#   'open': 11,
#   'high': 11,
#   'low': 11,
#   'close': 11},
#  {'time_open': '2012-09-09T00:00:00Z',
#   'time_close': '2012-09-09T23:59:59Z',
#   'open': 11.04,
#   'high': 11.04,
#   'low': 11.04,
#   'close': 11.04},
#  {'time_open': '2012-09-10T00:00:00Z',
#   'time_close': '2012-09-10T23:59:59Z',
#   'open': 11.02,
#   'high': 11.02,
#   'low': 11.02,
#   'close': 11.02},
#  {'time_open': '2012-09-11T00:00:00Z',
#   'time_close': '2012-09-11T23:59:59Z',
#   'open': 11.17,
#   'high': 11.17,
#   'low': 11.17,
#   'close': 11.17},
#  {'time_open': '2012-09-12T00:00:00Z',
#   'time_close': '2012-09-12T23:59:59Z',
#   'open': 11.33,
#   'high': 11.33,
#   'low': 11.33,
#   'close': 11.33},
#  {'time_open': '2012-09-13T00:00:00Z',
#   'time_close': '2012-09-13T23:59:59Z',
#   'open': 11.36,
#   'high': 11.36,
#   'low': 11.36,
#   'close': 11.36},
#  {'time_open': '2012-09-14T00:00:00Z',
#   'time_close': '2012-09-14T23:59:59Z',
#   'open': 11.4,
#   'high': 11.4,
#   'low': 11.4,
#   'close': 11.4},
#  {'time_open': '2012-09-15T00:00:00Z',
#   'time_close': '2012-09-15T23:59:59Z',
#   'open': 11.67,
#   'high': 11.67,
#   'low': 11.67,
#   'close': 11.67},
#  {'time_open': '2012-09-16T00:00:00Z',
#   'time_close': '2012-09-16T23:59:59Z',
#   'open': 11.75,
#   'high': 11.75,
#   'low': 11.75,
#   'close': 11.75},
#  {'time_open': '2012-09-17T00:00:00Z',
#   'time_close': '2012-09-17T23:59:59Z',
#   'open': 11.87,
#   'high': 11.87,
#   'low': 11.87,
#   'close': 11.87},
#  {'time_open': '2012-09-18T00:00:00Z',
#   'time_close': '2012-09-18T23:59:59Z',
#   'open': 11.89,
#   'high': 11.89,
#   'low': 11.89,
#   'close': 11.89},
#  {'time_open': '2012-09-19T00:00:00Z',
#   'time_close': '2012-09-19T23:59:59Z',
#   'open': 12.25,
#   'high': 12.25,
#   'low': 12.25,
#   'close': 12.25},
#  {'time_open': '2012-09-20T00:00:00Z',
#   'time_close': '2012-09-20T23:59:59Z',
#   'open': 12.57,
#   'high': 12.57,
#   'low': 12.57,
#   'close': 12.57},
#  {'time_open': '2012-09-21T00:00:00Z',
#   'time_close': '2012-09-21T23:59:59Z',
#   'open': 12.28,
#   'high': 12.28,
#   'low': 12.28,
#   'close': 12.28},
#  {'time_open': '2012-09-22T00:00:00Z',
#   'time_close': '2012-09-22T23:59:59Z',
#   'open': 12.37,
#   'high': 12.37,
#   'low': 12.37,
#   'close': 12.37},
#  {'time_open': '2012-09-23T00:00:00Z',
#   'time_close': '2012-09-23T23:59:59Z',
#   'open': 12.24,
#   'high': 12.24,
#   'low': 12.24,
#   'close': 12.24},
#  {'time_open': '2012-09-24T00:00:00Z',
#   'time_close': '2012-09-24T23:59:59Z',
#   'open': 12.19,
#   'high': 12.19,
#   'low': 12.19,
#   'close': 12.19},
#  {'time_open': '2012-09-25T00:00:00Z',
#   'time_close': '2012-09-25T23:59:59Z',
#   'open': 12.1,
#   'high': 12.1,
#   'low': 12.1,
#   'close': 12.1},
#  {'time_open': '2012-09-26T00:00:00Z',
#   'time_close': '2012-09-26T23:59:59Z',
#   'open': 12.2,
#   'high': 12.2,
#   'low': 12.2,
#   'close': 12.2},
#  {'time_open': '2012-09-27T00:00:00Z',
#   'time_close': '2012-09-27T23:59:59Z',
#   'open': 12.27,
#   'high': 12.27,
#   'low': 12.27,
#   'close': 12.27},
#  {'time_open': '2012-09-28T00:00:00Z',
#   'time_close': '2012-09-28T23:59:59Z',
#   'open': 12.31,
#   'high': 12.31,
#   'low': 12.31,
#   'close': 12.31},
#  {'time_open': '2012-09-29T00:00:00Z',
#   'time_close': '2012-09-29T23:59:59Z',
#   'open': 12.39,
#   'high': 12.39,
#   'low': 12.39,
#   'close': 12.39},
#  {'time_open': '2012-09-30T00:00:00Z',
#   'time_close': '2012-09-30T23:59:59Z',
#   'open': 12.36,
#   'high': 12.36,
#   'low': 12.36,
#   'close': 12.36},
#  {'time_open': '2012-10-01T00:00:00Z',
#   'time_close': '2012-10-01T23:59:59Z',
#   'open': 12.4,
#   'high': 12.4,
#   'low': 12.4,
#   'close': 12.4},
#  {'time_open': '2012-10-02T00:00:00Z',
#   'time_close': '2012-10-02T23:59:59Z',
#   'open': 12.4,
#   'high': 12.4,
#   'low': 12.4,
#   'close': 12.4},
#  {'time_open': '2012-10-03T00:00:00Z',
#   'time_close': '2012-10-03T23:59:59Z',
#   'open': 12.84,
#   'high': 12.84,
#   'low': 12.84,
#   'close': 12.84},
#  {'time_open': '2012-10-04T00:00:00Z',
#   'time_close': '2012-10-04T23:59:59Z',
#   'open': 12.89,
#   'high': 12.89,
#   'low': 12.89,
#   'close': 12.89},
#  {'time_open': '2012-10-05T00:00:00Z',
#   'time_close': '2012-10-05T23:59:59Z',
#   'open': 12.85,
#   'high': 12.85,
#   'low': 12.85,
#   'close': 12.85},
#  {'time_open': '2012-10-06T00:00:00Z',
#   'time_close': '2012-10-06T23:59:59Z',
#   'open': 12.69,
#   'high': 12.69,
#   'low': 12.69,
#   'close': 12.69},
#  {'time_open': '2012-10-07T00:00:00Z',
#   'time_close': '2012-10-07T23:59:59Z',
#   'open': 12.51,
#   'high': 12.51,
#   'low': 12.51,
#   'close': 12.51},
#  {'time_open': '2012-10-08T00:00:00Z',
#   'time_close': '2012-10-08T23:59:59Z',
#   'open': 11.8,
#   'high': 11.8,
#   'low': 11.8,
#   'close': 11.8},
#  {'time_open': '2012-10-09T00:00:00Z',
#   'time_close': '2012-10-09T23:59:59Z',
#   'open': 11.78,
#   'high': 11.78,
#   'low': 11.78,
#   'close': 11.78},
#  {'time_open': '2012-10-10T00:00:00Z',
#   'time_close': '2012-10-10T23:59:59Z',
#   'open': 11.9,
#   'high': 11.9,
#   'low': 11.9,
#   'close': 11.9},
#  {'time_open': '2012-10-11T00:00:00Z',
#   'time_close': '2012-10-11T23:59:59Z',
#   'open': 12.12,
#   'high': 12.12,
#   'low': 12.12,
#   'close': 12.12},
#  {'time_open': '2012-10-12T00:00:00Z',
#   'time_close': '2012-10-12T23:59:59Z',
#   'open': 12.03,
#   'high': 12.03,
#   'low': 12.03,
#   'close': 12.03},
#  {'time_open': '2012-10-13T00:00:00Z',
#   'time_close': '2012-10-13T23:59:59Z',
#   'open': 12,
#   'high': 12,
#   'low': 12,
#   'close': 12},
#  {'time_open': '2012-10-14T00:00:00Z',
#   'time_close': '2012-10-14T23:59:59Z',
#   'open': 11.86,
#   'high': 11.86,
#   'low': 11.86,
#   'close': 11.86},
#  {'time_open': '2012-10-15T00:00:00Z',
#   'time_close': '2012-10-15T23:59:59Z',
#   'open': 11.74,
#   'high': 11.74,
#   'low': 11.74,
#   'close': 11.74},
#  {'time_open': '2012-10-16T00:00:00Z',
#   'time_close': '2012-10-16T23:59:59Z',
#   'open': 11.84,
#   'high': 11.84,
#   'low': 11.84,
#   'close': 11.84},
#  {'time_open': '2012-10-17T00:00:00Z',
#   'time_close': '2012-10-17T23:59:59Z',
#   'open': 11.85,
#   'high': 11.85,
#   'low': 11.85,
#   'close': 11.85},
#  {'time_open': '2012-10-18T00:00:00Z',
#   'time_close': '2012-10-18T23:59:59Z',
#   'open': 11.81,
#   'high': 11.81,
#   'low': 11.81,
#   'close': 11.81},
#  {'time_open': '2012-10-19T00:00:00Z',
#   'time_close': '2012-10-19T23:59:59Z',
#   'open': 11.94,
#   'high': 11.94,
#   'low': 11.94,
#   'close': 11.94},
#  {'time_open': '2012-10-20T00:00:00Z',
#   'time_close': '2012-10-20T23:59:59Z',
#   'open': 11.74,
#   'high': 11.74,
#   'low': 11.74,
#   'close': 11.74},
#  {'time_open': '2012-10-21T00:00:00Z',
#   'time_close': '2012-10-21T23:59:59Z',
#   'open': 11.74,
#   'high': 11.74,
#   'low': 11.74,
#   'close': 11.74},
#  {'time_open': '2012-10-22T00:00:00Z',
#   'time_close': '2012-10-22T23:59:59Z',
#   'open': 11.63,
#   'high': 11.63,
#   'low': 11.63,
#   'close': 11.63},
#  {'time_open': '2012-10-23T00:00:00Z',
#   'time_close': '2012-10-23T23:59:59Z',
#   'open': 11.71,
#   'high': 11.71,
#   'low': 11.71,
#   'close': 11.71},
#  {'time_open': '2012-10-24T00:00:00Z',
#   'time_close': '2012-10-24T23:59:59Z',
#   'open': 11.65,
#   'high': 11.65,
#   'low': 11.65,
#   'close': 11.65},
#  {'time_open': '2012-10-25T00:00:00Z',
#   'time_close': '2012-10-25T23:59:59Z',
#   'open': 11.65,
#   'high': 11.65,
#   'low': 11.65,
#   'close': 11.65},
#  {'time_open': '2012-10-26T00:00:00Z',
#   'time_close': '2012-10-26T23:59:59Z',
#   'open': 10.86,
#   'high': 10.86,
#   'low': 10.86,
#   'close': 10.86},
#  {'time_open': '2012-10-27T00:00:00Z',
#   'time_close': '2012-10-27T23:59:59Z',
#   'open': 10.17,
#   'high': 10.17,
#   'low': 10.17,
#   'close': 10.17},
#  {'time_open': '2012-10-28T00:00:00Z',
#   'time_close': '2012-10-28T23:59:59Z',
#   'open': 10.26,
#   'high': 10.26,
#   'low': 10.26,
#   'close': 10.26},
#  {'time_open': '2012-10-29T00:00:00Z',
#   'time_close': '2012-10-29T23:59:59Z',
#   'open': 10.7,
#   'high': 10.7,
#   'low': 10.7,
#   'close': 10.7},
#  {'time_open': '2012-10-30T00:00:00Z',
#   'time_close': '2012-10-30T23:59:59Z',
#   'open': 10.6,
#   'high': 10.6,
#   'low': 10.6,
#   'close': 10.6},
#  {'time_open': '2012-10-31T00:00:00Z',
#   'time_close': '2012-10-31T23:59:59Z',
#   'open': 10.89,
#   'high': 10.89,
#   'low': 10.89,
#   'close': 10.89},
#  {'time_open': '2012-11-01T00:00:00Z',
#   'time_close': '2012-11-01T23:59:59Z',
#   'open': 11.2,
#   'high': 11.2,
#   'low': 11.2,
#   'close': 11.2},
#  {'time_open': '2012-11-02T00:00:00Z',
#   'time_close': '2012-11-02T23:59:59Z',
#   'open': 10.57,
#   'high': 10.57,
#   'low': 10.57,
#   'close': 10.57},
#  {'time_open': '2012-11-03T00:00:00Z',
#   'time_close': '2012-11-03T23:59:59Z',
#   'open': 10.47,
#   'high': 10.47,
#   'low': 10.47,
#   'close': 10.47},
#  {'time_open': '2012-11-04T00:00:00Z',
#   'time_close': '2012-11-04T23:59:59Z',
#   'open': 10.64,
#   'high': 10.64,
#   'low': 10.64,
#   'close': 10.64},
#  {'time_open': '2012-11-05T00:00:00Z',
#   'time_close': '2012-11-05T23:59:59Z',
#   'open': 10.8,
#   'high': 10.8,
#   'low': 10.8,
#   'close': 10.8},
#  {'time_open': '2012-11-06T00:00:00Z',
#   'time_close': '2012-11-06T23:59:59Z',
#   'open': 10.75,
#   'high': 10.75,
#   'low': 10.75,
#   'close': 10.75},
#  {'time_open': '2012-11-07T00:00:00Z',
#   'time_close': '2012-11-07T23:59:59Z',
#   'open': 10.9,
#   'high': 10.9,
#   'low': 10.9,
#   'close': 10.9},
#  {'time_open': '2012-11-08T00:00:00Z',
#   'time_close': '2012-11-08T23:59:59Z',
#   'open': 10.92,
#   'high': 10.92,
#   'low': 10.92,
#   'close': 10.92},
#  {'time_open': '2012-11-09T00:00:00Z',
#   'time_close': '2012-11-09T23:59:59Z',
#   'open': 10.93,
#   'high': 10.93,
#   'low': 10.93,
#   'close': 10.93},
#  {'time_open': '2012-11-10T00:00:00Z',
#   'time_close': '2012-11-10T23:59:59Z',
#   'open': 10.82,
#   'high': 10.82,
#   'low': 10.82,
#   'close': 10.82},
#  {'time_open': '2012-11-11T00:00:00Z',
#   'time_close': '2012-11-11T23:59:59Z',
#   'open': 10.89,
#   'high': 10.89,
#   'low': 10.89,
#   'close': 10.89},
#  {'time_open': '2012-11-12T00:00:00Z',
#   'time_close': '2012-11-12T23:59:59Z',
#   'open': 10.87,
#   'high': 10.87,
#   'low': 10.87,
#   'close': 10.87},
#  {'time_open': '2012-11-13T00:00:00Z',
#   'time_close': '2012-11-13T23:59:59Z',
#   'open': 11.01,
#   'high': 11.01,
#   'low': 11.01,
#   'close': 11.01},
#  {'time_open': '2012-11-14T00:00:00Z',
#   'time_close': '2012-11-14T23:59:59Z',
#   'open': 10.95,
#   'high': 10.95,
#   'low': 10.95,
#   'close': 10.95},
#  {'time_open': '2012-11-15T00:00:00Z',
#   'time_close': '2012-11-15T23:59:59Z',
#   'open': 10.95,
#   'high': 10.95,
#   'low': 10.95,
#   'close': 10.95},
#  {'time_open': '2012-11-16T00:00:00Z',
#   'time_close': '2012-11-16T23:59:59Z',
#   'open': 11.2,
#   'high': 11.2,
#   'low': 11.2,
#   'close': 11.2},
#  {'time_open': '2012-11-17T00:00:00Z',
#   'time_close': '2012-11-17T23:59:59Z',
#   'open': 11.75,
#   'high': 11.75,
#   'low': 11.75,
#   'close': 11.75},
#  {'time_open': '2012-11-18T00:00:00Z',
#   'time_close': '2012-11-18T23:59:59Z',
#   'open': 11.79,
#   'high': 11.79,
#   'low': 11.79,
#   'close': 11.79},
#  {'time_open': '2012-11-19T00:00:00Z',
#   'time_close': '2012-11-19T23:59:59Z',
#   'open': 11.65,
#   'high': 11.65,
#   'low': 11.65,
#   'close': 11.65},
#  {'time_open': '2012-11-20T00:00:00Z',
#   'time_close': '2012-11-20T23:59:59Z',
#   'open': 11.8,
#   'high': 11.8,
#   'low': 11.8,
#   'close': 11.8},
#  {'time_open': '2012-11-21T00:00:00Z',
#   'time_close': '2012-11-21T23:59:59Z',
#   'open': 11.73,
#   'high': 11.73,
#   'low': 11.73,
#   'close': 11.73},
#  {'time_open': '2012-11-22T00:00:00Z',
#   'time_close': '2012-11-22T23:59:59Z',
#   'open': 11.77,
#   'high': 11.77,
#   'low': 11.77,
#   'close': 11.77},
#  {'time_open': '2012-11-23T00:00:00Z',
#   'time_close': '2012-11-23T23:59:59Z',
#   'open': 12.42,
#   'high': 12.42,
#   'low': 12.42,
#   'close': 12.42},
#  {'time_open': '2012-11-24T00:00:00Z',
#   'time_close': '2012-11-24T23:59:59Z',
#   'open': 12.35,
#   'high': 12.35,
#   'low': 12.35,
#   'close': 12.35},
#  {'time_open': '2012-11-25T00:00:00Z',
#   'time_close': '2012-11-25T23:59:59Z',
#   'open': 12.41,
#   'high': 12.41,
#   'low': 12.41,
#   'close': 12.41},
#  {'time_open': '2012-11-26T00:00:00Z',
#   'time_close': '2012-11-26T23:59:59Z',
#   'open': 12.48,
#   'high': 12.48,
#   'low': 12.48,
#   'close': 12.48},
#  {'time_open': '2012-11-27T00:00:00Z',
#   'time_close': '2012-11-27T23:59:59Z',
#   'open': 12.25,
#   'high': 12.25,
#   'low': 12.25,
#   'close': 12.25},
# ...
#   'time_close': '2014-07-12T23:59:59Z',
#   'open': 631.881,
#   'high': 636.658,
#   'low': 626.982,
#   'close': 633.713,
#   'volume': 13329000,
#   'market_cap': 8219365874},
#  {'time_open': '2014-07-13T00:00:00Z',
#   'time_close': '2014-07-13T23:59:59Z',
#   'open': 634.217,
#   'high': 634.727,
#   'low': 624.909,
#   'close': 626.497,
#   'volume': 11291000,
#   'market_cap': 8252241338},
#  {'time_open': '2014-07-14T00:00:00Z',
#   'time_close': '2014-07-14T23:59:59Z',
#   'open': 626.562,
#   'high': 627.342,
#   'low': 617.322,
#   'close': 619.315,
#   'volume': 12706800,
#   'market_cap': 8155143023},
#  {'time_open': '2014-07-15T00:00:00Z',
#   'time_close': '2014-07-15T23:59:59Z',
#   'open': 619.996,
#   'high': 625.141,
#   'low': 619.635,
#   'close': 621.586,
#   'volume': 10873200,
#   'market_cap': 8071774423},
#  {'time_open': '2014-07-16T00:00:00Z',
#   'time_close': '2014-07-16T23:59:59Z',
#   'open': 622.013,
#   'high': 623.092,
#   'low': 615.325,
#   'close': 616.8,
#   'volume': 13182400,
#   'market_cap': 8100506399},
#  {'time_open': '2014-07-17T00:00:00Z',
#   'time_close': '2014-07-17T23:59:59Z',
#   'open': 616.539,
#   'high': 626.29,
#   'low': 608.399,
#   'close': 623.089,
#   'volume': 16576700,
#   'market_cap': 8031437764},
#  {'time_open': '2014-07-18T00:00:00Z',
#   'time_close': '2014-07-18T23:59:59Z',
#   'open': 622.369,
#   'high': 629.213,
#   'low': 620.472,
#   'close': 628.779,
#   'volume': 14158100,
#   'market_cap': 8110059320},
#  {'time_open': '2014-07-19T00:00:00Z',
#   'time_close': '2014-07-19T23:59:59Z',
#   'open': 629.166,
#   'high': 629.166,
#   'low': 624.597,
#   'close': 628.515,
#   'volume': 7222030,
#   'market_cap': 8201336101},
#  {'time_open': '2014-07-20T00:00:00Z',
#   'time_close': '2014-07-20T23:59:59Z',
#   'open': 628.559,
#   'high': 628.559,
#   'low': 622.775,
#   'close': 623.9,
#   'volume': 5760120,
#   'market_cap': 8196205078},
#  {'time_open': '2014-07-21T00:00:00Z',
#   'time_close': '2014-07-21T23:59:59Z',
#   'open': 623.95,
#   'high': 624.09,
#   'low': 619.109,
#   'close': 622.211,
#   'volume': 10711900,
#   'market_cap': 8138523022},
#  {'time_open': '2014-07-22T00:00:00Z',
#   'time_close': '2014-07-22T23:59:59Z',
#   'open': 622.273,
#   'high': 624.298,
#   'low': 620.957,
#   'close': 621.551,
#   'volume': 9602880,
#   'market_cap': 8119060297},
#  {'time_open': '2014-07-23T00:00:00Z',
#   'time_close': '2014-07-23T23:59:59Z',
#   'open': 621.123,
#   'high': 624.431,
#   'low': 618.293,
#   'close': 619.415,
#   'volume': 11056600,
#   'market_cap': 8106260744},
#  {'time_open': '2014-07-24T00:00:00Z',
#   'time_close': '2014-07-24T23:59:59Z',
#   'open': 619.496,
#   'high': 620.429,
#   'low': 595.566,
#   'close': 601.733,
#   'volume': 20917200,
#   'market_cap': 8087287969},
#  {'time_open': '2014-07-25T00:00:00Z',
#   'time_close': '2014-07-25T23:59:59Z',
#   'open': 601.512,
#   'high': 607.065,
#   'low': 597.226,
#   'close': 601.089,
#   'volume': 12279500,
#   'market_cap': 7854663998},
#  {'time_open': '2014-07-26T00:00:00Z',
#   'time_close': '2014-07-26T23:59:59Z',
#   'open': 601.542,
#   'high': 602.088,
#   'low': 593.964,
#   'close': 595.813,
#   'volume': 10752900,
#   'market_cap': 7857507028},
#  {'time_open': '2014-07-27T00:00:00Z',
#   'time_close': '2014-07-27T23:59:59Z',
#   'open': 595.672,
#   'high': 598.942,
#   'low': 593.43,
#   'close': 593.852,
#   'volume': 7774230,
#   'market_cap': 7782826975},
#  {'time_open': '2014-07-28T00:00:00Z',
#   'time_close': '2014-07-28T23:59:59Z',
#   'open': 594.137,
#   'high': 594.573,
#   'low': 575.185,
#   'close': 585.691,
#   'volume': 19316400,
#   'market_cap': 7765043814},
#  {'time_open': '2014-07-29T00:00:00Z',
#   'time_close': '2014-07-29T23:59:59Z',
#   'open': 585.552,
#   'high': 588.385,
#   'low': 581.695,
#   'close': 584.725,
#   'volume': 11275400,
#   'market_cap': 7655038406},
#  {'time_open': '2014-07-30T00:00:00Z',
#   'time_close': '2014-07-30T23:59:59Z',
#   'open': 584.742,
#   'high': 585.122,
#   'low': 564.896,
#   'close': 567.293,
#   'volume': 14898800,
#   'market_cap': 7646627278},
#  {'time_open': '2014-07-31T00:00:00Z',
#   'time_close': '2014-07-31T23:59:59Z',
#   'open': 567.368,
#   'high': 586.235,
#   'low': 564.511,
#   'close': 586.235,
#   'volume': 22467900,
#   'market_cap': 7421868465},
#  {'time_open': '2014-08-01T00:00:00Z',
#   'time_close': '2014-08-01T23:59:59Z',
#   'open': 586.202,
#   'high': 597.922,
#   'low': 583.634,
#   'close': 594.916,
#   'volume': 18215900,
#   'market_cap': 7670497135},
#  {'time_open': '2014-08-02T00:00:00Z',
#   'time_close': '2014-08-02T23:59:59Z',
#   'open': 594.898,
#   'high': 594.91,
#   'low': 586.155,
#   'close': 589.333,
#   'volume': 8359080,
#   'market_cap': 7786619922},
#  {'time_open': '2014-08-03T00:00:00Z',
#   'time_close': '2014-08-03T23:59:59Z',
#   'open': 588.893,
#   'high': 589.151,
#   'low': 581.65,
#   'close': 586.666,
#   'volume': 9917990,
#   'market_cap': 7710420215},
#  {'time_open': '2014-08-04T00:00:00Z',
#   'time_close': '2014-08-04T23:59:59Z',
#   'open': 586.233,
#   'high': 591.946,
#   'low': 583.74,
#   'close': 588.782,
#   'volume': 9867570,
#   'market_cap': 7677849633},
#  {'time_open': '2014-08-05T00:00:00Z',
#   'time_close': '2014-08-05T23:59:59Z',
#   'open': 589.011,
#   'high': 589.865,
#   'low': 584.102,
#   'close': 585.436,
#   'volume': 10790800,
#   'market_cap': 7716117726},
#  {'time_open': '2014-08-06T00:00:00Z',
#   'time_close': '2014-08-06T23:59:59Z',
#   'open': 585.952,
#   'high': 587.486,
#   'low': 583.098,
#   'close': 584.653,
#   'volume': 14497900,
#   'market_cap': 7678036680},
#  {'time_open': '2014-08-07T00:00:00Z',
#   'time_close': '2014-08-07T23:59:59Z',
#   'open': 584.646,
#   'high': 591.104,
#   'low': 584.052,
#   'close': 588.869,
#   'volume': 11131400,
#   'market_cap': 7663291293},
#  {'time_open': '2014-08-08T00:00:00Z',
#   'time_close': '2014-08-08T23:59:59Z',
#   'open': 588.875,
#   'high': 598.116,
#   'low': 588.791,
#   'close': 592.577,
#   'volume': 11072000,
#   'market_cap': 7721093450},
#  {'time_open': '2014-08-09T00:00:00Z',
#   'time_close': '2014-08-09T23:59:59Z',
#   'open': 592.47,
#   'high': 592.47,
#   'low': 587.633,
#   'close': 589.372,
#   'volume': 7922070,
#   'market_cap': 7770555096},
#  {'time_open': '2014-08-10T00:00:00Z',
#   'time_close': '2014-08-10T23:59:59Z',
#   'open': 589.172,
#   'high': 594.46,
#   'low': 587.942,
#   'close': 591.061,
#   'volume': 7555310,
#   'market_cap': 7729995557},
#  {'time_open': '2014-08-11T00:00:00Z',
#   'time_close': '2014-08-11T23:59:59Z',
#   'open': 591.282,
#   'high': 591.507,
#   'low': 574.051,
#   'close': 576.368,
#   'volume': 14764200,
#   'market_cap': 7760295391},
#  {'time_open': '2014-08-12T00:00:00Z',
#   'time_close': '2014-08-12T23:59:59Z',
#   'open': 576.512,
#   'high': 576.948,
#   'low': 566.595,
#   'close': 569.642,
#   'volume': 13978200,
#   'market_cap': 7569069286},
#  {'time_open': '2014-08-13T00:00:00Z',
#   'time_close': '2014-08-13T23:59:59Z',
#   'open': 570.377,
#   'high': 573.033,
#   'low': 532.667,
#   'close': 546.658,
#   'volume': 25777500,
#   'market_cap': 7490989291},
#  {'time_open': '2014-08-14T00:00:00Z',
#   'time_close': '2014-08-14T23:59:59Z',
#   'open': 546.181,
#   'high': 546.244,
#   'low': 498.725,
#   'close': 505.974,
#   'volume': 35803900,
#   'market_cap': 7175193451},
#  {'time_open': '2014-08-15T00:00:00Z',
#   'time_close': '2014-08-15T23:59:59Z',
#   'open': 511.138,
#   'high': 518.179,
#   'low': 487.926,
#   'close': 497.01,
#   'volume': 25598300,
#   'market_cap': 6717145583},
#  {'time_open': '2014-08-16T00:00:00Z',
#   'time_close': '2014-08-16T23:59:59Z',
#   'open': 497.826,
#   'high': 521.475,
#   'low': 487.744,
#   'close': 519.708,
#   'volume': 22832500,
#   'market_cap': 6544246356},
#  {'time_open': '2014-08-17T00:00:00Z',
#   'time_close': '2014-08-17T23:59:59Z',
#   'open': 519.142,
#   'high': 520.19,
#   'low': 483.626,
#   'close': 491.795,
#   'volume': 24300900,
#   'market_cap': 6826522621},
#  {'time_open': '2014-08-18T00:00:00Z',
#   'time_close': '2014-08-18T23:59:59Z',
#   'open': 491.507,
#   'high': 499.37,
#   'low': 443.851,
#   'close': 461.46,
#   'volume': 50783800,
#   'market_cap': 6465209351},
#  {'time_open': '2014-08-19T00:00:00Z',
#   'time_close': '2014-08-19T23:59:59Z',
#   'open': 461.48,
#   'high': 485.71,
#   'low': 455.539,
#   'close': 485.245,
#   'volume': 38422400,
#   'market_cap': 6072523024},
#  {'time_open': '2014-08-20T00:00:00Z',
#   'time_close': '2014-08-20T23:59:59Z',
#   'open': 485.072,
#   'high': 518.285,
#   'low': 467.511,
#   'close': 511.98,
#   'volume': 46527600,
#   'market_cap': 6385233145},
#  {'time_open': '2014-08-21T00:00:00Z',
#   'time_close': '2014-08-21T23:59:59Z',
#   'open': 510.449,
#   'high': 531.9,
#   'low': 510.449,
#   'close': 517.237,
#   'volume': 49444200,
#   'market_cap': 6721413774},
#  {'time_open': '2014-08-22T00:00:00Z',
#   'time_close': '2014-08-22T23:59:59Z',
#   'open': 517.581,
#   'high': 521.479,
#   'low': 501.275,
#   'close': 514.043,
#   'volume': 36563900,
#   'market_cap': 6817460476},
#  {'time_open': '2014-08-23T00:00:00Z',
#   'time_close': '2014-08-23T23:59:59Z',
#   'open': 513.394,
#   'high': 514.299,
#   'low': 492.114,
#   'close': 498.075,
#   'volume': 25171900,
#   'market_cap': 6764338160},
#  {'time_open': '2014-08-24T00:00:00Z',
#   'time_close': '2014-08-24T23:59:59Z',
#   'open': 498.285,
#   'high': 512.888,
#   'low': 497.351,
#   'close': 508.286,
#   'volume': 19441700,
#   'market_cap': 6567296643},
#  {'time_open': '2014-08-25T00:00:00Z',
#   'time_close': '2014-08-25T23:59:59Z',
#   'open': 508.22,
#   'high': 508.22,
#   'low': 499.233,
#   'close': 502.496,
#   'volume': 18356700,
#   'market_cap': 6700092959},
#  {'time_open': '2014-08-26T00:00:00Z',
#   'time_close': '2014-08-26T23:59:59Z',
#   'open': 502.544,
#   'high': 512.688,
#   'low': 502.544,
#   'close': 511.57,
#   'volume': 23235100,
#   'market_cap': 6626972346},
#  {'time_open': '2014-08-27T00:00:00Z',
#   'time_close': '2014-08-27T23:59:59Z',
#   'open': 512.189,
#   'high': 520.709,
#   'low': 510.922,
#   'close': 511.153,
#   'volume': 22648500,
#   'market_cap': 6756336317},
#  {'time_open': '2014-08-28T00:00:00Z',
#   'time_close': '2014-08-28T23:59:59Z',
#   'open': 510.884,
#   'high': 516.157,
#   'low': 506.877,
#   'close': 507.815,
#   'volume': 19862000,
#   'market_cap': 6741318733},
#  {'time_open': '2014-08-29T00:00:00Z',
#   'time_close': '2014-08-29T23:59:59Z',
#   'open': 508.425,
#   'high': 511.695,
#   'low': 503.817,
#   'close': 508.517,
#   'volume': 17624800,
#   'market_cap': 6711082893},
#  {'time_open': '2014-08-30T00:00:00Z',
#   'time_close': '2014-08-30T23:59:59Z',
#   'open': 508.59,
#   'high': 509.308,
#   'low': 501.636,
#   'close': 504.249,
#   'volume': 9424070,
#   'market_cap': 6715422360},
#  {'time_open': '2014-08-31T00:00:00Z',
#   'time_close': '2014-08-31T23:59:59Z',
#   'open': 502.905,
#   'high': 504.879,
#   'low': 474.814,
#   'close': 477.763,
#   'volume': 44632300,
#   'market_cap': 6642633265},
#  {'time_open': '2014-09-01T00:00:00Z',
#   'time_close': '2014-09-01T23:59:59Z',
#   'open': 477.787,
#   'high': 485.306,
#   'low': 471.91,
#   'close': 474.879,
#   'volume': 20432000,
#   'market_cap': 6313119077},
#  {'time_open': '2014-09-02T00:00:00Z',
#   'time_close': '2014-09-02T23:59:59Z',
#   'open': 474.475,
#   'high': 482.988,
#   'low': 472.324,
#   'close': 477.426,
#   'volume': 23337900,
#   'market_cap': 6270970008},
#  {'time_open': '2014-09-03T00:00:00Z',
#   'time_close': '2014-09-03T23:59:59Z',
#   'open': 476.871,
#   'high': 481.712,
#   'low': 476.208,
#   'close': 477.586,
#   'volume': 13342200,
#   'market_cap': 6304365759},
#  {'time_open': '2014-09-04T00:00:00Z',
#   'time_close': '2014-09-04T23:59:59Z',
#   'open': 477.68,
#   'high': 493.928,
#   'low': 477.086,
#   'close': 489.66,
#   'volume': 26081400,
#   'market_cap': 6317103044},
#  {'time_open': '2014-09-05T00:00:00Z',
#   'time_close': '2014-09-05T23:59:59Z',
#   'open': 489.665,
#   'high': 490.643,
#   'low': 481.609,
#   'close': 483.342,
#   'volume': 15302500,
#   'market_cap': 6477533452},
#  {'time_open': '2014-09-06T00:00:00Z',
#   'time_close': '2014-09-06T23:59:59Z',
#   'open': 483.341,
#   'high': 488.595,
#   'low': 482.998,
#   'close': 484.83,
#   'volume': 10601400,
#   'market_cap': 6395628529},
#  {'time_open': '2014-09-07T00:00:00Z',
#   'time_close': '2014-09-07T23:59:59Z',
#   'open': 485.129,
#   'high': 488.066,
#   'low': 482.278,
#   'close': 482.278,
#   'volume': 8994050,
#   'market_cap': 6421458521},
#  {'time_open': '2014-09-08T00:00:00Z',
#   'time_close': '2014-09-08T23:59:59Z',
#   'open': 481.811,
#   'high': 489.834,
#   'low': 468.79,
#   'close': 474.6,
#   'volume': 30238000,
#   'market_cap': 6379406500},
#  {'time_open': '2014-09-09T00:00:00Z',
#   'time_close': '2014-09-09T23:59:59Z',
#   'open': 474.88,
#   'high': 477.377,
#   'low': 467.778,
#   'close': 475.26,
#   'volume': 21447800,
#   'market_cap': 6289346336},
#  {'time_open': '2014-09-10T00:00:00Z',
#   'time_close': '2014-09-10T23:59:59Z',
#   'open': 475.484,
#   'high': 487.468,
#   'low': 475.145,
#   'close': 479.359,
#   'volume': 22787800,
#   'market_cap': 6299069386},
#  {'time_open': '2014-09-11T00:00:00Z',
#   'time_close': '2014-09-11T23:59:59Z',
#   'open': 479.617,
#   'high': 482.351,
#   'low': 474.61,
#   'close': 479.749,
#   'volume': 16852900,
#   'market_cap': 6355704627},
#  {'time_open': '2014-09-12T00:00:00Z',
#   'time_close': '2014-09-12T23:59:59Z',
#   'open': 479.582,
#   'high': 479.628,
#   'low': 473.009,
#   'close': 477.753,
#   'volume': 15437200,
#   'market_cap': 6357291033},
#  {'time_open': '2014-09-13T00:00:00Z',
#   'time_close': '2014-09-13T23:59:59Z',
#   'open': 477.793,
#   'high': 482.117,
#   'low': 475.098,
#   'close': 479.002,
#   'volume': 15588000,
#   'market_cap': 6335403786},
#  {'time_open': '2014-09-14T00:00:00Z',
#   'time_close': '2014-09-14T23:59:59Z',
#   'open': 479.117,
#   'high': 479.853,
#   'low': 476.119,
#   'close': 477.892,
#   'volume': 13105500,
#   'market_cap': 6355139645},
#  {'time_open': '2014-09-15T00:00:00Z',
#   'time_close': '2014-09-15T23:59:59Z',
#   'open': 477.765,
#   'high': 478.62,
#   'low': 474.022,
#   'close': 475.371,
#   'volume': 15345200,
#   'market_cap': 6339093517},
#  {'time_open': '2014-09-16T00:00:00Z',
#   'time_close': '2014-09-16T23:59:59Z',
#   'open': 474.862,
#   'high': 475.642,
#   'low': 465.128,
#   'close': 466.057,
#   'volume': 16797300,
#   'market_cap': 6302439693},
#  {'time_open': '2014-09-17T00:00:00Z',
#   'time_close': '2014-09-17T23:59:59Z',
#   'open': 465.864,
#   'high': 468.174,
#   'low': 452.422,
#   'close': 457.334,
#   'volume': 21056800,
#   'market_cap': 6185008456},
#  {'time_open': '2014-09-18T00:00:00Z',
#   'time_close': '2014-09-18T23:59:59Z',
#   'open': 456.86,
#   'high': 456.86,
#   'low': 413.104,
#   'close': 424.44,
#   'volume': 34483200,
#   'market_cap': 6067614767},
#  {'time_open': '2014-09-19T00:00:00Z',
#   'time_close': '2014-09-19T23:59:59Z',
#   'open': 424.103,
#   'high': 427.835,
#   'low': 384.532,
#   'close': 394.796,
#   'volume': 37919700,
#   'market_cap': 5634441611},
#  {'time_open': '2014-09-20T00:00:00Z',
#   'time_close': '2014-09-20T23:59:59Z',
#   'open': 394.673,
#   'high': 423.296,
#   'low': 389.883,
#   'close': 408.904,
#   'volume': 36863600,
#   'market_cap': 5245144969},
#  {'time_open': '2014-09-21T00:00:00Z',
#   'time_close': '2014-09-21T23:59:59Z',
#   'open': 408.085,
#   'high': 412.426,
#   'low': 393.181,
#   'close': 398.821,
#   'volume': 26580100,
#   'market_cap': 5425184011},
#  {'time_open': '2014-09-22T00:00:00Z',
#   'time_close': '2014-09-22T23:59:59Z',
#   'open': 399.1,
#   'high': 406.916,
#   'low': 397.13,
#   'close': 402.152,
#   'volume': 24127600,
#   'market_cap': 5307361507},
#  {'time_open': '2014-09-23T00:00:00Z',
#   'time_close': '2014-09-23T23:59:59Z',
#   'open': 402.092,
#   'high': 441.557,
#   'low': 396.197,
#   'close': 435.791,
#   'volume': 45099500,
#   'market_cap': 5348838882},
#  {'time_open': '2014-09-24T00:00:00Z',
#   'time_close': '2014-09-24T23:59:59Z',
#   'open': 435.751,
#   'high': 436.112,
#   'low': 421.132,
#   'close': 423.205,
#   'volume': 30627700,
#   'market_cap': 5798222637},
#  {'time_open': '2014-09-25T00:00:00Z',
#   'time_close': '2014-09-25T23:59:59Z',
#   'open': 423.156,
#   'high': 423.52,
#   'low': 409.468,
#   'close': 411.574,
#   'volume': 26814400,
#   'market_cap': 5632259254},
#  {'time_open': '2014-09-26T00:00:00Z',
#   'time_close': '2014-09-26T23:59:59Z',
#   'open': 411.429,
#   'high': 414.938,
#   'low': 400.009,
#   'close': 404.425,
#   'volume': 21460800,
#   'market_cap': 5477971420},
#  {'time_open': '2014-09-27T00:00:00Z',
#   'time_close': '2014-09-27T23:59:59Z',
#   'open': 403.556,
#   'high': 406.623,
#   'low': 397.372,
#   'close': 399.52,
#   'volume': 15029300,
#   'market_cap': 5374498274},
#  ...]

# %% [markdown]
# 5. Convert the previous object to a pandas dataframe

# %%
df_btc = pd.DataFrame(crypto.get('btc-bitcoin'))
df_btc.head()
# Out:
#               time_open            time_close  open  high   low  close  \
# 0  2012-01-01T00:00:00Z  2012-01-01T23:59:59Z  4.72  4.72  4.72   4.72
# 1  2012-01-02T00:00:00Z  2012-01-02T23:59:59Z  5.27  5.27  5.27   5.27
# 2  2012-01-03T00:00:00Z  2012-01-03T23:59:59Z  5.22  5.22  5.22   5.22
# 3  2012-01-04T00:00:00Z  2012-01-04T23:59:59Z  4.88  4.88  4.88   4.88
# 4  2012-01-05T00:00:00Z  2012-01-05T23:59:59Z  5.57  5.57  5.57   5.57
#
#    market_cap  volume
# 0         NaN     NaN
# 1         NaN     NaN
# 2         NaN     NaN
# 3         NaN     NaN
# 4         NaN     NaN

# %% [markdown]
# 6. Now that you know how to convert one element of `crypto` into a dataframe, write ONE line of code that will convert each element into a dataframe and store them in a `list` object.
#
# <details>
#   <summary>Spoiler</summary>
#   Use a list comprehension.
# </details>

# %%
list_values = [pd.DataFrame(crypto.get(k)) for k in crypto.keys()]
print(len(list_values))
# Out:
# 10

# %% [markdown]
# 7. For each of these dataframes add a column called `"coin"` that contains the name of the key it was associated with.
#
# <details>
#   <summary>Spoiler</summary>
#   Use a for loop and the `zip` command to be able to loop over two iterables at once
# </details>

# %%
for x,y in zip(list_values,crypto.keys()):
    x['coin'] = y

# %% [markdown]
# 8. Upload each of these dataframes to the folder of your choice in your s3
#
# <details>
#   <summary>Spoiler</summary>
#   Use the pandas method `to_csv` to convert your dataframes to csv files and the appropriate command from the bucket object
# </details>

# %%
for x,y in zip(list_values,crypto.keys()):
    put_object = bucket.put_object(Key=f"{y}/values-{y}.csv", Body=x.to_csv(index=False))

# %% [markdown]
# 9. Now go to your S3 to make sure the files have been uploaded correctly!
