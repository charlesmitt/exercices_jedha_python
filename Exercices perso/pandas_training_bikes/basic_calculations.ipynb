# %%
import pandas as pd

# %%
data = pd.read_csv("comptage-velo-donnees-compteurs.csv", sep=";")
data.head()
# Out:
#   Identifiant du compteur                    Nom du compteur  \
# 0     100003096-353242251  97 avenue Denfert Rochereau SO-NE
# 1     100003096-353242251  97 avenue Denfert Rochereau SO-NE
# 2     100003096-353242251  97 avenue Denfert Rochereau SO-NE
# 3     100003096-353242251  97 avenue Denfert Rochereau SO-NE
# 4     100003096-353242251  97 avenue Denfert Rochereau SO-NE
#
#    Identifiant du site de comptage      Nom du site de comptage  \
# 0                        100003096  97 avenue Denfert Rochereau
# 1                        100003096  97 avenue Denfert Rochereau
# 2                        100003096  97 avenue Denfert Rochereau
# 3                        100003096  97 avenue Denfert Rochereau
# 4                        100003096  97 avenue Denfert Rochereau
#
#    Comptage horaire  Date et heure de comptage  \
# 0                14  2024-10-01T00:00:00+02:00
# 1                 0  2024-10-01T03:00:00+02:00
# 2                 9  2024-10-01T05:00:00+02:00
# ...

# %%
data.describe()
# Out:
#        Identifiant du site de comptage  Comptage horaire
# count                     9.900460e+05     990046.000000
# mean                      1.329943e+08         77.401742
# std                       7.418306e+07        107.557171
# min                       1.000031e+08          0.000000
# 25%                       1.000475e+08         12.000000
# 50%                       1.000560e+08         42.000000
# 75%                       1.000563e+08         96.000000
# max                       3.000303e+08       8190.000000

# %%
data.count()
# Out:
# Identifiant du compteur                       990046
# Nom du compteur                               990046
# Identifiant du site de comptage               990046
# Nom du site de comptage                       990046
# Comptage horaire                              990046
# Date et heure de comptage                     990046
# Date d'installation du site de comptage       990046
# Lien vers photo du site de comptage           979852
# Coordonnées géographiques                     990046
# Identifiant technique compteur                979849
# ID Photos                                     979852
# test_lien_vers_photos_du_site_de_comptage_    979852
# id_photo_1                                    979852
# url_sites                                     990046
# type_dimage                                   979852
# mois_annee_comptage                           990046
# dtype: int64

# %%
data.max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data.max()
#
# File c:\Users\Admin\anaconda3\Lib\site-packages\pandas\core\frame.py:11656, in DataFrame.max(self, axis, skipna, numeric_only, **kwargs)
#   11648 @doc(make_doc("max", ndim=2))
#   11649 def max(
#   11650     self,
#    (...)
#   11654     **kwargs,
#   11655 ):
# > 11656     result = super().max(axis, skipna, numeric_only, **kwargs)
#   11657     if isinstance(result, Series):
#   11658         result = result.__finalize__(self, method="max")
#
# File c:\Users\Admin\anaconda3\Lib\site-packages\pandas\core\generic.py:12404, in NDFrame.max(self, axis, skipna, numeric_only, **kwargs)
#   12397 def max(
#   12398     self,
#   12399     axis: Axis | None = 0,
#    (...)
#   12402     **kwargs,
#   12403 ):
# > 12404     return self._stat_function(
#   12405         "max",
# ...

# %%
data["Identifiant du compteur"].head
# Out:
# <bound method NDFrame.head of 0         100003096-353242251
# 1         100003096-353242251
# 2         100003096-353242251
# 3         100003096-353242251
# 4         100003096-353242251
#                  ...
# 990041    300030271-353356061
# 990042    300030271-353356061
# 990043    300030271-353356061
# 990044    300030271-353356061
# 990045    300030271-353356061
# Name: Identifiant du compteur, Length: 990046, dtype: object>

# %%
mask = data["Nom du site de comptage"]== "*Magenta*"

data[mask]
# Out:
# Empty DataFrame
# Columns: [Identifiant du compteur, Nom du compteur, Identifiant du site de comptage, Nom du site de comptage, Comptage horaire, Date et heure de comptage, Date d'installation du site de comptage, Lien vers photo du site de comptage, Coordonnées géographiques, Identifiant technique compteur, ID Photos, test_lien_vers_photos_du_site_de_comptage_, id_photo_1, url_sites, type_dimage, mois_annee_comptage]
# Index: []

# %%
data["Nom du site de comptage"].unique()
# Out:
# array(['97 avenue Denfert Rochereau', '105 rue La Fayette',
#        '106 avenue Denfert Rochereau', '135 avenue Daumesnil',
#        '100 rue La Fayette', '28 boulevard Diderot',
#        '39 quai François Mauriac', "18 quai de l'Hôtel de Ville",
#        '27 boulevard Diderot', 'Voie Georges Pompidou',
#        '67 boulevard Voltaire', '10 avenue de la Grande Armée',
#        '7 avenue de la Grande Armée', '72 boulevard Voltaire',
#        '89 boulevard de Magenta', '16 avenue de la Porte des Ternes',
#        'Pont du Garigliano', '102 boulevard de Magenta',
#        'Face au 16 avenue de la  Porte des Ternes',
#        '21 boulevard Auguste Blanqui', '72 boulevard Richard Lenoir',
#        'Pont National', 'Face au 48 quai de la marne',
#        '77 boulevard Richard Lenoir', "Face 104 rue d'Aubervilliers",
#        'Face au 70 quai de Bercy', '6 rue Julia Bartet',
#        "Face au 25 quai de l'Oise", '35 boulevard de Ménilmontant',
# ...

# %%
mask = data["Nom du site de comptage"]=="102 boulevard de Magenta"

data_magenta = data[mask]
mask = data["Nom du site de comptage"]=="81 boulevard Mortier"

data_mortier = data[mask]

# %%
print(data_magenta["Comptage horaire"].sum())

print(data_mortier["Comptage horaire"].sum())
# Out:
# 2263947
# 519867
