# %% [markdown]
# key = "f8fbd7aec959fc960101693bdb488eb5c99bfca4261a2c400e7713372ce03d9a"
#
# curl --request GET \
# --url "https://api.openaq.org/v3/locations/2178" \
# --header "X-API-Key: YOUR-OPENAQ-API-KEY"

# %%
import requests
import pandas as pd
key = "f8fbd7aec959fc960101693bdb488eb5c99bfca4261a2c400e7713372ce03d9a"

url = "https://api.openaq.org/v3/countries/42"
header = {'X-API-Key': key}

resp = requests.get(url, headers=header)

# %%
url_param = "https://api.openaq.org/v2/parameters"

resp_param = requests.get(url_param, headers=header)

# %%
resp_param.json()
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': '',
#   'website': '/',
#   'page': 1,
#   'limit': 100,
#   'found': 64},
#  'results': [{'id': 1,
#    'name': 'pm10',
#    'displayName': 'PM10',
#    'description': 'Particulate matter less than 10 micrometers in diameter mass concentration',
#    'preferredUnit': 'µg/m³'},
#   {'id': 2,
#    'name': 'pm25',
#    'displayName': 'PM2.5',
#    'description': 'Particulate matter less than 2.5 micrometers in diameter mass concentration',
#    'preferredUnit': 'µg/m³'},
#   {'id': 3,
#    'name': 'o3',
#    'displayName': 'O₃ mass',
#    'description': 'Ozone mass concentration',
#    'preferredUnit': 'µg/m³'},
#   {'id': 4,
#    'name': 'co',
#    'displayName': 'CO mass',
#    'description': 'Carbon Monoxide mass concentration',
#    'preferredUnit': 'µg/m³'},
#   {'id': 5,
#    'name': 'no2',
#    'displayName': 'NO₂ mass',
#    'description': 'Nitrogen Dioxide mass concentration',
#    'preferredUnit': 'µg/m³'},
#   {'id': 6,
#    'name': 'so2',
#    'displayName': 'SO₂ mass',
#    'description': 'Sulfur Dioxide mass concentration',
#    'preferredUnit': 'µg/m³'},
#   {'id': 7,
#    'name': 'no2',
#    'displayName': 'NO₂',
#    'description': 'Nitrogen Dioxide concentration',
#    'preferredUnit': 'ppm'},
#   {'id': 8,
#    'name': 'co',
#    'displayName': 'CO',
#    'description': 'Carbon Monoxide concentration',
#    'preferredUnit': 'ppm'},
#   {'id': 9,
#    'name': 'so2',
#    'displayName': 'SO₂',
#    'description': 'Sulfur Dioxide concentration',
#    'preferredUnit': 'ppm'},
#   {'id': 10,
#    'name': 'o3',
#    'displayName': 'O₃',
#    'description': 'Ozone concentration',
#    'preferredUnit': 'ppm'},
#   {'id': 11,
#    'name': 'bc',
#    'displayName': 'BC',
#    'description': 'Black Carbon mass concentration',
#    'preferredUnit': 'µg/m³'},
#   {'id': 14,
#    'name': 'co2',
#    'displayName': 'CO2',
#    'description': 'CO2',
#    'preferredUnit': 'umol/mol'},
#   {'id': 15,
#    'name': 'no2',
#    'displayName': 'NO₂',
#    'description': 'NO₂',
#    'preferredUnit': 'ppb'},
#   {'id': 17,
#    'name': 'bc',
#    'displayName': 'BC',
#    'description': 'BC',
#    'preferredUnit': 'ng/m3'},
#   {'id': 19,
#    'name': 'pm1',
#    'displayName': 'PM1',
#    'description': 'Particulate matter less than 1 micrometer in diameter mass concentration',
#    'preferredUnit': 'µg/m³'},
#   {'id': 21,
#    'name': 'co2',
#    'displayName': 'CO₂',
#    'description': 'Carbon Dioxide concentration',
#    'preferredUnit': 'ppm'},
#   {'id': 22,
#    'name': 'wind_direction',
#    'displayName': 'Wind direction',
#    'description': 'Direction that the wind originates from',
#    'preferredUnit': 'deg'},
#   {'id': 23,
#    'name': 'nox',
#    'displayName': 'NOX',
#    'description': 'NOX',
#    'preferredUnit': 'ppb'},
#   {'id': 24,
#    'name': 'no',
#    'displayName': 'NO',
#    'description': 'NO',
#    'preferredUnit': 'ppb'},
#   {'id': 25,
#    'name': 'rh',
#    'displayName': 'RH',
#    'description': 'RH',
#    'preferredUnit': '%'},
#   {'id': 27,
#    'name': 'nox',
#    'displayName': 'NOx mass',
#    'description': 'Nitrogen Oxides mass concentration',
#    'preferredUnit': 'µg/m³'},
#   {'id': 28,
#    'name': 'ch4',
#    'displayName': 'CH₄',
#    'description': 'Methane concentration',
#    'preferredUnit': 'ppm'},
#   {'id': 29,
#    'name': 'pn',
#    'displayName': None,
#    'description': 'n/a',
#    'preferredUnit': 'particles/cm³'},
#   {'id': 32,
#    'name': 'o3',
#    'displayName': 'O₃',
#    'description': 'O₃',
#    'preferredUnit': 'ppb'},
#   {'id': 33,
#    'name': 'ufp',
#    'displayName': 'UFP count',
#    'description': 'Ultrafine Particles count concentration',
#    'preferredUnit': 'particles/cm³'},
#   {'id': 34,
#    'name': 'wind_speed',
#    'displayName': 'Wind speed',
#    'description': 'Average wind speed in meters per second',
#    'preferredUnit': 'm/s'},
#   {'id': 35,
#    'name': 'no',
#    'displayName': 'NO',
#    'description': 'Nitrogen Monoxide concentration',
#    'preferredUnit': 'ppm'},
#   {'id': 36,
#    'name': 'pm',
#    'displayName': 'PM',
#    'description': 'PM',
#    'preferredUnit': 'µg/m³'},
#   {'id': 37,
#    'name': 'ambient_temp',
#    'displayName': 'Temperature (C)',
#    'description': 'Temperature (C)',
#    'preferredUnit': 'deg_c'},
#   {'id': 95,
#    'name': 'pressure',
#    'displayName': 'Atmospheric pressure',
#    'description': 'Atmospheric or barometric pressure',
#    'preferredUnit': 'hpa'},
#   {'id': 97,
#    'name': 'pm25-old',
#    'displayName': None,
#    'description': 'n/a',
#    'preferredUnit': 'ugm3'},
#   {'id': 98,
#    'name': 'relativehumidity',
#    'displayName': 'RH',
#    'description': 'RH',
#    'preferredUnit': '%'},
#   {'id': 100,
#    'name': 'temperature',
#    'displayName': 'Temperature (C)',
#    'description': 'Temperature (C)',
#    'preferredUnit': 'c'},
#   {'id': 101,
#    'name': 'so2',
#    'displayName': 'SO₂',
#    'description': 'SO₂',
#    'preferredUnit': 'ppb'},
#   {'id': 102,
#    'name': 'co',
#    'displayName': 'CO',
#    'description': 'CO',
#    'preferredUnit': 'ppb'},
#   {'id': 125,
#    'name': 'um003',
#    'displayName': 'PM0.3 count',
#    'description': 'PM0.3 count',
#    'preferredUnit': 'particles/cm³'},
#   {'id': 126,
#    'name': 'um010',
#    'displayName': 'PM1 count',
#    'description': 'PM1 count',
#    'preferredUnit': 'particles/cm³'},
#   {'id': 128,
#    'name': 'temperature',
#    'displayName': 'Temperature (F)',
#    'description': 'Temperature (F)',
#    'preferredUnit': 'f'},
#   {'id': 129,
#    'name': 'um050',
#    'displayName': 'PM5.0 count',
#    'description': 'PM5.0 count',
#    'preferredUnit': 'particles/cm³'},
#   {'id': 130,
#    'name': 'um025',
#    'displayName': 'PM2.5 count',
#    'description': 'PM2.5 count',
#    'preferredUnit': 'particles/cm³'},
#   {'id': 131,
#    'name': 'pm100',
#    'displayName': 'PM100',
#    'description': 'PM100',
#    'preferredUnit': 'µg/m³'},
#   {'id': 132,
#    'name': 'pressure',
#    'displayName': 'Pressure',
#    'description': 'Pressure',
#    'preferredUnit': 'mb'},
#   {'id': 133,
#    'name': 'um005',
#    'displayName': 'PM0.5',
#    'description': 'PM0.5',
#    'preferredUnit': 'particles/cm³'},
#   {'id': 134,
#    'name': 'humidity',
#    'displayName': 'H',
#    'description': 'H',
#    'preferredUnit': '%'},
#   {'id': 135,
#    'name': 'um100',
#    'displayName': 'PM10 count',
#    'description': 'PM10 count',
#    'preferredUnit': 'particles/cm³'},
#   {'id': 150,
#    'name': 'voc',
#    'displayName': 'VOC',
#    'description': 'VOC',
#    'preferredUnit': 'iaq'},
#   {'id': 676,
#    'name': 'ozone',
#    'displayName': 'O₃',
#    'description': 'O₃',
#    'preferredUnit': 'ppb'},
#   {'id': 19840,
#    'name': 'nox',
#    'displayName': 'NOx',
#    'description': 'Nitrogen Oxides concentration',
#    'preferredUnit': 'ppm'},
#   {'id': 19841,
#    'name': 'bc',
#    'displayName': 'BC',
#    'description': 'BC',
#    'preferredUnit': 'ppm'},
#   {'id': 19843,
#    'name': 'no',
#    'displayName': 'NO mass',
#    'description': 'Nitrogen Monoxide mass concentration',
#    'preferredUnit': 'µg/m³'},
#   {'id': 19844,
#    'name': 'pm4',
#    'displayName': 'PM4.0',
#    'description': 'Particulate matter less than 4 micrometers in diameter mass concentration',
#    'preferredUnit': 'µg/m³'},
#   {'id': 19848,
#    'name': 'so4',
#    'displayName': 'SO4',
#    'description': 'Sulfate',
#    'preferredUnit': 'ppb'},
#   {'id': 19849,
#    'name': 'ec',
#    'displayName': 'EC',
#    'description': 'Elemental Carbon',
#    'preferredUnit': 'ppb'},
#   {'id': 19850,
#    'name': 'oc',
#    'displayName': 'OC',
#    'description': 'Organic Carbon',
#    'preferredUnit': 'ppb'},
#   {'id': 19851,
#    'name': 'cl',
#    'displayName': 'Cl',
#    'description': 'Chloride',
#    'preferredUnit': 'ppb'},
#   {'id': 19852,
#    'name': 'k',
#    'displayName': 'K',
#    'description': 'Potassium',
#    'preferredUnit': 'ppb'},
#   {'id': 19853,
#    'name': 'no3',
#    'displayName': 'NO3',
#    'description': 'Nitrite',
#    'preferredUnit': 'ppb'},
#   {'id': 19854,
#    'name': 'pb',
#    'displayName': 'Pb',
#    'description': 'Lead',
#    'preferredUnit': 'ppb'},
#   {'id': 19855,
#    'name': 'as',
#    'displayName': 'As',
#    'description': 'Arsenic',
#    'preferredUnit': 'ppb'},
#   {'id': 19856,
#    'name': 'ca',
#    'displayName': 'Ca',
#    'description': 'Calcium',
#    'preferredUnit': 'ppb'},
#   {'id': 19857,
#    'name': 'fe',
#    'displayName': 'Fe',
#    'description': 'Iron',
#    'preferredUnit': 'ppb'},
#   {'id': 19858,
#    'name': 'ni',
#    'displayName': 'Ni',
#    'description': 'Nickle',
#    'preferredUnit': 'ppb'},
#   {'id': 19859,
#    'name': 'v',
#    'displayName': 'V',
#    'description': 'Vanadium',
#    'preferredUnit': 'ppb'},
#   {'id': 19860,
#    'name': 'pm25',
#    'displayName': None,
#    'description': 'n/a',
#    'preferredUnit': 'ppm'}]}

# %% [markdown]
# Obtenir la liste des pays - ATTENTION V2 ET V3 DONNENT PAS LES MEMES RESULTATS

# %%
url_pays = "https://api.openaq.org/v3/countries"

p = {'parameters_id':2}

resp_pays = requests.get(url_pays, params=p, headers=header)

# %%
resp_pays.json()
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': '',
#   'website': '/',
#   'page': 1,
#   'limit': 100,
#   'found': '>100'},
#  'results': [{'code': 'AF',
#    'name': 'Afghanistan',
#    'locations': 2,
#    'firstUpdated': '2019-10-20 23:00:00+00',
#    'lastUpdated': '2021-08-16 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 23641,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'DZ',
#    'name': 'Algeria',
#    'locations': 1,
#    'firstUpdated': '2019-06-15 22:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['pm25'],
#    'count': 43413,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'AD',
#    'name': 'Andorra',
#    'locations': 2,
#    'firstUpdated': '2017-09-14 23:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 299562,
#    'cities': 2,
#    'sources': 1},
#   {'code': 'AQ',
#    'name': 'Antarctica',
#    'locations': 2,
#    'firstUpdated': '2018-11-30 11:00:00+00',
#    'lastUpdated': '2021-02-04 14:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 9180,
#    'cities': 0,
#    'sources': 2},
#   {'code': 'AR',
#    'name': 'Argentina',
#    'locations': 18,
#    'firstUpdated': '2016-01-01 03:00:00+00',
#    'lastUpdated': '2024-11-09 03:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 441707,
#    'cities': 1,
#    'sources': 6},
#   {'code': 'AM',
#    'name': 'Armenia',
#    'locations': 61,
#    'firstUpdated': '2022-11-14 09:00:00+00',
#    'lastUpdated': '2024-11-08 15:06:46.521+00',
#    'parameters': ['pm25'],
#    'count': 347256,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'AU',
#    'name': 'Australia',
#    'locations': 267,
#    'firstUpdated': '2016-01-28 19:00:00+00',
#    'lastUpdated': '2024-11-09 12:54:23+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 15725178,
#    'cities': 54,
#    'sources': 11},
#   {'code': 'AT',
#    'name': 'Austria',
#    'locations': 380,
#    'firstUpdated': '2016-11-18 05:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 14417718,
#    'cities': 161,
#    'sources': 4},
#   {'code': 'AZ',
#    'name': 'Azerbaijan',
#    'locations': 1,
#    'firstUpdated': '2022-06-23 13:00:00+00',
#    'lastUpdated': '2024-11-08 13:00:00+00',
#    'parameters': ['pm25'],
#    'count': 17561,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'BH',
#    'name': 'Bahrain',
#    'locations': 1,
#    'firstUpdated': '2016-12-01 22:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['o3', 'pm25'],
#    'count': 102421,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'BD',
#    'name': 'Bangladesh',
#    'locations': 3,
#    'firstUpdated': '2016-03-10 22:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 78510,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'BE',
#    'name': 'Belgium',
#    'locations': 174,
#    'firstUpdated': '2016-11-17 23:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 5212080,
#    'cities': 74,
#    'sources': 4},
#   {'code': 'BZ',
#    'name': 'Belize',
#    'locations': 1,
#    'firstUpdated': '2023-03-19 02:00:00+00',
#    'lastUpdated': '2024-06-25 07:00:00+00',
#    'parameters': ['pm25'],
#    'count': 9834,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'BA',
#    'name': 'Bosnia and Herzegovina',
#    'locations': 47,
#    'firstUpdated': '2016-04-26 22:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 1474478,
#    'cities': 22,
#    'sources': 6},
#   {'code': 'BR',
#    'name': 'Brazil',
#    'locations': 76,
#    'firstUpdated': '2017-07-01 00:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 3185466,
#    'cities': 39,
#    'sources': 5},
#   {'code': 'BG',
#    'name': 'Bulgaria',
#    'locations': 116,
#    'firstUpdated': '2020-04-20 18:00:00+00',
#    'lastUpdated': '2024-11-08 15:28:00+00',
#    'parameters': ['co',
#     'humidity',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pm4',
#     'pressure',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 203394929,
#    'cities': 18,
#    'sources': 3},
#   {'code': 'CM',
#    'name': 'Cameroon',
#    'locations': 2,
#    'firstUpdated': '2024-09-23 10:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 5628,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'CA',
#    'name': 'Canada',
#    'locations': 406,
#    'firstUpdated': '2016-03-06 20:00:00+00',
#    'lastUpdated': '2024-11-08 15:07:04.805+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 23557958,
#    'cities': 18,
#    'sources': 5},
#   {'code': 'TD',
#    'name': 'Chad',
#    'locations': 1,
#    'firstUpdated': '2020-08-02 20:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['pm25'],
#    'count': 33931,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'CL',
#    'name': 'Chile',
#    'locations': 180,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 14120732,
#    'cities': 65,
#    'sources': 2},
#   {'code': 'CN',
#    'name': 'China',
#    'locations': 1874,
#    'firstUpdated': '2016-01-01 01:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 168928220,
#    'cities': 7,
#    'sources': 16},
#   {'code': 'CO',
#    'name': 'Colombia',
#    'locations': 64,
#    'firstUpdated': '2016-03-17 15:00:00+00',
#    'lastUpdated': '2024-11-08 15:06:54.619+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 2597770,
#    'cities': 10,
#    'sources': 6},
#   {'code': 'CR',
#    'name': 'Costa Rica',
#    'locations': 2,
#    'firstUpdated': '2019-10-28 18:00:00+00',
#    'lastUpdated': '2024-11-08 14:56:59.745+00',
#    'parameters': ['pm25'],
#    'count': 40057,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'HR',
#    'name': 'Croatia',
#    'locations': 33,
#    'firstUpdated': '2016-11-17 22:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 1637473,
#    'cities': 18,
#    'sources': 4},
#   {'code': 'CW',
#    'name': 'Curaçao',
#    'locations': 1,
#    'firstUpdated': '2018-07-27 16:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['o3', 'pm25'],
#    'count': 83360,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'CY',
#    'name': 'Cyprus',
#    'locations': 12,
#    'firstUpdated': '2020-04-20 16:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 980117,
#    'cities': 11,
#    'sources': 3},
#   {'code': 'CZ',
#    'name': 'Czech Republic',
#    'locations': 123,
#    'firstUpdated': '2016-11-21 11:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 12180635,
#    'cities': 71,
#    'sources': 3},
#   {'code': 'CI',
#    'name': "Côte d'Ivoire",
#    'locations': 1,
#    'firstUpdated': '2020-03-15 21:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['pm25'],
#    'count': 34239,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'CD',
#    'name': 'Democratic Republic of the Congo',
#    'locations': 1,
#    'firstUpdated': '2022-06-16 17:00:00+00',
#    'lastUpdated': '2024-11-08 13:00:00+00',
#    'parameters': ['pm25'],
#    'count': 6390,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'DK',
#    'name': 'Denmark',
#    'locations': 21,
#    'firstUpdated': '2016-11-21 11:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 1062293,
#    'cities': 11,
#    'sources': 3},
#   {'code': '-99',
#    'name': 'Dhekelia',
#    'locations': 1,
#    'firstUpdated': '2023-03-19 01:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['no', 'no2', 'nox', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 73747,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'EC',
#    'name': 'Ecuador',
#    'locations': 10,
#    'firstUpdated': '2020-12-29 05:00:00+00',
#    'lastUpdated': '2024-09-25 23:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 108067,
#    'cities': 0,
#    'sources': 2},
#   {'code': 'EG',
#    'name': 'Egypt',
#    'locations': 2,
#    'firstUpdated': '2022-06-20 19:00:00+00',
#    'lastUpdated': '2024-11-08 13:00:00+00',
#    'parameters': ['pm25'],
#    'count': 15499,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'EE',
#    'name': 'Estonia',
#    'locations': 8,
#    'firstUpdated': '2020-04-20 20:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 344770,
#    'cities': 6,
#    'sources': 1},
#   {'code': 'ET',
#    'name': 'Ethiopia',
#    'locations': 3,
#    'firstUpdated': '2016-08-18 23:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['pm25'],
#    'count': 123255,
#    'cities': 2,
#    'sources': 2},
#   {'code': 'FI',
#    'name': 'Finland',
#    'locations': 82,
#    'firstUpdated': '2016-12-10 19:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 4689228,
#    'cities': 34,
#    'sources': 2},
#   {'code': 'FR',
#    'name': 'France',
#    'locations': 833,
#    'firstUpdated': '2016-11-21 11:00:00+00',
#    'lastUpdated': '2024-11-08 15:05:36.271+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 51590105,
#    'cities': 441,
#    'sources': 6},
#   {'code': 'DE',
#    'name': 'Germany',
#    'locations': 551,
#    'firstUpdated': '2016-11-21 11:00:00+00',
#    'lastUpdated': '2024-11-08 15:03:40.671+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 29252860,
#    'cities': 304,
#    'sources': 6},
#   {'code': 'GH',
#    'name': 'Ghana',
#    'locations': 28,
#    'firstUpdated': '2020-05-01 01:00:00+00',
#    'lastUpdated': '2024-11-08 15:07:00.432+00',
#    'parameters': ['no2',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 1634959,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'GI',
#    'name': 'Gibraltar',
#    'locations': 2,
#    'firstUpdated': '2016-12-10 20:00:00+00',
#    'lastUpdated': '2024-02-14 18:00:00+00',
#    'parameters': ['co', 'no2', 'pm10', 'pm25', 'so2'],
#    'count': 27602,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'GR',
#    'name': 'Greece',
#    'locations': 49,
#    'firstUpdated': '2020-04-20 18:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 2289140,
#    'cities': 8,
#    'sources': 3},
#   {'code': 'GT',
#    'name': 'Guatemala',
#    'locations': 2,
#    'firstUpdated': '2019-10-20 21:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['o3', 'pm10', 'pm25'],
#    'count': 114358,
#    'cities': 2,
#    'sources': 2},
#   {'code': 'GN',
#    'name': 'Guinea',
#    'locations': 1,
#    'firstUpdated': '2020-05-01 02:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['pm25'],
#    'count': 32905,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'GY',
#    'name': 'Guyana',
#    'locations': 1,
#    'firstUpdated': '2024-10-02 12:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 5298,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'HK',
#    'name': 'Hong Kong',
#    'locations': 15,
#    'firstUpdated': '2018-01-02 22:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 2852545,
#    'cities': 6,
#    'sources': 2},
#   {'code': 'HU',
#    'name': 'Hungary',
#    'locations': 101,
#    'firstUpdated': '2016-12-12 14:00:00+00',
#    'lastUpdated': '2024-11-08 23:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 6858874,
#    'cities': 63,
#    'sources': 3},
#   {'code': 'IS',
#    'name': 'Iceland',
#    'locations': 23,
#    'firstUpdated': '2020-02-28 01:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 805866,
#    'cities': 8,
#    'sources': 3},
#   {'code': 'IN',
#    'name': 'India',
#    'locations': 440,
#    'firstUpdated': '2016-01-30 00:30:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pressure',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003',
#     'wind_direction',
#     'wind_speed'],
#    'count': 43832981,
#    'cities': 2,
#    'sources': 12},
#   {'code': 'ID',
#    'name': 'Indonesia',
#    'locations': 282,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-11-08 15:02:07.552+00',
#    'parameters': ['bc',
#     'co2',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003',
#     'um025'],
#    'count': 45076309,
#    'cities': 2,
#    'sources': 7},
#   {'code': 'IQ',
#    'name': 'Iraq',
#    'locations': 2,
#    'firstUpdated': '2019-03-10 16:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['pm25'],
#    'count': 66665,
#    'cities': 2,
#    'sources': 2},
#   {'code': 'IE',
#    'name': 'Ireland',
#    'locations': 49,
#    'firstUpdated': '2016-12-10 21:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 1926930,
#    'cities': 7,
#    'sources': 3},
#   {'code': 'IL',
#    'name': 'Israel',
#    'locations': 120,
#    'firstUpdated': '2016-01-01 01:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 20938671,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'IT',
#    'name': 'Italy',
#    'locations': 749,
#    'firstUpdated': '2017-11-01 23:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 27882686,
#    'cities': 585,
#    'sources': 7},
#   {'code': 'JP',
#    'name': 'Japan',
#    'locations': 1600,
#    'firstUpdated': '2023-07-14 17:00:00+00',
#    'lastUpdated': '2024-11-08 15:02:08.372+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 61076206,
#    'cities': 1,
#    'sources': 4},
#   {'code': 'JE',
#    'name': 'Jersey',
#    'locations': 17,
#    'firstUpdated': '2024-06-10 14:00:00+00',
#    'lastUpdated': '2024-11-08 15:06:15.783+00',
#    'parameters': ['pm25'],
#    'count': 153707,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'JO',
#    'name': 'Jordan',
#    'locations': 3,
#    'firstUpdated': '2017-08-10 23:00:00+00',
#    'lastUpdated': '2024-11-08 13:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm25', 'so2'],
#    'count': 266466,
#    'cities': 2,
#    'sources': 3},
#   {'code': 'KZ',
#    'name': 'Kazakhstan',
#    'locations': 44,
#    'firstUpdated': '2018-07-27 17:00:00+00',
#    'lastUpdated': '2024-11-08 15:06:50.191+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 527759,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'KE',
#    'name': 'Kenya',
#    'locations': 6,
#    'firstUpdated': '2018-04-21 00:00:00+00',
#    'lastUpdated': '2024-11-08 15:06:02.536+00',
#    'parameters': ['no2',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 126139,
#    'cities': 1,
#    'sources': 4},
#   {'code': 'XK',
#    'name': 'Kosovo',
#    'locations': 25,
#    'firstUpdated': '2016-04-08 20:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 814298,
#    'cities': 13,
#    'sources': 4},
#   {'code': 'KW',
#    'name': 'Kuwait',
#    'locations': 1,
#    'firstUpdated': '2017-02-17 21:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['pm25'],
#    'count': 59651,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'KG',
#    'name': 'Kyrgyzstan',
#    'locations': 47,
#    'firstUpdated': '2019-03-08 20:00:00+00',
#    'lastUpdated': '2024-11-08 15:06:26.979+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 621212,
#    'cities': 2,
#    'sources': 4},
#   {'code': 'LA',
#    'name': 'Lao PDR',
#    'locations': 4,
#    'firstUpdated': '2019-06-16 02:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2', 'temperature'],
#    'count': 111034,
#    'cities': 2,
#    'sources': 4},
#   {'code': 'LV',
#    'name': 'Latvia',
#    'locations': 16,
#    'firstUpdated': '2017-09-22 10:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 554494,
#    'cities': 5,
#    'sources': 2},
#   {'code': 'LT',
#    'name': 'Lithuania',
#    'locations': 18,
#    'firstUpdated': '2017-09-21 23:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 1134078,
#    'cities': 14,
#    'sources': 2},
#   {'code': 'LU',
#    'name': 'Luxembourg',
#    'locations': 14,
#    'firstUpdated': '2017-09-22 10:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 1143646,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'MG',
#    'name': 'Madagascar',
#    'locations': 1,
#    'firstUpdated': '2020-12-22 07:00:00+00',
#    'lastUpdated': '2024-11-08 13:00:00+00',
#    'parameters': ['pm25'],
#    'count': 27356,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'MY',
#    'name': 'Malaysia',
#    'locations': 4,
#    'firstUpdated': '2022-11-03 21:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 48155,
#    'cities': 2,
#    'sources': 3},
#   {'code': 'MV',
#    'name': 'Maldives',
#    'locations': 1,
#    'firstUpdated': '2024-09-08 19:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 8556,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'ML',
#    'name': 'Mali',
#    'locations': 1,
#    'firstUpdated': '2020-03-16 05:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['pm25'],
#    'count': 29986,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'MT',
#    'name': 'Malta',
#    'locations': 8,
#    'firstUpdated': '2017-09-22 10:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 812948,
#    'cities': 5,
#    'sources': 2},
#   {'code': 'MU',
#    'name': 'Mauritius',
#    'locations': 1,
#    'firstUpdated': '2023-11-05 03:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 35634,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'MX',
#    'name': 'Mexico',
#    'locations': 249,
#    'firstUpdated': '2016-03-06 20:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 11943377,
#    'cities': 117,
#    'sources': 4},
#   {'code': 'MD',
#    'name': 'Moldova',
#    'locations': 2,
#    'firstUpdated': '2022-01-26 14:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 24626,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'MC',
#    'name': 'Monaco',
#    'locations': 1,
#    'firstUpdated': '2023-09-25 16:11:07+00',
#    'lastUpdated': '2023-09-25 16:46:07+00',
#    'parameters': ['pm25'],
#    'count': 36,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'MN',
#    'name': 'Mongolia',
#    'locations': 44,
#    'firstUpdated': '2016-01-30 00:15:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 2363727,
#    'cities': 23,
#    'sources': 4},
#   {'code': 'ME',
#    'name': 'Montenegro',
#    'locations': 9,
#    'firstUpdated': '2022-03-24 14:00:00+00',
#    'lastUpdated': '2024-03-19 22:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 273517,
#    'cities': 7,
#    'sources': 1},
#   {'code': 'MA',
#    'name': 'Morocco',
#    'locations': 3,
#    'firstUpdated': '2024-04-04 10:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 38418,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'MZ',
#    'name': 'Mozambique',
#    'locations': 2,
#    'firstUpdated': '2024-01-18 19:00:00+00',
#    'lastUpdated': '2024-11-08 13:00:00+00',
#    'parameters': ['o3', 'pm25'],
#    'count': 13098,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'MM',
#    'name': 'Myanmar',
#    'locations': 1,
#    'firstUpdated': '2019-06-16 08:00:00+00',
#    'lastUpdated': '2024-11-08 14:30:00+00',
#    'parameters': ['o3', 'pm25'],
#    'count': 56536,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'NP',
#    'name': 'Nepal',
#    'locations': 5,
#    'firstUpdated': '2017-03-03 00:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 304638,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'NL',
#    'name': 'Netherlands',
#    'locations': 115,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 14827981,
#    'cities': 51,
#    'sources': 3},
#   {'code': 'NZ',
#    'name': 'New Zealand',
#    'locations': 16,
#    'firstUpdated': '2023-03-30 17:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 254974,
#    'cities': 8,
#    'sources': 2},
#   {'code': 'NG',
#    'name': 'Nigeria',
#    'locations': 5,
#    'firstUpdated': '2019-04-26 08:00:00+00',
#    'lastUpdated': '2024-11-08 15:05:20.958+00',
#    'parameters': ['pm1', 'pm10', 'pm25', 'temperature'],
#    'count': 133877,
#    'cities': 2,
#    'sources': 3},
#   {'code': 'MK',
#    'name': 'North Macedonia',
#    'locations': 27,
#    'firstUpdated': '2016-12-10 20:00:00+00',
#    'lastUpdated': '2024-09-20 09:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 3097977,
#    'cities': 5,
#    'sources': 2},
#   {'code': 'NO',
#    'name': 'Norway',
#    'locations': 86,
#    'firstUpdated': '2016-12-02 10:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 6280266,
#    'cities': 27,
#    'sources': 3},
#   {'code': 'OM',
#    'name': 'Oman',
#    'locations': 2,
#    'firstUpdated': '2022-10-28 16:00:00+00',
#    'lastUpdated': '2024-05-20 14:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'so2'],
#    'count': 50231,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'PK',
#    'name': 'Pakistan',
#    'locations': 10,
#    'firstUpdated': '2019-05-22 22:00:00+00',
#    'lastUpdated': '2024-11-08 14:57:38.788+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 279553,
#    'cities': 2,
#    'sources': 4},
#   {'code': 'PS',
#    'name': 'Palestine',
#    'locations': 3,
#    'firstUpdated': '2017-08-10 23:00:00+00',
#    'lastUpdated': '2019-04-03 21:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'so2'],
#    'count': 481715,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'PY',
#    'name': 'Paraguay',
#    'locations': 1,
#    'firstUpdated': '2023-10-02 20:00:00+00',
#    'lastUpdated': '2024-11-08 14:00:00+00',
#    'parameters': ['pm25'],
#    'count': 9447,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'PE',
#    'name': 'Peru',
#    'locations': 51,
#    'firstUpdated': '2016-03-04 17:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 5817520,
#    'cities': 25,
#    'sources': 6},
#   {'code': 'PH',
#    'name': 'Philippines',
#    'locations': 11,
#    'firstUpdated': '2023-09-06 21:00:00+00',
#    'lastUpdated': '2024-11-08 15:04:50.635+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 95372,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'PL',
#    'name': 'Poland',
#    'locations': 340,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['bc',
#     'co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 28962540,
#    'cities': 199,
#    'sources': 4},
#   {'code': 'PT',
#    'name': 'Portugal',
#    'locations': 75,
#    'firstUpdated': '2017-09-21 23:00:00+00',
#    'lastUpdated': '2024-11-08 15:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 7834472,
#    'cities': 15,
#    'sources': 3},
#   {'code': 'PR',
#    'name': 'Puerto Rico',
#    'locations': 5,
#    'firstUpdated': '2016-05-04 12:00:00+00',
#    'lastUpdated': '2024-10-15 11:00:00+00',
#    'parameters': ['o3', 'pm10', 'pm25'],
#    'count': 108674,
#    'cities': 2,
#    'sources': 1},
#   {'code': 'QA',
#    'name': 'Qatar',
#    'locations': 1,
#    'firstUpdated': '2022-04-11 15:00:00+00',
#    'lastUpdated': '2024-11-08 13:00:00+00',
#    'parameters': ['o3', 'pm25'],
#    'count': 24699,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'CV',
#    'name': 'Republic of Cabo Verde',
#    'locations': 4,
#    'firstUpdated': '2024-04-24 15:07:35.089+00',
#    'lastUpdated': '2024-11-08 15:05:45.263+00',
#    'parameters': ['pm25'],
#    'count': 39358,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'KR',
#    'name': 'Republic of Korea',
#    'locations': 719,
#    'firstUpdated': '2020-10-12 06:00:00+00',
#    'lastUpdated': '2024-11-08 15:05:03.929+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 20609426,
#    'cities': 3,
#    'sources': 4},
#   {'code': 'RO',
#    'name': 'Romania',
#    'locations': 359,
#    'firstUpdated': '2020-04-19 21:00:00+00',
#    'lastUpdated': '2024-11-08 15:03:02.932+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 6640497,
#    'cities': 120,
#    'sources': 4},
#   {'code': 'RU',
#    'name': 'Russian Federation',
#    'locations': 49,
#    'firstUpdated': '2016-11-21 11:00:00+00',
#    'lastUpdated': '2021-08-09 11:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 306571,
#    'cities': 0,
#    'sources': 3},
#   {'code': 'RW',
#    'name': 'Rwanda',
#    'locations': 2,
#    'firstUpdated': '2020-12-28 23:00:00+00',
#    'lastUpdated': '2024-11-08 13:00:00+00',
#    'parameters': ['co', 'no2', 'pm10', 'pm25'],
#    'count': 128961,
#    'cities': 1,
#    'sources': 2}]}

# %% [markdown]
# On veut que la liste des pays et pas les métadonnées

# %%
liste_pays = resp_pays.json().get('results')

# %%
liste_pays
# Out:
# [{'id': 1,
#   'code': 'ID',
#   'name': 'Indonesia',
#   'datetimeFirst': '2016-01-30T01:00:00Z',
#   'datetimeLast': '2024-11-08T16:07:00.655Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 11, 'name': 'bc', 'units': 'µg/m³', 'displayName': None},
#    {'id': 15, 'name': 'no2', 'units': 'ppb', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 21, 'name': 'co2', 'units': 'ppm', 'displayName': None},
#    {'id': 24, 'name': 'no', 'units': 'ppb', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None},
#    {'id': 130,
#     'name': 'um025',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 2,
#   'code': 'MY',
#   'name': 'Malaysia',
#   'datetimeFirst': '2022-11-03T21:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 3,
#   'code': 'CL',
#   'name': 'Chile',
#   'datetimeFirst': '2016-01-30T01:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 5,
#   'code': 'PE',
#   'name': 'Peru',
#   'datetimeFirst': '2016-03-04T17:00:00Z',
#   'datetimeLast': '2024-11-08T15:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#    {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 6,
#   'code': 'AR',
#   'name': 'Argentina',
#   'datetimeFirst': '2016-01-01T03:00:00Z',
#   'datetimeLast': '2024-11-09T03:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 27, 'name': 'nox', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 7,
#   'code': '-99',
#   'name': 'Dhekelia',
#   'datetimeFirst': '2023-03-19T01:00:00Z',
#   'datetimeLast': '2024-11-08T15:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 27, 'name': 'nox', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 8,
#   'code': 'CY',
#   'name': 'Cyprus',
#   'datetimeFirst': '2020-04-20T16:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 27, 'name': 'nox', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 9,
#   'code': 'IN',
#   'name': 'India',
#   'datetimeFirst': '2016-01-30T00:30:00Z',
#   'datetimeLast': '2024-11-08T16:06:30.694Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 22, 'name': 'wind_direction', 'units': 'deg', 'displayName': None},
#    {'id': 34, 'name': 'wind_speed', 'units': 'm/s', 'displayName': None},
#    {'id': 95, 'name': 'pressure', 'units': 'hpa', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 102, 'name': 'co', 'units': 'ppb', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 10,
#   'code': 'CN',
#   'name': 'China',
#   'datetimeFirst': '2016-01-01T01:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 11,
#   'code': 'IL',
#   'name': 'Israel',
#   'datetimeFirst': '2016-01-01T01:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#    {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 15, 'name': 'no2', 'units': 'ppb', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 23, 'name': 'nox', 'units': 'ppb', 'displayName': None},
#    {'id': 24, 'name': 'no', 'units': 'ppb', 'displayName': None},
#    {'id': 32, 'name': 'o3', 'units': 'ppb', 'displayName': None},
#    {'id': 35, 'name': 'no', 'units': 'ppm', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 101, 'name': 'so2', 'units': 'ppb', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 19840, 'name': 'nox', 'units': 'ppm', 'displayName': None}]},
#  {'id': 12,
#   'code': 'PS',
#   'name': 'Palestine',
#   'datetimeFirst': '2017-08-10T23:00:00Z',
#   'datetimeLast': '2024-11-08T15:40:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#    {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 15, 'name': 'no2', 'units': 'ppb', 'displayName': None},
#    {'id': 23, 'name': 'nox', 'units': 'ppb', 'displayName': None},
#    {'id': 24, 'name': 'no', 'units': 'ppb', 'displayName': None},
#    {'id': 32, 'name': 'o3', 'units': 'ppb', 'displayName': None},
#    {'id': 35, 'name': 'no', 'units': 'ppm', 'displayName': None},
#    {'id': 101, 'name': 'so2', 'units': 'ppb', 'displayName': None},
#    {'id': 19840, 'name': 'nox', 'units': 'ppm', 'displayName': None}]},
#  {'id': 14,
#   'code': 'ET',
#   'name': 'Ethiopia',
#   'datetimeFirst': '2016-08-18T23:00:00Z',
#   'datetimeLast': '2024-11-08T15:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None}]},
#  {'id': 15,
#   'code': 'SS',
#   'name': 'South Sudan',
#   'datetimeFirst': '2024-09-13T15:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 17,
#   'code': 'KE',
#   'name': 'Kenya',
#   'datetimeFirst': '2018-04-21T00:00:00Z',
#   'datetimeLast': '2024-11-08T15:57:08.504Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 15, 'name': 'no2', 'units': 'ppb', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None}]},
#  {'id': 22,
#   'code': 'FR',
#   'name': 'France',
#   'datetimeFirst': '2016-11-21T11:00:00Z',
#   'datetimeLast': '2024-11-08T16:05:48.821Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 24,
#   'code': 'GY',
#   'name': 'Guyana',
#   'datetimeFirst': '2024-10-02T12:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 25,
#   'code': 'KR',
#   'name': 'Republic of Korea',
#   'datetimeFirst': '2020-10-12T06:00:00Z',
#   'datetimeLast': '2024-11-08T16:04:28.87Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#    {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 27,
#   'code': 'MA',
#   'name': 'Morocco',
#   'datetimeFirst': '2024-04-04T10:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 29,
#   'code': 'CR',
#   'name': 'Costa Rica',
#   'datetimeFirst': '2019-10-28T18:00:00Z',
#   'datetimeLast': '2024-11-08T16:06:54.352Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None}]},
#  {'id': 32,
#   'code': 'CD',
#   'name': 'Democratic Republic of the Congo',
#   'datetimeFirst': '2022-06-16T17:00:00Z',
#   'datetimeLast': '2024-11-08T14:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None}]},
#  {'id': 34,
#   'code': 'UA',
#   'name': 'Ukraine',
#   'datetimeFirst': '2023-09-12T17:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 37,
#   'code': 'ZA',
#   'name': 'South Africa',
#   'datetimeFirst': '2016-02-14T08:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#    {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 35, 'name': 'no', 'units': 'ppm', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None},
#    {'id': 19840, 'name': 'nox', 'units': 'ppm', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 38,
#   'code': 'MF',
#   'name': 'Saint-Martin',
#   'datetimeFirst': '2024-01-28T23:00:00Z',
#   'datetimeLast': '2024-11-08T14:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 41,
#   'code': 'UZ',
#   'name': 'Uzbekistan',
#   'datetimeFirst': '2018-11-27T22:00:00Z',
#   'datetimeLast': '2024-11-08T15:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None}]},
#  {'id': 42,
#   'code': 'KZ',
#   'name': 'Kazakhstan',
#   'datetimeFirst': '2018-07-27T17:00:00Z',
#   'datetimeLast': '2024-11-08T16:07:04.082Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 43,
#   'code': 'TJ',
#   'name': 'Tajikistan',
#   'datetimeFirst': '2019-10-20T23:00:00Z',
#   'datetimeLast': '2024-11-08T16:02:41.338Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None}]},
#  {'id': 44,
#   'code': 'LT',
#   'name': 'Lithuania',
#   'datetimeFirst': '2017-09-21T23:00:00Z',
#   'datetimeLast': '2024-11-08T14:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 45,
#   'code': 'BR',
#   'name': 'Brazil',
#   'datetimeFirst': '2017-07-01T00:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 27, 'name': 'nox', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 46,
#   'code': 'UY',
#   'name': 'Uruguay',
#   'datetimeFirst': '2023-10-19T22:00:00Z',
#   'datetimeLast': '2023-10-21T10:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None}]},
#  {'id': 47,
#   'code': 'MN',
#   'name': 'Mongolia',
#   'datetimeFirst': '2016-01-30T00:15:00Z',
#   'datetimeLast': '2024-11-08T15:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 48,
#   'code': 'RU',
#   'name': 'Russian Federation',
#   'datetimeFirst': '2016-11-21T11:00:00Z',
#   'datetimeLast': '2021-08-09T11:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 49,
#   'code': 'CZ',
#   'name': 'Czech Republic',
#   'datetimeFirst': '2016-11-21T11:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 50,
#   'code': 'DE',
#   'name': 'Germany',
#   'datetimeFirst': '2016-11-21T11:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 51,
#   'code': 'EE',
#   'name': 'Estonia',
#   'datetimeFirst': '2020-04-20T20:00:00Z',
#   'datetimeLast': '2024-11-08T14:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 52,
#   'code': 'LV',
#   'name': 'Latvia',
#   'datetimeFirst': '2017-09-22T10:00:00Z',
#   'datetimeLast': '2024-11-08T14:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 53,
#   'code': 'NO',
#   'name': 'Norway',
#   'datetimeFirst': '2016-12-02T10:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 54,
#   'code': 'SE',
#   'name': 'Sweden',
#   'datetimeFirst': '2017-02-08T01:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 55,
#   'code': 'FI',
#   'name': 'Finland',
#   'datetimeFirst': '2016-12-10T19:00:00Z',
#   'datetimeLast': '2024-11-08T14:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 56,
#   'code': 'VN',
#   'name': 'Vietnam',
#   'datetimeFirst': '2016-01-30T01:00:00Z',
#   'datetimeLast': '2024-11-08T15:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None}]},
#  {'id': 58,
#   'code': 'LU',
#   'name': 'Luxembourg',
#   'datetimeFirst': '2017-09-22T10:00:00Z',
#   'datetimeLast': '2024-11-08T14:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 59,
#   'code': 'AE',
#   'name': 'United Arab Emirates',
#   'datetimeFirst': '2019-11-25T17:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 60,
#   'code': 'BE',
#   'name': 'Belgium',
#   'datetimeFirst': '2016-11-17T23:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None}]},
#  {'id': 62,
#   'code': 'MK',
#   'name': 'North Macedonia',
#   'datetimeFirst': '2016-12-10T20:00:00Z',
#   'datetimeLast': '2024-09-20T09:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 64,
#   'code': 'AZ',
#   'name': 'Azerbaijan',
#   'datetimeFirst': '2022-06-23T13:00:00Z',
#   'datetimeLast': '2024-11-08T14:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None}]},
#  {'id': 65,
#   'code': 'XK',
#   'name': 'Kosovo',
#   'datetimeFirst': '2016-04-08T20:00:00Z',
#   'datetimeLast': '2024-11-08T15:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 66,
#   'code': 'TR',
#   'name': 'Turkey',
#   'datetimeFirst': '2016-12-12T06:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 15, 'name': 'no2', 'units': 'ppb', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 67,
#   'code': 'ES',
#   'name': 'Spain',
#   'datetimeFirst': '2016-11-17T23:00:00Z',
#   'datetimeLast': '2024-11-08T16:14:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 27, 'name': 'nox', 'units': 'µg/m³', 'displayName': None},
#    {'id': 95, 'name': 'pressure', 'units': 'hpa', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 134, 'name': 'humidity', 'units': '%', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19844, 'name': 'pm4', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 68,
#   'code': 'LA',
#   'name': 'Lao PDR',
#   'datetimeFirst': '2019-06-16T02:00:00Z',
#   'datetimeLast': '2024-11-08T15:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#    {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None}]},
#  {'id': 69,
#   'code': 'KG',
#   'name': 'Kyrgyzstan',
#   'datetimeFirst': '2019-03-08T20:00:00Z',
#   'datetimeLast': '2024-11-08T16:06:58.114Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None}]},
#  {'id': 121,
#   'code': 'MC',
#   'name': 'Monaco',
#   'datetimeFirst': '2023-09-25T16:11:07Z',
#   'datetimeLast': '2023-09-25T16:46:07Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None}]},
#  {'id': 122,
#   'code': 'DZ',
#   'name': 'Algeria',
#   'datetimeFirst': '2019-06-15T22:00:00Z',
#   'datetimeLast': '2024-11-08T15:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None}]},
#  {'id': 123,
#   'code': 'MZ',
#   'name': 'Mozambique',
#   'datetimeFirst': '2024-01-18T19:00:00Z',
#   'datetimeLast': '2024-11-08T14:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None}]},
#  {'id': 70,
#   'code': 'AM',
#   'name': 'Armenia',
#   'datetimeFirst': '2022-11-14T09:00:00Z',
#   'datetimeLast': '2024-11-08T16:06:54.702Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None}]},
#  {'id': 71,
#   'code': 'DK',
#   'name': 'Denmark',
#   'datetimeFirst': '2016-11-21T11:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 74,
#   'code': 'RO',
#   'name': 'Romania',
#   'datetimeFirst': '2020-04-19T21:00:00Z',
#   'datetimeLast': '2024-11-08T16:02:35.287Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None}]},
#  {'id': 75,
#   'code': 'HU',
#   'name': 'Hungary',
#   'datetimeFirst': '2016-12-12T14:00:00Z',
#   'datetimeLast': '2024-11-08T23:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 76,
#   'code': 'SK',
#   'name': 'Slovakia',
#   'datetimeFirst': '2016-11-18T05:00:00Z',
#   'datetimeLast': '2024-11-08T14:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 77,
#   'code': 'PL',
#   'name': 'Poland',
#   'datetimeFirst': '2016-01-30T01:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 11, 'name': 'bc', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 78,
#   'code': 'IE',
#   'name': 'Ireland',
#   'datetimeFirst': '2016-12-10T21:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 79,
#   'code': 'GB',
#   'name': 'United Kingdom',
#   'datetimeFirst': '2016-01-30T01:00:00Z',
#   'datetimeLast': '2024-11-08T16:03:46.977Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 21, 'name': 'co2', 'units': 'ppm', 'displayName': None},
#    {'id': 27, 'name': 'nox', 'units': 'µg/m³', 'displayName': None},
#    {'id': 35, 'name': 'no', 'units': 'ppm', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 80,
#   'code': 'GR',
#   'name': 'Greece',
#   'datetimeFirst': '2020-04-20T18:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 81,
#   'code': 'ZM',
#   'name': 'Zambia',
#   'datetimeFirst': '2024-09-01T17:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 83,
#   'code': 'GN',
#   'name': 'Guinea',
#   'datetimeFirst': '2020-05-01T02:00:00Z',
#   'datetimeLast': '2024-11-08T15:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None}]},
#  {'id': 86,
#   'code': 'SD',
#   'name': 'Sudan',
#   'datetimeFirst': '2020-05-14T14:00:00Z',
#   'datetimeLast': '2024-11-06T12:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 89,
#   'code': 'AT',
#   'name': 'Austria',
#   'datetimeFirst': '2016-11-18T05:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
# ...
#   'datetimeFirst': '2016-11-17T22:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 15, 'name': 'no2', 'units': 'ppb', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 24, 'name': 'no', 'units': 'ppb', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 101, 'name': 'so2', 'units': 'ppb', 'displayName': None},
#    {'id': 102, 'name': 'co', 'units': 'ppb', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 104,
#   'code': 'SI',
#   'name': 'Slovenia',
#   'datetimeFirst': '2016-11-17T22:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 105,
#   'code': 'QA',
#   'name': 'Qatar',
#   'datetimeFirst': '2022-04-11T15:00:00Z',
#   'datetimeLast': '2024-11-08T14:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None}]},
#  {'id': 106,
#   'code': 'SA',
#   'name': 'Saudi Arabia',
#   'datetimeFirst': '2019-07-15T19:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 109,
#   'code': 'PK',
#   'name': 'Pakistan',
#   'datetimeFirst': '2019-05-22T22:00:00Z',
#   'datetimeLast': '2024-11-08T16:06:59.493Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None}]},
#  {'id': 110,
#   'code': 'BG',
#   'name': 'Bulgaria',
#   'datetimeFirst': '2020-04-20T18:00:00Z',
#   'datetimeLast': '2024-11-08T16:14:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 15, 'name': 'no2', 'units': 'ppb', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 95, 'name': 'pressure', 'units': 'hpa', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 101, 'name': 'so2', 'units': 'ppb', 'displayName': None},
#    {'id': 102, 'name': 'co', 'units': 'ppb', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None},
#    {'id': 132, 'name': 'pressure', 'units': 'mb', 'displayName': None},
#    {'id': 134, 'name': 'humidity', 'units': '%', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19844, 'name': 'pm4', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 111,
#   'code': 'TH',
#   'name': 'Thailand',
#   'datetimeFirst': '2016-01-30T01:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#    {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125, 'name': 'um003', 'units': 'particles/cm³', 'displayName': None},
#    {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None}]},
#  {'id': 115,
#   'code': 'TD',
#   'name': 'Chad',
#   'datetimeFirst': '2020-08-02T20:00:00Z',
#   'datetimeLast': '2024-11-08T15:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None}]},
#  {'id': 116,
#   'code': 'KW',
#   'name': 'Kuwait',
#   'datetimeFirst': '2017-02-17T21:00:00Z',
#   'datetimeLast': '2024-11-08T15:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None}]},
#  {'id': 199,
#   'code': 'TT',
#   'name': 'Trinidad and Tobago',
#   'datetimeFirst': '2023-03-30T10:00:00Z',
#   'datetimeLast': '2024-11-08T14:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 118,
#   'code': 'GT',
#   'name': 'Guatemala',
#   'datetimeFirst': '2019-10-20T21:00:00Z',
#   'datetimeLast': '2024-11-08T15:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None}]},
#  {'id': 126,
#   'code': 'RW',
#   'name': 'Rwanda',
#   'datetimeFirst': '2020-12-28T23:00:00Z',
#   'datetimeLast': '2024-11-08T14:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None}]},
#  {'id': 127,
#   'code': 'MM',
#   'name': 'Myanmar',
#   'datetimeFirst': '2019-06-16T08:00:00Z',
#   'datetimeLast': '2024-11-08T15:30:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None}]},
#  {'id': 128,
#   'code': 'BD',
#   'name': 'Bangladesh',
#   'datetimeFirst': '2016-03-10T22:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 129,
#   'code': 'AD',
#   'name': 'Andorra',
#   'datetimeFirst': '2017-09-14T23:00:00Z',
#   'datetimeLast': '2024-11-08T14:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 130,
#   'code': 'AF',
#   'name': 'Afghanistan',
#   'datetimeFirst': '2019-10-20T23:00:00Z',
#   'datetimeLast': '2021-08-16T18:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None}]},
#  {'id': 131,
#   'code': 'ME',
#   'name': 'Montenegro',
#   'datetimeFirst': '2022-03-24T14:00:00Z',
#   'datetimeLast': '2024-03-19T22:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}]},
#  {'id': 132,
#   'code': 'BA',
#   'name': 'Bosnia and Herzegovina',
#   'datetimeFirst': '2016-04-26T22:00:00Z',
#   'datetimeLast': '2024-11-08T15:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 133,
#   'code': 'UG',
#   'name': 'Uganda',
#   'datetimeFirst': '2017-02-18T02:00:00Z',
#   'datetimeLast': '2024-11-08T15:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None}]},
#  {'id': 137,
#   'code': 'EC',
#   'name': 'Ecuador',
#   'datetimeFirst': '2020-12-29T05:00:00Z',
#   'datetimeLast': '2024-09-25T23:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#    {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 138,
#   'code': 'CO',
#   'name': 'Colombia',
#   'datetimeFirst': '2016-03-17T15:00:00Z',
#   'datetimeLast': '2024-11-08T16:05:42.248Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#    {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 139,
#   'code': 'PY',
#   'name': 'Paraguay',
#   'datetimeFirst': '2023-10-02T20:00:00Z',
#   'datetimeLast': '2024-11-08T14:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None}]},
#  {'id': 141,
#   'code': 'PT',
#   'name': 'Portugal',
#   'datetimeFirst': '2017-09-21T23:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#    {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#    {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 142,
#   'code': 'MD',
#   'name': 'Moldova',
#   'datetimeFirst': '2022-01-26T14:00:00Z',
#   'datetimeLast': '2024-11-08T16:00:00Z',
#   'parameters': [{'id': 1,
#     'name': 'pm10',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#    {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#    {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#    {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#    {'id': 125,
#     'name': 'um003',
#     'units': 'particles/cm³',
#     'displayName': None}]},
#  {'id': 143,
#   'code': 'TM',
#   'name': 'Turkmenistan',
#   'datetimeFirst': '2019-10-20T22:00:00Z',
#   'datetimeLast': '2024-11-08T15:00:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None}]},
#  {'id': 144,
#   'code': 'JO',
#   'name': 'Jordan',
#   'datetimeFirst': '2017-08-10T23:00:00Z',
#   'datetimeLast': '2024-11-08T15:40:00Z',
#   'parameters': [{'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#    {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#    {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#    {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#    {'id': 35, 'name': 'no', 'units': 'ppm', 'displayName': None},
#    {'id': 19840, 'name': 'nox', 'units': 'ppm', 'displayName': None}]}]

# %%
df = pd.DataFrame(liste_pays)

# %%
df[df["name"]=='France']
# Out:
#     id code    name         datetimeFirst              datetimeLast  \
# 14  22   FR  France  2016-11-21T11:00:00Z  2024-11-08T16:05:48.821Z
#
#                                            parameters
# 14  [{'id': 1, 'name': 'pm10', 'units': 'µg/m³', '...

# %%
url_pays = "https://api.openaq.org/v2/countries/92"


resp_pays = requests.get(url_pays, headers=header)

# %%
resp_pays.json()
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': '',
#   'website': '/',
#   'page': 1,
#   'limit': 100,
#   'found': 1},
#  'results': [{'code': 'CH',
#    'name': 'Switzerland',
#    'locations': 64,
#    'firstUpdated': '2016-11-18 05:00:00+00',
#    'lastUpdated': '2024-11-08 16:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 4224292,
#    'cities': 13,
#    'sources': 4}]}

# %% [markdown]
# Stations de mesures en Suisse

# %%
url_locations = "https://api.openaq.org/v3/locations"
p = {'countries_id': ['92']}

#, 'parameters_id':2
resp_locations = requests.get(url_locations, params=p,  headers=header)

# %%
resp_locations.json()
# Out:
# {'meta': {'name': 'openaq-api',
#   'website': '/',
#   'page': 1,
#   'limit': 100,
#   'found': 64},
#  'results': [{'id': 2819,
#    'name': 'Lustenau Zollamt',
#    'locality': None,
#    'timezone': 'Europe/Vienna',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 171, 'name': 'EEA Austria'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 5889,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}}],
#    'coordinates': {'latitude': 47.43251800890822,
#     'longitude': 9.649433287426664},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-18',
#      'dateTo': None}],
#    'bounds': [9.649433287426664,
#     47.43251800890822,
#     9.649433287426664,
#     47.43251800890822],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-11-18T05:00:00Z',
#     'local': '2016-11-18T06:00:00+01:00'},
#    'datetimeLast': {'utc': '2016-12-12T09:00:00Z',
#     'local': '2016-12-12T10:00:00+01:00'}},
#   {'id': 4467,
#    'name': 'Konstanz',
#    'locality': 'Konstanz',
#    'timezone': 'Europe/Berlin',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4274465,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}},
#     {'id': 11049,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 11050,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 11051,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 1300259,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}}],
#    'coordinates': {'latitude': 47.66436099999235,
#     'longitude': 9.169288999852993},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-17',
#      'dateTo': None}],
#    'bounds': [9.169288999852993,
#     47.66436099999235,
#     9.169288999852993,
#     47.66436099999235],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-11-25T04:00:00Z',
#     'local': '2016-11-25T05:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-11-08T13:00:00Z',
#     'local': '2024-11-08T14:00:00+01:00'}},
#   {'id': 4494,
#    'name': 'Weil am Rhein',
#    'locality': 'Weil am Rhein',
#    'timezone': 'Europe/Berlin',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4275258,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}},
#     {'id': 11568,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 11560,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 11115,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 1300231,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}}],
#    'coordinates': {'latitude': 47.58815199972278,
#     'longitude': 7.63327099993656},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-17',
#      'dateTo': None}],
#    'bounds': [7.63327099993656,
#     47.58815199972278,
#     7.63327099993656,
#     47.58815199972278],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-11-25T04:00:00Z',
#     'local': '2016-11-25T05:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-11-08T14:00:00Z',
#     'local': '2024-11-08T15:00:00+01:00'}},
#   {'id': 5376,
#    'name': 'CH0016A',
#    'locality': None,
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 198, 'name': 'EEA Switzerland'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 13978,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 13979,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}}],
#    'coordinates': {'latitude': 47.4781951524703,
#     'longitude': 8.36436632403517},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2017-09-21',
#      'dateTo': None}],
#    'bounds': [8.36436632403517,
#     47.4781951524703,
#     8.36436632403517,
#     47.4781951524703],
#    'distance': None,
#    'datetimeFirst': {'utc': '2017-09-22T07:00:00Z',
#     'local': '2017-09-22T09:00:00+02:00'},
#    'datetimeLast': {'utc': '2018-01-08T13:00:00Z',
#     'local': '2018-01-08T14:00:00+01:00'}},
#   {'id': 5595,
#    'name': 'CH0041A',
#    'locality': None,
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 198, 'name': 'EEA Switzerland'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 29483,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 29482,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 14809,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 29481,
#      'name': 'so2 µg/m³',
#      'parameter': {'id': 6,
#       'name': 'so2',
#       'units': 'µg/m³',
#       'displayName': 'SO₂ mass'}}],
#    'coordinates': {'latitude': 46.9763828250552,
#     'longitude': 7.47871728542173},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2017-09-21',
#      'dateTo': None}],
#    'bounds': [7.47871728542173,
#     46.9763828250552,
#     7.47871728542173,
#     46.9763828250552],
#    'distance': None,
#    'datetimeFirst': {'utc': '2017-09-21T23:00:00Z',
#     'local': '2017-09-22T01:00:00+02:00'},
#    'datetimeLast': {'utc': '2021-05-18T06:00:00Z',
#     'local': '2021-05-18T08:00:00+02:00'}},
#   {'id': 5734,
#    'name': 'Basel-Binningen',
#    'locality': 'Nationales Beobachtungsnetz für Luftfremdstoffe',
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 15471,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 15472,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 15456,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 15470,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 15469,
#      'name': 'so2 µg/m³',
#      'parameter': {'id': 6,
#       'name': 'so2',
#       'units': 'µg/m³',
#       'displayName': 'SO₂ mass'}}],
#    'coordinates': {'latitude': 47.54110000003129,
#     'longitude': 7.58327999961538},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-17',
#      'dateTo': None}],
#    'bounds': [7.58327999961538,
#     47.54110000003129,
#     7.58327999961538,
#     47.54110000003129],
#    'distance': None,
#    'datetimeFirst': {'utc': '2017-09-22T07:00:00Z',
#     'local': '2017-09-22T09:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T14:00:00Z',
#     'local': '2024-11-08T15:00:00+01:00'}},
#   {'id': 5735,
#    'name': 'Ebikon-Sedel',
#    'locality': 'inLUFT',
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 1180418,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 15458,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 15481,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 47.067700000042095,
#     'longitude': 8.30067999965945},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-17',
#      'dateTo': None}],
#    'bounds': [8.30067999965945,
#     47.067700000042095,
#     8.30067999965945,
#     47.067700000042095],
#    'distance': None,
#    'datetimeFirst': {'utc': '2017-09-22T07:00:00Z',
#     'local': '2017-09-22T09:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T14:00:00Z',
#     'local': '2024-11-08T15:00:00+01:00'}},
#   {'id': 5736,
#    'name': 'Opfikon-Balsberg',
#    'locality': 'OSTLUFT',
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 15484,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 15459,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 15466,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 47.43870000028494,
#     'longitude': 8.57011999966538},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-17',
#      'dateTo': None}],
#    'bounds': [8.57011999966538,
#     47.43870000028494,
#     8.57011999966538,
#     47.43870000028494],
#    'distance': None,
#    'datetimeFirst': {'utc': '2017-09-22T07:00:00Z',
#     'local': '2017-09-22T09:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T14:00:00Z',
#     'local': '2024-11-08T15:00:00+01:00'}},
#   {'id': 5737,
#    'name': 'Zürich-Schimmelstrasse',
#    'locality': 'OSTLUFT',
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 15467,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 15465,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 15463,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 8622699,
#      'name': 'so2 µg/m³',
#      'parameter': {'id': 6,
#       'name': 'so2',
#       'units': 'µg/m³',
#       'displayName': 'SO₂ mass'}}],
#    'coordinates': {'latitude': 47.37089999996605,
#     'longitude': 8.52354000039437},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-17',
#      'dateTo': None}],
#    'bounds': [8.52354000039437,
#     47.37089999996605,
#     8.52354000039437,
#     47.37089999996605],
#    'distance': None,
#    'datetimeFirst': {'utc': '2017-09-22T07:00:00Z',
#     'local': '2017-09-22T09:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T13:00:00Z',
#     'local': '2024-11-08T14:00:00+01:00'}},
#   {'id': 5738,
#    'name': 'Saxon',
#    'locality': 'Canton du Valais',
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 15478,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 15474,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 15475,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 46.138999999734644,
#     'longitude': 7.148329999799844},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-17',
#      'dateTo': None}],
#    'bounds': [7.148329999799844,
#     46.138999999734644,
#     7.148329999799844,
#     46.138999999734644],
#    'distance': None,
#    'datetimeFirst': {'utc': '2017-09-22T07:00:00Z',
#     'local': '2017-09-22T09:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T14:00:00Z',
#     'local': '2024-11-08T15:00:00+01:00'}},
#   {'id': 9577,
#    'name': 'Avully-Passeiry',
#    'locality': 'Canton de Genève',
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 29471,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 29470,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 29469,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 46.16259999999076,
#     'longitude': 6.005179999802816},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-17',
#      'dateTo': None}],
#    'bounds': [6.005179999802816,
#     46.16259999999076,
#     6.005179999802816,
#     46.16259999999076],
#    'distance': None,
#    'datetimeFirst': {'utc': '2017-09-22T07:00:00Z',
#     'local': '2017-09-22T09:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T14:00:00Z',
#     'local': '2024-11-08T15:00:00+01:00'}},
#   {'id': 9578,
#    'name': 'Meyrin-Vaudagne',
#    'locality': 'Canton de Genève',
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 29474,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 29473,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 29472,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 46.231100000206006,
#     'longitude': 6.074170000073853},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-17',
#      'dateTo': None}],
#    'bounds': [6.074170000073853,
#     46.231100000206006,
#     6.074170000073853,
#     46.231100000206006],
#    'distance': None,
#    'datetimeFirst': {'utc': '2017-09-22T07:00:00Z',
#     'local': '2017-09-22T09:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T14:00:00Z',
#     'local': '2024-11-08T15:00:00+01:00'}},
#   {'id': 9580,
#    'name': 'CH0043A',
#    'locality': 'Ticino',
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 198, 'name': 'EEA Switzerland'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 29480,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 29479,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 29478,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 46.02589572569159,
#     'longitude': 8.96752215525154},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2017-09-21',
#      'dateTo': None}],
#    'bounds': [8.96752215525154,
#     46.02589572569159,
#     8.96752215525154,
#     46.02589572569159],
#    'distance': None,
#    'datetimeFirst': {'utc': '2017-09-22T07:00:00Z',
#     'local': '2017-09-22T09:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-01-29T20:00:00Z',
#     'local': '2024-01-29T21:00:00+01:00'}},
#   {'id': 9581,
#    'name': 'Magadino-Cadenazzo',
#    'locality': 'Nationales Beobachtungsnetz für Luftfremdstoffe',
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 29488,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 29487,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 29486,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 29485,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 29484,
#      'name': 'so2 µg/m³',
#      'parameter': {'id': 6,
#       'name': 'so2',
#       'units': 'µg/m³',
#       'displayName': 'SO₂ mass'}}],
#    'coordinates': {'latitude': 46.16030000011032,
#     'longitude': 8.933940000200698},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-17',
#      'dateTo': None}],
#    'bounds': [8.933940000200698,
#     46.16030000011032,
#     8.933940000200698,
#     46.16030000011032],
#    'distance': None,
#    'datetimeFirst': {'utc': '2017-09-22T07:00:00Z',
#     'local': '2017-09-22T09:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T14:00:00Z',
#     'local': '2024-11-08T15:00:00+01:00'}},
#   {'id': 9582,
#    'name': 'Bern-Bollwerk',
#    'locality': 'Nationales Beobachtungsnetz für Luftfremdstoffe',
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 29493,
#      'name': 'co µg/m³',
#      'parameter': {'id': 4,
#       'name': 'co',
#       'units': 'µg/m³',
#       'displayName': 'CO mass'}},
#     {'id': 29492,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 29491,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 29490,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 29489,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}}],
#    'coordinates': {'latitude': 46.95100000021143,
#     'longitude': 7.440870000368799},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-17',
#      'dateTo': None}],
#    'bounds': [7.440870000368799,
#     46.95100000021143,
#     7.440870000368799,
#     46.95100000021143],
#    'distance': None,
#    'datetimeFirst': {'utc': '2017-09-22T07:00:00Z',
#     'local': '2017-09-22T09:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T14:00:00Z',
#     'local': '2024-11-08T15:00:00+01:00'}},
#   {'id': 9583,
#    'name': 'Basel-Feldbergstrasse',
#    'locality': None,
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 29495,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 29494,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 47.566999999575025,
#     'longitude': 7.594709999797136},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-17',
#      'dateTo': None}],
#    'bounds': [7.594709999797136,
#     47.566999999575025,
#     7.594709999797136,
#     47.566999999575025],
#    'distance': None,
#    'datetimeFirst': {'utc': '2018-01-24T23:00:00Z',
#     'local': '2018-01-25T00:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-05-30T08:00:00Z',
#     'local': '2024-05-30T10:00:00+02:00'}},
#   {'id': 9584,
#    'name': 'Lausanne-César-Roux',
#    'locality': 'Nationales Beobachtungsnetz für Luftfremdstoffe',
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 29499,
#      'name': 'co µg/m³',
#      'parameter': {'id': 4,
#       'name': 'co',
#       'units': 'µg/m³',
#       'displayName': 'CO mass'}},
#     {'id': 29498,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 29497,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 29496,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 46.52199999998234,
#     'longitude': 6.639630000397568},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-17',
#      'dateTo': None}],
#    'bounds': [6.639630000397568,
#     46.52199999998234,
#     6.639630000397568,
#     46.52199999998234],
#    'distance': None,
#    'datetimeFirst': {'utc': '2017-09-22T07:00:00Z',
#     'local': '2017-09-22T09:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T14:00:00Z',
#     'local': '2024-11-08T15:00:00+01:00'}},
#   {'id': 9585,
#    'name': 'CH0019A',
#    'locality': 'Sankt Gallen',
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 198, 'name': 'EEA Switzerland'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 29502,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 29501,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 29500,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 47.4069895689662,
#     'longitude': 9.39431174673672},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2017-09-21',
#      'dateTo': None}],
#    'bounds': [9.39431174673672,
#     47.4069895689662,
#     9.39431174673672,
#     47.4069895689662],
#    'distance': None,
#    'datetimeFirst': {'utc': '2017-09-22T07:00:00Z',
#     'local': '2017-09-22T09:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-01-29T20:00:00Z',
#     'local': '2024-01-29T21:00:00+01:00'}},
#   {'id': 9586,
#    'name': 'Basel-St-Johann',
#    'locality': 'Beide Basel',
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 29505,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 29504,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 29503,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 47.56590000002686,
#     'longitude': 7.58208000041445},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-17',
#      'dateTo': None}],
#    'bounds': [7.58208000041445,
#     47.56590000002686,
#     7.58208000041445,
#     47.56590000002686],
#    'distance': None,
#    'datetimeFirst': {'utc': '2017-09-22T07:00:00Z',
#     'local': '2017-09-22T09:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T14:00:00Z',
#     'local': '2024-11-08T15:00:00+01:00'}},
#   {'id': 9587,
#    'name': 'Zürich-Stampfenbachstrasse',
#    'locality': 'OSTLUFT',
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 29510,
#      'name': 'co µg/m³',
#      'parameter': {'id': 4,
#       'name': 'co',
#       'units': 'µg/m³',
#       'displayName': 'CO mass'}},
#     {'id': 29509,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 29508,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 29507,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 29506,
#      'name': 'so2 µg/m³',
#      'parameter': {'id': 6,
#       'name': 'so2',
#       'units': 'µg/m³',
#       'displayName': 'SO₂ mass'}}],
#    'coordinates': {'latitude': 47.38679999983631,
#     'longitude': 8.539810000257768},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-17',
#      'dateTo': None}],
#    'bounds': [8.539810000257768,
#     47.38679999983631,
#     8.539810000257768,
#     47.38679999983631],
#    'distance': None,
#    'datetimeFirst': {'utc': '2017-09-22T07:00:00Z',
#     'local': '2017-09-22T09:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T14:00:00Z',
#     'local': '2024-11-08T15:00:00+01:00'}},
#   {'id': 9588,
#    'name': 'Lugano-Università',
#    'locality': 'Nationales Beobachtungsnetz für Luftfremdstoffe',
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 29516,
#      'name': 'co µg/m³',
#      'parameter': {'id': 4,
#       'name': 'co',
#       'units': 'µg/m³',
#       'displayName': 'CO mass'}},
#     {'id': 29515,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 29514,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 29513,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 29512,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 29511,
#      'name': 'so2 µg/m³',
#      'parameter': {'id': 6,
#       'name': 'so2',
#       'units': 'µg/m³',
#       'displayName': 'SO₂ mass'}}],
#    'coordinates': {'latitude': 46.01110000001776,
#     'longitude': 8.957100000139862},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-17',
#      'dateTo': None}],
#    'bounds': [8.957100000139862,
#     46.01110000001776,
#     8.957100000139862,
#     46.01110000001776],
#    'distance': None,
#    'datetimeFirst': {'utc': '2017-09-22T07:00:00Z',
#     'local': '2017-09-22T09:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T14:00:00Z',
#     'local': '2024-11-08T15:00:00+01:00'}},
#   {'id': 9589,
#    'name': 'Zürich-Kaserne',
#    'locality': 'Nationales Beobachtungsnetz für Luftfremdstoffe',
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 29522,
#      'name': 'co µg/m³',
#      'parameter': {'id': 4,
#       'name': 'co',
#       'units': 'µg/m³',
#       'displayName': 'CO mass'}},
#     {'id': 29521,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 29520,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 29519,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 29518,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 29517,
#      'name': 'so2 µg/m³',
#      'parameter': {'id': 6,
#       'name': 'so2',
#       'units': 'µg/m³',
#       'displayName': 'SO₂ mass'}}],
#    'coordinates': {'latitude': 47.377600000102944,
#     'longitude': 8.530410000378652},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-17',
#      'dateTo': None}],
#    'bounds': [8.530410000378652,
#     47.377600000102944,
#     8.530410000378652,
#     47.377600000102944],
#    'distance': None,
#    'datetimeFirst': {'utc': '2017-09-22T07:00:00Z',
#     'local': '2017-09-22T09:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T14:00:00Z',
#     'local': '2024-11-08T15:00:00+01:00'}},
#   {'id': 9590,
#    'name': 'Rigi-Seebodenalp',
#    'locality': 'Nationales Beobachtungsnetz für Luftfremdstoffe',
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 29531,
#      'name': 'co µg/m³',
#      'parameter': {'id': 4,
#       'name': 'co',
#       'units': 'µg/m³',
#       'displayName': 'CO mass'}},
#     {'id': 29527,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 29526,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 29525,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 29524,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 29523,
#      'name': 'so2 µg/m³',
#      'parameter': {'id': 6,
#       'name': 'so2',
#       'units': 'µg/m³',
#       'displayName': 'SO₂ mass'}}],
#    'coordinates': {'latitude': 47.06739999978191,
#     'longitude': 8.463329999861337},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-17',
#      'dateTo': None}],
#    'bounds': [8.463329999861337,
#     47.06739999978191,
#     8.463329999861337,
#     47.06739999978191],
#    'distance': None,
#    'datetimeFirst': {'utc': '2017-09-22T07:00:00Z',
#     'local': '2017-09-22T09:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T14:00:00Z',
#     'local': '2024-11-08T15:00:00+01:00'}},
#   {'id': 9591,
#    'name': 'Dübendorf-EMPA',
#    'locality': 'Nationales Beobachtungsnetz für Luftfremdstoffe',
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 29539,
#      'name': 'co µg/m³',
#      'parameter': {'id': 4,
#       'name': 'co',
#       'units': 'µg/m³',
#       'displayName': 'CO mass'}},
#     {'id': 29537,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 29535,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 29534,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 29533,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 29532,
#      'name': 'so2 µg/m³',
#      'parameter': {'id': 6,
#       'name': 'so2',
#       'units': 'µg/m³',
#       'displayName': 'SO₂ mass'}}],
#    'coordinates': {'latitude': 47.4028999998603,
#     'longitude': 8.613400000010936},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-17',
#      'dateTo': None}],
#    'bounds': [8.613400000010936,
#     47.4028999998603,
#     8.613400000010936,
#     47.4028999998603],
#    'distance': None,
#    'datetimeFirst': {'utc': '2017-09-22T07:00:00Z',
#     'local': '2017-09-22T09:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T14:00:00Z',
#     'local': '2024-11-08T15:00:00+01:00'}},
#   {'id': 9593,
#    'name': 'Chaumont',
#    'locality': 'Nationales Beobachtungsnetz für Luftfremdstoffe',
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 29542,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 29541,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 29540,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 47.049500000117035,
#     'longitude': 6.979150000270615},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-17',
#      'dateTo': None}],
#    'bounds': [6.979150000270615,
#     47.049500000117035,
#     6.979150000270615,
#     47.049500000117035],
#    'distance': None,
#    'datetimeFirst': {'utc': '2017-09-22T06:00:00Z',
#     'local': '2017-09-22T08:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T14:00:00Z',
#     'local': '2024-11-08T15:00:00+01:00'}},
#   {'id': 9594,
#    'name': 'Tänikon',
#    'locality': 'Nationales Beobachtungsnetz für Luftfremdstoffe',
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 5079021,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 5078480,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 5078338,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 47.47979999984894,
#     'longitude': 8.904680000206188},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-17',
#      'dateTo': None}],
#    'bounds': [8.904680000206188,
#     47.47979999984894,
#     8.904680000206188,
#     47.47979999984894],
#    'distance': None,
#    'datetimeFirst': {'utc': '2023-05-06T00:00:00Z',
#     'local': '2023-05-06T02:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T14:00:00Z',
#     'local': '2024-11-08T15:00:00+01:00'}},
#   {'id': 9595,
#    'name': 'Payerne',
#    'locality': 'Nationales Beobachtungsnetz für Luftfremdstoffe',
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 29553,
#      'name': 'co µg/m³',
#      'parameter': {'id': 4,
#       'name': 'co',
#       'units': 'µg/m³',
#       'displayName': 'CO mass'}},
#     {'id': 29552,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 29551,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 29549,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 29548,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 29547,
#      'name': 'so2 µg/m³',
#      'parameter': {'id': 6,
#       'name': 'so2',
#       'units': 'µg/m³',
#       'displayName': 'SO₂ mass'}}],
#    'coordinates': {'latitude': 46.81309999982213,
#     'longitude': 6.944479999783754},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-17',
#      'dateTo': None}],
#    'bounds': [6.944479999783754,
#     46.81309999982213,
#     6.944479999783754,
#     46.81309999982213],
#    'distance': None,
#    'datetimeFirst': {'utc': '2017-09-22T07:00:00Z',
#     'local': '2017-09-22T09:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T14:00:00Z',
#     'local': '2024-11-08T15:00:00+01:00'}},
#   {'id': 1236033,
#    'name': 'Letzigrund',
#    'locality': None,
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 1, 'name': 'N/A'},
#     {'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 7978693,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 7971264,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 7978732,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 7971340,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 6530254,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 7973118,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 6530261,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'Temperature (C)'}},
#     {'id': 7973087,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}}],
#    'coordinates': {'latitude': 47.38049, 'longitude': 8.50299},
#    'licenses': [{'id': 41,
#      'name': 'CC BY 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2023-07-15',
#      'dateTo': None}],
#    'bounds': [8.50299, 47.38049, 8.50299, 47.38049],
#    'distance': None,
#    'datetimeFirst': {'utc': '2023-07-15T13:00:00Z',
#     'local': '2023-07-15T15:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T15:00:00Z',
#     'local': '2024-11-08T16:00:00+01:00'}},
#   {'id': 1372169,
#    'name': 'Seebach',
#    'locality': None,
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 1, 'name': 'N/A'},
#     {'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 7970790,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 7979243,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 7979241,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 7970866,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 6667924,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 7972878,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 6667920,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'Temperature (C)'}},
#     {'id': 7972896,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}}],
#    'coordinates': {'latitude': 47.42876601692833,
#     'longitude': 8.545199226884375},
#    'licenses': [{'id': 41,
#      'name': 'CC BY 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2023-07-15',
#      'dateTo': None}],
#    'bounds': [8.545199226884375,
#     47.42876601692833,
#     8.545199226884375,
#     47.42876601692833],
#    'distance': None,
#    'datetimeFirst': {'utc': '2023-08-02T12:00:00Z',
#     'local': '2023-08-02T14:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T15:00:00Z',
#     'local': '2024-11-08T16:00:00+01:00'}},
#   {'id': 1459983,
#    'name': 'Arnikastrasse',
#    'locality': None,
#    'timezone': 'Europe/Zurich',
# ...
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 7897461,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'Temperature (C)'}},
#     {'id': 7971698,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}}],
#    'coordinates': {'latitude': 47.40489, 'longitude': 8.60848},
#    'licenses': [{'id': 41,
#      'name': 'CC BY 4.0 DEED',
#      'attribution': {'name': 'AirGradient', 'url': None},
#      'dateFrom': '2023-07-15',
#      'dateTo': None}],
#    'bounds': [8.60848, 47.40489, 8.60848, 47.40489],
#    'distance': None,
#    'datetimeFirst': {'utc': '2024-02-20T14:00:00Z',
#     'local': '2024-02-20T15:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-11-08T15:00:00Z',
#     'local': '2024-11-08T16:00:00+01:00'}},
#   {'id': 2865371,
#    'name': 'Herzogenbuchsee',
#    'locality': None,
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 12, 'name': 'AirGradient'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 9358847,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 9358860,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 9358842,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 9358856,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 9358854,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'Temperature (C)'}},
#     {'id': 9358863,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}}],
#    'coordinates': {'latitude': 47.186782154114304,
#     'longitude': 7.701578990572923},
#    'licenses': [{'id': 41,
#      'name': 'CC BY 4.0 DEED',
#      'attribution': {'name': 'AirGradient', 'url': None},
#      'dateFrom': '2023-07-15',
#      'dateTo': None}],
#    'bounds': [7.701578990572923,
#     47.186782154114304,
#     7.701578990572923,
#     47.186782154114304],
#    'distance': None,
#    'datetimeFirst': {'utc': '2024-05-25T07:00:00Z',
#     'local': '2024-05-25T09:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T15:00:00Z',
#     'local': '2024-11-08T16:00:00+01:00'}},
#   {'id': 2900712,
#    'name': 'Bern',
#    'locality': None,
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 12, 'name': 'AirGradient'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 9624087,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 9624084,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 9624091,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 9624097,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 9624089,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'Temperature (C)'}},
#     {'id': 9624099,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}}],
#    'coordinates': {'latitude': 46.961811, 'longitude': 7.449759},
#    'licenses': [{'id': 41,
#      'name': 'CC BY 4.0 DEED',
#      'attribution': {'name': 'AirGradient', 'url': None},
#      'dateFrom': '2023-07-15',
#      'dateTo': None}],
#    'bounds': [7.449759, 46.961811, 7.449759, 46.961811],
#    'distance': None,
#    'datetimeFirst': {'utc': '2024-06-16T21:00:00Z',
#     'local': '2024-06-16T23:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T15:00:00Z',
#     'local': '2024-11-08T16:00:00+01:00'}},
#   {'id': 2972050,
#    'name': 'Herznach',
#    'locality': None,
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 12, 'name': 'AirGradient'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 10037887,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 10037881,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 10037890,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 10037891,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 10037886,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'Temperature (C)'}},
#     {'id': 10037879,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}}],
#    'coordinates': {'latitude': 47.47639017152665,
#     'longitude': 8.055727780563062},
#    'licenses': [{'id': 41,
#      'name': 'CC BY 4.0 DEED',
#      'attribution': {'name': 'AirGradient', 'url': None},
#      'dateFrom': '2023-07-15',
#      'dateTo': None}],
#    'bounds': [8.055727780563062,
#     47.47639017152665,
#     8.055727780563062,
#     47.47639017152665],
#    'distance': None,
#    'datetimeFirst': {'utc': '2024-07-22T15:00:00Z',
#     'local': '2024-07-22T17:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T15:00:00Z',
#     'local': '2024-11-08T16:00:00+01:00'}},
#   {'id': 3031030,
#    'name': 'Lussy',
#    'locality': None,
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 12, 'name': 'AirGradient'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 10371579,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 10371580,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 10371577,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 10371578,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 10371575,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'Temperature (C)'}},
#     {'id': 10371576,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}}],
#    'coordinates': {'latitude': 46.501014, 'longitude': 6.451581},
#    'licenses': [{'id': 41,
#      'name': 'CC BY 4.0 DEED',
#      'attribution': {'name': 'AirGradient', 'url': None},
#      'dateFrom': '2023-07-15',
#      'dateTo': None}],
#    'bounds': [6.451581, 46.501014, 6.451581, 46.501014],
#    'distance': None,
#    'datetimeFirst': {'utc': '2024-08-24T10:00:00Z',
#     'local': '2024-08-24T12:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T15:00:00Z',
#     'local': '2024-11-08T16:00:00+01:00'}},
#   {'id': 3047155,
#    'name': 'Technikum/Turmhaldenstrasse',
#    'locality': None,
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 12, 'name': 'AirGradient'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 10493202,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 10493176,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 10493168,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 10493192,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 10493164,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'Temperature (C)'}},
#     {'id': 10493160,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}}],
#    'coordinates': {'latitude': 47.4975207, 'longitude': 8.7276939},
#    'licenses': [{'id': 41,
#      'name': 'CC BY 4.0 DEED',
#      'attribution': {'name': 'AirGradient', 'url': None},
#      'dateFrom': '2023-07-15',
#      'dateTo': None}],
#    'bounds': [8.7276939, 47.4975207, 8.7276939, 47.4975207],
#    'distance': None,
#    'datetimeFirst': {'utc': '2024-09-04T10:00:00Z',
#     'local': '2024-09-04T12:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T15:00:00Z',
#     'local': '2024-11-08T16:00:00+01:00'}},
#   {'id': 3053429,
#    'name': 'Schönenbuch',
#    'locality': None,
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 12, 'name': 'AirGradient'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 10540509,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 10540522,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 10540513,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 10540514,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 10540517,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'Temperature (C)'}},
#     {'id': 10540518,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}}],
#    'coordinates': {'latitude': 47.5391273, 'longitude': 7.5075795},
#    'licenses': [{'id': 41,
#      'name': 'CC BY 4.0 DEED',
#      'attribution': {'name': 'AirGradient', 'url': None},
#      'dateFrom': '2023-07-15',
#      'dateTo': None}],
#    'bounds': [7.5075795, 47.5391273, 7.5075795, 47.5391273],
#    'distance': None,
#    'datetimeFirst': {'utc': '2024-09-08T11:00:00Z',
#     'local': '2024-09-08T13:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T15:00:00Z',
#     'local': '2024-11-08T16:00:00+01:00'}},
#   {'id': 3177616,
#    'name': 'Bern-Engehalde',
#    'locality': None,
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 12, 'name': 'AirGradient'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 11065865,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 11065855,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 11065860,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 11065859,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 11065863,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'Temperature (C)'}},
#     {'id': 11065862,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}}],
#    'coordinates': {'latitude': 46.9602119, 'longitude': 7.4407804},
#    'licenses': [{'id': 41,
#      'name': 'CC BY 4.0 DEED',
#      'attribution': {'name': 'AirGradient', 'url': None},
#      'dateFrom': '2023-07-15',
#      'dateTo': None}],
#    'bounds': [7.4407804, 46.9602119, 7.4407804, 46.9602119],
#    'distance': None,
#    'datetimeFirst': {'utc': '2024-10-24T16:00:00Z',
#     'local': '2024-10-24T18:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-11-08T15:00:00Z',
#     'local': '2024-11-08T16:00:00+01:00'}},
#   {'id': 3238534,
#    'name': 'Unterzollikofen',
#    'locality': None,
#    'timezone': 'Europe/Zurich',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 12, 'name': 'AirGradient'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 11222999,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 11222974,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 11223015,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 11222983,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 11223013,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'Temperature (C)'}},
#     {'id': 11222982,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}}],
#    'coordinates': {'latitude': 46.98897303595501,
#     'longitude': 7.4566606629454935},
#    'licenses': [{'id': 41,
#      'name': 'CC BY 4.0 DEED',
#      'attribution': {'name': 'AirGradient', 'url': None},
#      'dateFrom': '2023-07-15',
#      'dateTo': None}],
#    'bounds': [7.4566606629454935,
#     46.98897303595501,
#     7.4566606629454935,
#     46.98897303595501],
#    'distance': None,
#    'datetimeFirst': {'utc': '2024-11-07T14:00:00Z',
#     'local': '2024-11-07T15:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-11-08T15:00:00Z',
#     'local': '2024-11-08T16:00:00+01:00'}}]}

# %%
id_location = 2819

url_location = "https://api.openaq.org/v3/locations/"+str(id_location)
resp_location = requests.get(url_location, headers=header)

# %%
df_resp_location.json()
# Out:
# {'meta': {'name': 'openaq-api',
#   'website': '/',
#   'page': 1,
#   'limit': 100,
#   'found': 1},
#  'results': [{'id': 2819,
#    'name': 'Lustenau Zollamt',
#    'locality': None,
#    'timezone': 'Europe/Vienna',
#    'country': {'id': 92, 'code': 'CH', 'name': 'Switzerland'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 171, 'name': 'EEA Austria'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 5889,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}}],
#    'coordinates': {'latitude': 47.43251800890822,
#     'longitude': 9.649433287426664},
#    'licenses': [{'id': 30,
#      'name': 'CC BY-SA 4.0 DEED',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-11-18',
#      'dateTo': None}],
#    'bounds': [9.649433287426664,
#     47.43251800890822,
#     9.649433287426664,
#     47.43251800890822],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-11-18T05:00:00Z',
#     'local': '2016-11-18T06:00:00+01:00'},
#    'datetimeLast': {'utc': '2016-12-12T09:00:00Z',
#     'local': '2016-12-12T10:00:00+01:00'}}]}
