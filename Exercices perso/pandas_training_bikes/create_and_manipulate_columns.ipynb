# %%
import pandas as pd

data = pd.read_csv("comptage-velo-donnees-compteurs.csv",sep=";")
data = data.iloc[:,1:]
data.head()
# Out:
#                      Nom du compteur  Identifiant du site de comptage  \
# 0  97 avenue Denfert Rochereau SO-NE                        100003096
# 1  97 avenue Denfert Rochereau SO-NE                        100003096
# 2  97 avenue Denfert Rochereau SO-NE                        100003096
# 3  97 avenue Denfert Rochereau SO-NE                        100003096
# 4  97 avenue Denfert Rochereau SO-NE                        100003096
#
#        Nom du site de comptage  Comptage horaire  Date et heure de comptage  \
# 0  97 avenue Denfert Rochereau                14  2024-10-01T00:00:00+02:00
# 1  97 avenue Denfert Rochereau                 0  2024-10-01T03:00:00+02:00
# 2  97 avenue Denfert Rochereau                 9  2024-10-01T05:00:00+02:00
# 3  97 avenue Denfert Rochereau               119  2024-10-01T10:00:00+02:00
# 4  97 avenue Denfert Rochereau               106  2024-10-01T13:00:00+02:00
#
#   Date d'installation du site de comptage  \
# ...

# %%
mask = data["Comptage horaire"] > 0
data_1 = data[mask]
data_1.head()
# Out:
#                      Nom du compteur  Identifiant du site de comptage  \
# 0  97 avenue Denfert Rochereau SO-NE                        100003096
# 2  97 avenue Denfert Rochereau SO-NE                        100003096
# 3  97 avenue Denfert Rochereau SO-NE                        100003096
# 4  97 avenue Denfert Rochereau SO-NE                        100003096
# 5  97 avenue Denfert Rochereau SO-NE                        100003096
#
#        Nom du site de comptage  Comptage horaire  Date et heure de comptage  \
# 0  97 avenue Denfert Rochereau                14  2024-10-01T00:00:00+02:00
# 2  97 avenue Denfert Rochereau                 9  2024-10-01T05:00:00+02:00
# 3  97 avenue Denfert Rochereau               119  2024-10-01T10:00:00+02:00
# 4  97 avenue Denfert Rochereau               106  2024-10-01T13:00:00+02:00
# 5  97 avenue Denfert Rochereau               138  2024-10-01T16:00:00+02:00
#
#   Date d'installation du site de comptage  \
# ...
